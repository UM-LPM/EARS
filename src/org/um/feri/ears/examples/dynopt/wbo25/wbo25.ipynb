// %%
%useLatestDescriptors
%use lets-plot

// %%
import java.io.File

val algResultsDir =
    "D:${File.separator}" +
            "EDOLAB-MATLAB${File.separator}" +
            "Results${File.separator}" +
            "Comparison${File.separator}" +
            "WBO25${File.separator}" +
            "MPB_Peaks10_ChangeFrequency5000_D5_ShiftSeverity1_Environments100"

// %%
import org.um.feri.ears.algorithms.DummyAlgorithm
import org.um.feri.ears.algorithms.NumberAlgorithm

val players = arrayListOf<NumberAlgorithm>(
    DummyAlgorithm("ACFPSO", algResultsDir),
    DummyAlgorithm("AMPDE", algResultsDir),
    DummyAlgorithm("CPSO", algResultsDir),
    //DummyAlgorithm("mjDE", algResultsDir)
)

// %%
import org.um.feri.ears.examples.dynopt.AlgorithmPerformance

val algPerf = players.map { AlgorithmPerformance(it.id) }.toMutableList() // Prepare objects for storing the algorithms data.

val runNumber = 31

val changeFrequency = 5000
val environmentNumber = 100
val sampleInterval = 100
val numOfProblems = (changeFrequency / sampleInterval) * environmentNumber + environmentNumber - 1

// %%
import org.um.feri.ears.benchmark.Benchmark
import org.um.feri.ears.examples.dynopt.MPBBenchmark
import org.um.feri.ears.statistic.rating_system.RatingType
import org.um.feri.ears.visualization.rating.RatingIntervalPlot

Benchmark.printInfo = false
//DummyAlgorithm.readFromJson = false
val displayRatingChart = false

var evaluationNumber = sampleInterval
for (i in 0 until numOfProblems) {
    // Create and execute benchmarks for every evaluation defined with sampleInterval.
    val gmpbBenchmark = MPBBenchmark(evaluationNumber).apply {
        setDisplayRatingCharts(false)
        addAlgorithms(players)
        run(runNumber)
    }

    val tournamentResults = gmpbBenchmark.tournamentResults

    //tournamentResults.players.forEach { player ->
    //    algPerf.firstOrNull { it.name == player.id }?.apply {
    //        addRating(
    //            "mpbeval0",
    //            1500.0,
    //            350.0
    //        )
    //    }
    //}

    if (displayRatingChart) {
        RatingIntervalPlot.displayChart(
            tournamentResults.players,
            RatingType.GLICKO2,
            "Rating Interval for Eval$evaluationNumber"
        )
    }

    // Store tournament results for every player (algorithm).
    tournamentResults.players.forEach { player ->
        algPerf.firstOrNull { it.name == player.id }?.apply {
            addRating(
                "mpbeval$evaluationNumber",
                player.glicko2Rating.rating,
                player.glicko2Rating.ratingDeviation
            )
        }
    }

    if (evaluationNumber % changeFrequency == 0) {
        // first evaluation after environment/problem change
        evaluationNumber++
    } else if (evaluationNumber % sampleInterval == 0) {
        // evaluation every 'sampleInterval'
        evaluationNumber += sampleInterval
    } else {
        // next evaluation after environment/problem change
        evaluationNumber = evaluationNumber + sampleInterval - 1
    }
}
// Out:
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=21,6, Std-Dev(sigma)=1,48 RI=[18,64, 24,57]
// AMPDE - Mean(mu)=18,01, Std-Dev(sigma)=1,13 RI=[15,74, 20,27]
// CPSO - Mean(mu)=17,52, Std-Dev(sigma)=1,08 RI=[15,37, 19,68]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=27,82, Std-Dev(sigma)=1,48 RI=[24,85, 30,79]
// AMPDE - Mean(mu)=22,37, Std-Dev(sigma)=1,16 RI=[20,05, 24,68]
// CPSO - Mean(mu)=21,85, Std-Dev(sigma)=1,16 RI=[19,53, 24,16]
//
// Glicko2 rating:
// ACFPSO - Rating=1.839,7 RD=64,8 ro=0,06 RI=[1710,1, 1969,34]
// AMPDE - Rating=1.338,2 RD=64,8 ro=0,06 RI=[1208,61, 1467,85]
// CPSO - Rating=1.322,1 RD=64,8 ro=0,06 RI=[1192,43, 1451,67]
//
// Game results:
// ACFPSO [win=52, lose=10, draw=0]
// 	 Against:{CPSO=[win=26, lose=5, draw=0], AMPDE=[win=26, lose=5, draw=0]}
// 	 Problems:{MPBEval100=[win=52, lose=10, draw=0]}
// AMPDE [win=13, lose=33, draw=16]
// 	 Against:{ACFPSO=[win=5, lose=26, draw=0], CPSO=[win=8, lose=7, draw=16]}
// 	 Problems:{MPBEval100=[win=13, lose=33, draw=16]}
// CPSO [win=12, lose=34, draw=16]
// 	 Against:{ACFPSO=[win=5, lose=26, draw=0], AMPDE=[win=7, lose=8, draw=16]}
// 	 Problems:{MPBEval100=[win=12, lose=34, draw=16]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=27,77, Std-Dev(sigma)=2,54 RI=[22,69, 32,85]
// AMPDE - Mean(mu)=17,48, Std-Dev(sigma)=1,34 RI=[14,81, 20,15]
// CPSO - Mean(mu)=16,97, Std-Dev(sigma)=1,35 RI=[14,28, 19,67]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=32,3, Std-Dev(sigma)=2,3 RI=[27,7, 36,89]
// CPSO - Mean(mu)=20,71, Std-Dev(sigma)=1,36 RI=[17,99, 23,44]
// AMPDE - Mean(mu)=20,52, Std-Dev(sigma)=1,38 RI=[17,77, 23,28]
//
// Glicko2 rating:
// ACFPSO - Rating=1.969,1 RD=64,8 ro=0,06 RI=[1839,52, 2098,76]
// AMPDE - Rating=1.273,5 RD=64,8 ro=0,06 RI=[1143,9, 1403,14]
// CPSO - Rating=1.257,3 RD=64,8 ro=0,06 RI=[1127,72, 1386,96]
//
// Game results:
// ACFPSO [win=60, lose=2, draw=0]
// 	 Against:{CPSO=[win=29, lose=2, draw=0], AMPDE=[win=31, lose=0, draw=0]}
// 	 Problems:{MPBEval200=[win=60, lose=2, draw=0]}
// AMPDE [win=16, lose=44, draw=2]
// 	 Against:{ACFPSO=[win=0, lose=31, draw=0], CPSO=[win=16, lose=13, draw=2]}
// 	 Problems:{MPBEval200=[win=16, lose=44, draw=2]}
// CPSO [win=15, lose=45, draw=2]
// 	 Against:{ACFPSO=[win=2, lose=29, draw=0], AMPDE=[win=13, lose=16, draw=2]}
// 	 Problems:{MPBEval200=[win=15, lose=45, draw=2]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=26,17, Std-Dev(sigma)=2,2 RI=[21,76, 30,58]
// AMPDE - Mean(mu)=17,47, Std-Dev(sigma)=1,31 RI=[14,85, 20,1]
// CPSO - Mean(mu)=16,24, Std-Dev(sigma)=1,33 RI=[13,58, 18,9]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=31,28, Std-Dev(sigma)=1,99 RI=[27,29, 35,26]
// AMPDE - Mean(mu)=21,63, Std-Dev(sigma)=1,35 RI=[18,93, 24,32]
// CPSO - Mean(mu)=20,5, Std-Dev(sigma)=1,35 RI=[17,8, 23,2]
//
// Glicko2 rating:
// ACFPSO - Rating=1.953 RD=64,8 ro=0,06 RI=[1823,34, 2082,58]
// AMPDE - Rating=1.297,8 RD=64,8 ro=0,06 RI=[1168,17, 1427,4]
// CPSO - Rating=1.249,3 RD=64,8 ro=0,06 RI=[1119,63, 1378,87]
//
// Game results:
// ACFPSO [win=59, lose=3, draw=0]
// 	 Against:{CPSO=[win=29, lose=2, draw=0], AMPDE=[win=30, lose=1, draw=0]}
// 	 Problems:{MPBEval300=[win=59, lose=3, draw=0]}
// AMPDE [win=18, lose=43, draw=1]
// 	 Against:{ACFPSO=[win=1, lose=30, draw=0], CPSO=[win=17, lose=13, draw=1]}
// 	 Problems:{MPBEval300=[win=18, lose=43, draw=1]}
// CPSO [win=15, lose=46, draw=1]
// 	 Against:{ACFPSO=[win=2, lose=29, draw=0], AMPDE=[win=13, lose=17, draw=1]}
// 	 Problems:{MPBEval300=[win=15, lose=46, draw=1]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=24,65, Std-Dev(sigma)=2 RI=[20,65, 28,66]
// AMPDE - Mean(mu)=17,63, Std-Dev(sigma)=1,29 RI=[15,06, 20,2]
// CPSO - Mean(mu)=16,1, Std-Dev(sigma)=1,31 RI=[13,49, 18,72]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=31,03, Std-Dev(sigma)=1,85 RI=[27,33, 34,74]
// AMPDE - Mean(mu)=21,87, Std-Dev(sigma)=1,33 RI=[19,21, 24,54]
// CPSO - Mean(mu)=20,6, Std-Dev(sigma)=1,33 RI=[17,94, 23,27]
//
// Glicko2 rating:
// ACFPSO - Rating=1.936,8 RD=64,8 ro=0,06 RI=[1807,17, 2066,4]
// AMPDE - Rating=1.322,1 RD=64,8 ro=0,06 RI=[1192,43, 1451,67]
// CPSO - Rating=1.241,2 RD=64,8 ro=0,06 RI=[1111,55, 1370,78]
//
// Game results:
// ACFPSO [win=58, lose=4, draw=0]
// 	 Against:{CPSO=[win=28, lose=3, draw=0], AMPDE=[win=30, lose=1, draw=0]}
// 	 Problems:{MPBEval400=[win=58, lose=4, draw=0]}
// AMPDE [win=20, lose=42, draw=0]
// 	 Against:{ACFPSO=[win=1, lose=30, draw=0], CPSO=[win=19, lose=12, draw=0]}
// 	 Problems:{MPBEval400=[win=20, lose=42, draw=0]}
// CPSO [win=15, lose=47, draw=0]
// 	 Against:{ACFPSO=[win=3, lose=28, draw=0], AMPDE=[win=12, lose=19, draw=0]}
// 	 Problems:{MPBEval400=[win=15, lose=47, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=22,03, Std-Dev(sigma)=1,68 RI=[18,66, 25,4]
// AMPDE - Mean(mu)=16,41, Std-Dev(sigma)=1,25 RI=[13,92, 18,91]
// CPSO - Mean(mu)=14,35, Std-Dev(sigma)=1,26 RI=[11,82, 16,87]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=30,03, Std-Dev(sigma)=1,54 RI=[26,95, 33,11]
// AMPDE - Mean(mu)=23,47, Std-Dev(sigma)=1,27 RI=[20,93, 26,02]
// CPSO - Mean(mu)=21,07, Std-Dev(sigma)=1,3 RI=[18,46, 23,68]
//
// Glicko2 rating:
// ACFPSO - Rating=1.888,3 RD=64,8 ro=0,06 RI=[1758,63, 2017,87]
// AMPDE - Rating=1.386,8 RD=64,8 ro=0,06 RI=[1257,14, 1516,38]
// CPSO - Rating=1.225 RD=64,8 ro=0,06 RI=[1095,37, 1354,61]
//
// Game results:
// ACFPSO [win=55, lose=7, draw=0]
// 	 Against:{CPSO=[win=28, lose=3, draw=0], AMPDE=[win=27, lose=4, draw=0]}
// 	 Problems:{MPBEval500=[win=55, lose=7, draw=0]}
// AMPDE [win=24, lose=38, draw=0]
// 	 Against:{ACFPSO=[win=4, lose=27, draw=0], CPSO=[win=20, lose=11, draw=0]}
// 	 Problems:{MPBEval500=[win=24, lose=38, draw=0]}
// CPSO [win=14, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=3, lose=28, draw=0], AMPDE=[win=11, lose=20, draw=0]}
// 	 Problems:{MPBEval500=[win=14, lose=48, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=21,66, Std-Dev(sigma)=1,57 RI=[18,53, 24,79]
// AMPDE - Mean(mu)=16,81, Std-Dev(sigma)=1,21 RI=[14,39, 19,22]
// CPSO - Mean(mu)=15,71, Std-Dev(sigma)=1,2 RI=[13,31, 18,12]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=29,39, Std-Dev(sigma)=1,49 RI=[26,42, 32,37]
// AMPDE - Mean(mu)=23,02, Std-Dev(sigma)=1,25 RI=[20,52, 25,52]
// CPSO - Mean(mu)=21,91, Std-Dev(sigma)=1,25 RI=[19,4, 24,41]
//
// Glicko2 rating:
// ACFPSO - Rating=1.855,9 RD=64,8 ro=0,06 RI=[1726,28, 1985,52]
// AMPDE - Rating=1.370,6 RD=64,8 ro=0,06 RI=[1240,96, 1500,2]
// CPSO - Rating=1.273,5 RD=64,8 ro=0,06 RI=[1143,9, 1403,14]
//
// Game results:
// ACFPSO [win=53, lose=9, draw=0]
// 	 Against:{CPSO=[win=26, lose=5, draw=0], AMPDE=[win=27, lose=4, draw=0]}
// 	 Problems:{MPBEval600=[win=53, lose=9, draw=0]}
// AMPDE [win=23, lose=39, draw=0]
// 	 Against:{ACFPSO=[win=4, lose=27, draw=0], CPSO=[win=19, lose=12, draw=0]}
// 	 Problems:{MPBEval600=[win=23, lose=39, draw=0]}
// CPSO [win=17, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=5, lose=26, draw=0], AMPDE=[win=12, lose=19, draw=0]}
// 	 Problems:{MPBEval600=[win=17, lose=45, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=21,21, Std-Dev(sigma)=1,52 RI=[18,17, 24,26]
// CPSO - Mean(mu)=16,34, Std-Dev(sigma)=1,19 RI=[13,96, 18,73]
// AMPDE - Mean(mu)=15,98, Std-Dev(sigma)=1,22 RI=[13,55, 18,42]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=28,96, Std-Dev(sigma)=1,45 RI=[26,07, 31,85]
// CPSO - Mean(mu)=22,96, Std-Dev(sigma)=1,23 RI=[20,49, 25,42]
// AMPDE - Mean(mu)=22,38, Std-Dev(sigma)=1,27 RI=[19,84, 24,92]
//
// Glicko2 rating:
// ACFPSO - Rating=1.839,7 RD=64,8 ro=0,06 RI=[1710,1, 1969,34]
// CPSO - Rating=1.338,2 RD=64,8 ro=0,06 RI=[1208,61, 1467,85]
// AMPDE - Rating=1.322,1 RD=64,8 ro=0,06 RI=[1192,43, 1451,67]
//
// Game results:
// ACFPSO [win=52, lose=10, draw=0]
// 	 Against:{CPSO=[win=25, lose=6, draw=0], AMPDE=[win=27, lose=4, draw=0]}
// 	 Problems:{MPBEval700=[win=52, lose=10, draw=0]}
// CPSO [win=21, lose=41, draw=0]
// 	 Against:{ACFPSO=[win=6, lose=25, draw=0], AMPDE=[win=15, lose=16, draw=0]}
// 	 Problems:{MPBEval700=[win=21, lose=41, draw=0]}
// AMPDE [win=20, lose=42, draw=0]
// 	 Against:{ACFPSO=[win=4, lose=27, draw=0], CPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{MPBEval700=[win=20, lose=42, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=21,26, Std-Dev(sigma)=1,53 RI=[18,21, 24,32]
// CPSO - Mean(mu)=16,51, Std-Dev(sigma)=1,19 RI=[14,13, 18,89]
// AMPDE - Mean(mu)=15,87, Std-Dev(sigma)=1,23 RI=[13,41, 18,33]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=28,98, Std-Dev(sigma)=1,45 RI=[26,08, 31,88]
// CPSO - Mean(mu)=23,1, Std-Dev(sigma)=1,23 RI=[20,64, 25,56]
// AMPDE - Mean(mu)=22,23, Std-Dev(sigma)=1,28 RI=[19,68, 24,79]
//
// Glicko2 rating:
// ACFPSO - Rating=1.839,7 RD=64,8 ro=0,06 RI=[1710,1, 1969,34]
// CPSO - Rating=1.354,4 RD=64,8 ro=0,06 RI=[1224,79, 1484,02]
// AMPDE - Rating=1.305,9 RD=64,8 ro=0,06 RI=[1176,26, 1435,49]
//
// Game results:
// ACFPSO [win=52, lose=10, draw=0]
// 	 Against:{CPSO=[win=25, lose=6, draw=0], AMPDE=[win=27, lose=4, draw=0]}
// 	 Problems:{MPBEval800=[win=52, lose=10, draw=0]}
// CPSO [win=22, lose=40, draw=0]
// 	 Against:{ACFPSO=[win=6, lose=25, draw=0], AMPDE=[win=16, lose=15, draw=0]}
// 	 Problems:{MPBEval800=[win=22, lose=40, draw=0]}
// AMPDE [win=19, lose=43, draw=0]
// 	 Against:{ACFPSO=[win=4, lose=27, draw=0], CPSO=[win=15, lose=16, draw=0]}
// 	 Problems:{MPBEval800=[win=19, lose=43, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=18,67, Std-Dev(sigma)=1,4 RI=[15,86, 21,48]
// AMPDE - Mean(mu)=15,91, Std-Dev(sigma)=1,18 RI=[13,55, 18,28]
// CPSO - Mean(mu)=14,6, Std-Dev(sigma)=1,15 RI=[12,29, 16,9]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=28,38, Std-Dev(sigma)=1,37 RI=[25,64, 31,12]
// AMPDE - Mean(mu)=24,13, Std-Dev(sigma)=1,22 RI=[21,69, 26,57]
// CPSO - Mean(mu)=22,62, Std-Dev(sigma)=1,22 RI=[20,17, 25,06]
//
// Glicko2 rating:
// ACFPSO - Rating=1.791,2 RD=64,8 ro=0,06 RI=[1661,57, 1920,81]
// AMPDE - Rating=1.386,8 RD=64,8 ro=0,06 RI=[1257,14, 1516,38]
// CPSO - Rating=1.322,1 RD=64,8 ro=0,06 RI=[1192,43, 1451,67]
//
// Game results:
// ACFPSO [win=49, lose=13, draw=0]
// 	 Against:{CPSO=[win=25, lose=6, draw=0], AMPDE=[win=24, lose=7, draw=0]}
// 	 Problems:{MPBEval900=[win=49, lose=13, draw=0]}
// AMPDE [win=24, lose=38, draw=0]
// 	 Against:{ACFPSO=[win=7, lose=24, draw=0], CPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{MPBEval900=[win=24, lose=38, draw=0]}
// CPSO [win=20, lose=42, draw=0]
// 	 Against:{ACFPSO=[win=6, lose=25, draw=0], AMPDE=[win=14, lose=17, draw=0]}
// 	 Problems:{MPBEval900=[win=20, lose=42, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=15,93, Std-Dev(sigma)=1,29 RI=[13,35, 18,52]
// AMPDE - Mean(mu)=14,42, Std-Dev(sigma)=1,16 RI=[12,11, 16,73]
// CPSO - Mean(mu)=13,87, Std-Dev(sigma)=1,2 RI=[11,48, 16,27]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=26,92, Std-Dev(sigma)=1,27 RI=[24,37, 29,47]
// AMPDE - Mean(mu)=24,42, Std-Dev(sigma)=1,19 RI=[22,05, 26,79]
// CPSO - Mean(mu)=23,9, Std-Dev(sigma)=1,24 RI=[21,42, 26,38]
//
// Glicko2 rating:
// ACFPSO - Rating=1.710,3 RD=64,8 ro=0,06 RI=[1580,68, 1839,92]
// AMPDE - Rating=1.451,5 RD=64,8 ro=0,06 RI=[1321,85, 1581,09]
// CPSO - Rating=1.338,2 RD=64,8 ro=0,06 RI=[1208,61, 1467,85]
//
// Game results:
// ACFPSO [win=44, lose=18, draw=0]
// 	 Against:{CPSO=[win=23, lose=8, draw=0], AMPDE=[win=21, lose=10, draw=0]}
// 	 Problems:{MPBEval1000=[win=44, lose=18, draw=0]}
// AMPDE [win=28, lose=34, draw=0]
// 	 Against:{ACFPSO=[win=10, lose=21, draw=0], CPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{MPBEval1000=[win=28, lose=34, draw=0]}
// CPSO [win=21, lose=41, draw=0]
// 	 Against:{ACFPSO=[win=8, lose=23, draw=0], AMPDE=[win=13, lose=18, draw=0]}
// 	 Problems:{MPBEval1000=[win=21, lose=41, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=16,14, Std-Dev(sigma)=1,29 RI=[13,57, 18,71]
// AMPDE - Mean(mu)=15,54, Std-Dev(sigma)=1,18 RI=[13,18, 17,9]
// CPSO - Mean(mu)=13,99, Std-Dev(sigma)=1,19 RI=[11,61, 16,37]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=26,84, Std-Dev(sigma)=1,28 RI=[24,28, 29,4]
// AMPDE - Mean(mu)=25,2, Std-Dev(sigma)=1,21 RI=[22,79, 27,62]
// CPSO - Mean(mu)=23,41, Std-Dev(sigma)=1,27 RI=[20,87, 25,95]
//
// Glicko2 rating:
// ACFPSO - Rating=1.694,1 RD=64,8 ro=0,06 RI=[1564,51, 1823,74]
// AMPDE - Rating=1.532,4 RD=64,8 ro=0,06 RI=[1402,74, 1661,97]
// CPSO - Rating=1.273,5 RD=64,8 ro=0,06 RI=[1143,9, 1403,14]
//
// Game results:
// ACFPSO [win=43, lose=19, draw=0]
// 	 Against:{CPSO=[win=23, lose=8, draw=0], AMPDE=[win=20, lose=11, draw=0]}
// 	 Problems:{MPBEval1100=[win=43, lose=19, draw=0]}
// AMPDE [win=33, lose=29, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], CPSO=[win=22, lose=9, draw=0]}
// 	 Problems:{MPBEval1100=[win=33, lose=29, draw=0]}
// CPSO [win=17, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=8, lose=23, draw=0], AMPDE=[win=9, lose=22, draw=0]}
// 	 Problems:{MPBEval1100=[win=17, lose=45, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=16,8, Std-Dev(sigma)=1,21 RI=[14,38, 19,22]
// ACFPSO - Mean(mu)=16,78, Std-Dev(sigma)=1,31 RI=[14,15, 19,4]
// CPSO - Mean(mu)=13,04, Std-Dev(sigma)=1,18 RI=[10,68, 15,4]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=27,53, Std-Dev(sigma)=1,28 RI=[24,97, 30,09]
// AMPDE - Mean(mu)=26,17, Std-Dev(sigma)=1,22 RI=[23,73, 28,61]
// CPSO - Mean(mu)=21,82, Std-Dev(sigma)=1,29 RI=[19,24, 24,4]
//
// Glicko2 rating:
// ACFPSO - Rating=1.710,3 RD=64,8 ro=0,06 RI=[1580,68, 1839,92]
// AMPDE - Rating=1.597,1 RD=64,8 ro=0,06 RI=[1467,44, 1726,68]
// CPSO - Rating=1.192,6 RD=64,8 ro=0,06 RI=[1063,01, 1322,25]
//
// Game results:
// ACFPSO [win=44, lose=18, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=20, lose=11, draw=0]}
// 	 Problems:{MPBEval1200=[win=44, lose=18, draw=0]}
// AMPDE [win=37, lose=25, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], CPSO=[win=26, lose=5, draw=0]}
// 	 Problems:{MPBEval1200=[win=37, lose=25, draw=0]}
// CPSO [win=12, lose=50, draw=0]
// 	 Against:{ACFPSO=[win=7, lose=24, draw=0], AMPDE=[win=5, lose=26, draw=0]}
// 	 Problems:{MPBEval1200=[win=12, lose=50, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,2, Std-Dev(sigma)=1,23 RI=[14,73, 19,66]
// ACFPSO - Mean(mu)=16,37, Std-Dev(sigma)=1,3 RI=[13,76, 18,98]
// CPSO - Mean(mu)=12,68, Std-Dev(sigma)=1,2 RI=[10,29, 15,07]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=27,19, Std-Dev(sigma)=1,27 RI=[24,65, 29,74]
// AMPDE - Mean(mu)=26,74, Std-Dev(sigma)=1,23 RI=[24,29, 29,2]
// CPSO - Mean(mu)=21,52, Std-Dev(sigma)=1,31 RI=[18,9, 24,15]
//
// Glicko2 rating:
// ACFPSO - Rating=1.694,1 RD=64,8 ro=0,06 RI=[1564,51, 1823,74]
// AMPDE - Rating=1.629,4 RD=64,8 ro=0,06 RI=[1499,8, 1759,04]
// CPSO - Rating=1.176,5 RD=64,8 ro=0,06 RI=[1046,84, 1306,08]
//
// Game results:
// ACFPSO [win=43, lose=19, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=19, lose=12, draw=0]}
// 	 Problems:{MPBEval1300=[win=43, lose=19, draw=0]}
// AMPDE [win=39, lose=23, draw=0]
// 	 Against:{ACFPSO=[win=12, lose=19, draw=0], CPSO=[win=27, lose=4, draw=0]}
// 	 Problems:{MPBEval1300=[win=39, lose=23, draw=0]}
// CPSO [win=11, lose=51, draw=0]
// 	 Against:{ACFPSO=[win=7, lose=24, draw=0], AMPDE=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval1300=[win=11, lose=51, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,73, Std-Dev(sigma)=1,26 RI=[15,22, 20,24]
// ACFPSO - Mean(mu)=14,99, Std-Dev(sigma)=1,32 RI=[12,35, 17,63]
// CPSO - Mean(mu)=12,57, Std-Dev(sigma)=1,25 RI=[10,07, 15,07]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=26,96, Std-Dev(sigma)=1,25 RI=[24,46, 29,45]
// ACFPSO - Mean(mu)=26,5, Std-Dev(sigma)=1,28 RI=[23,93, 29,06]
// CPSO - Mean(mu)=21,65, Std-Dev(sigma)=1,36 RI=[18,93, 24,37]
//
// Glicko2 rating:
// ACFPSO - Rating=1.677,9 RD=64,8 ro=0,06 RI=[1548,33, 1807,57]
// AMPDE - Rating=1.645,6 RD=64,8 ro=0,06 RI=[1515,98, 1775,21]
// CPSO - Rating=1.176,5 RD=64,8 ro=0,06 RI=[1046,84, 1306,08]
//
// Game results:
// ACFPSO [win=42, lose=20, draw=0]
// 	 Against:{CPSO=[win=22, lose=9, draw=0], AMPDE=[win=20, lose=11, draw=0]}
// 	 Problems:{MPBEval1400=[win=42, lose=20, draw=0]}
// AMPDE [win=40, lose=22, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], CPSO=[win=29, lose=2, draw=0]}
// 	 Problems:{MPBEval1400=[win=40, lose=22, draw=0]}
// CPSO [win=11, lose=51, draw=0]
// 	 Against:{ACFPSO=[win=9, lose=22, draw=0], AMPDE=[win=2, lose=29, draw=0]}
// 	 Problems:{MPBEval1400=[win=11, lose=51, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,85, Std-Dev(sigma)=1,29 RI=[15,27, 20,43]
// ACFPSO - Mean(mu)=14,85, Std-Dev(sigma)=1,28 RI=[12,29, 17,41]
// CPSO - Mean(mu)=12,48, Std-Dev(sigma)=1,25 RI=[9,98, 14,98]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,52, Std-Dev(sigma)=1,25 RI=[25,02, 30,03]
// ACFPSO - Mean(mu)=26,14, Std-Dev(sigma)=1,25 RI=[23,65, 28,63]
// CPSO - Mean(mu)=21,75, Std-Dev(sigma)=1,36 RI=[19,02, 24,48]
//
// Glicko2 rating:
// AMPDE - Rating=1.694,1 RD=64,8 ro=0,06 RI=[1564,51, 1823,74]
// ACFPSO - Rating=1.629,4 RD=64,8 ro=0,06 RI=[1499,8, 1759,04]
// CPSO - Rating=1.176,5 RD=64,8 ro=0,06 RI=[1046,84, 1306,08]
//
// Game results:
// AMPDE [win=43, lose=19, draw=0]
// 	 Against:{ACFPSO=[win=14, lose=17, draw=0], CPSO=[win=29, lose=2, draw=0]}
// 	 Problems:{MPBEval1500=[win=43, lose=19, draw=0]}
// ACFPSO [win=39, lose=23, draw=0]
// 	 Against:{CPSO=[win=22, lose=9, draw=0], AMPDE=[win=17, lose=14, draw=0]}
// 	 Problems:{MPBEval1500=[win=39, lose=23, draw=0]}
// CPSO [win=11, lose=51, draw=0]
// 	 Against:{ACFPSO=[win=9, lose=22, draw=0], AMPDE=[win=2, lose=29, draw=0]}
// 	 Problems:{MPBEval1500=[win=11, lose=51, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,88, Std-Dev(sigma)=1,28 RI=[15,32, 20,44]
// ACFPSO - Mean(mu)=14,86, Std-Dev(sigma)=1,29 RI=[12,27, 17,45]
// CPSO - Mean(mu)=12,52, Std-Dev(sigma)=1,25 RI=[10,01, 15,02]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,36, Std-Dev(sigma)=1,25 RI=[24,85, 29,86]
// ACFPSO - Mean(mu)=26,17, Std-Dev(sigma)=1,26 RI=[23,65, 28,69]
// CPSO - Mean(mu)=21,68, Std-Dev(sigma)=1,36 RI=[18,96, 24,41]
//
// Glicko2 rating:
// AMPDE - Rating=1.677,9 RD=64,8 ro=0,06 RI=[1548,33, 1807,57]
// ACFPSO - Rating=1.645,6 RD=64,8 ro=0,06 RI=[1515,98, 1775,21]
// CPSO - Rating=1.176,5 RD=64,8 ro=0,06 RI=[1046,84, 1306,08]
//
// Game results:
// AMPDE [win=42, lose=20, draw=0]
// 	 Against:{ACFPSO=[win=13, lose=18, draw=0], CPSO=[win=29, lose=2, draw=0]}
// 	 Problems:{MPBEval1600=[win=42, lose=20, draw=0]}
// ACFPSO [win=40, lose=22, draw=0]
// 	 Against:{CPSO=[win=22, lose=9, draw=0], AMPDE=[win=18, lose=13, draw=0]}
// 	 Problems:{MPBEval1600=[win=40, lose=22, draw=0]}
// CPSO [win=11, lose=51, draw=0]
// 	 Against:{ACFPSO=[win=9, lose=22, draw=0], AMPDE=[win=2, lose=29, draw=0]}
// 	 Problems:{MPBEval1600=[win=11, lose=51, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,83, Std-Dev(sigma)=1,28 RI=[15,27, 20,39]
// ACFPSO - Mean(mu)=14,49, Std-Dev(sigma)=1,23 RI=[12,04, 16,95]
// CPSO - Mean(mu)=13,12, Std-Dev(sigma)=1,21 RI=[10,7, 15,55]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,67, Std-Dev(sigma)=1,24 RI=[25,19, 30,16]
// ACFPSO - Mean(mu)=25,18, Std-Dev(sigma)=1,22 RI=[22,73, 27,63]
// CPSO - Mean(mu)=22,5, Std-Dev(sigma)=1,3 RI=[19,91, 25,1]
//
// Glicko2 rating:
// AMPDE - Rating=1.694,1 RD=64,8 ro=0,06 RI=[1564,51, 1823,74]
// ACFPSO - Rating=1.580,9 RD=64,8 ro=0,06 RI=[1451,27, 1710,5]
// CPSO - Rating=1.225 RD=64,8 ro=0,06 RI=[1095,37, 1354,61]
//
// Game results:
// AMPDE [win=43, lose=19, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], CPSO=[win=28, lose=3, draw=0]}
// 	 Problems:{MPBEval1700=[win=43, lose=19, draw=0]}
// ACFPSO [win=36, lose=26, draw=0]
// 	 Against:{CPSO=[win=20, lose=11, draw=0], AMPDE=[win=16, lose=15, draw=0]}
// 	 Problems:{MPBEval1700=[win=36, lose=26, draw=0]}
// CPSO [win=14, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], AMPDE=[win=3, lose=28, draw=0]}
// 	 Problems:{MPBEval1700=[win=14, lose=48, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,83, Std-Dev(sigma)=1,28 RI=[15,27, 20,39]
// ACFPSO - Mean(mu)=14,49, Std-Dev(sigma)=1,23 RI=[12,04, 16,95]
// CPSO - Mean(mu)=13,12, Std-Dev(sigma)=1,21 RI=[10,7, 15,55]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,67, Std-Dev(sigma)=1,24 RI=[25,19, 30,16]
// ACFPSO - Mean(mu)=25,18, Std-Dev(sigma)=1,22 RI=[22,73, 27,63]
// CPSO - Mean(mu)=22,5, Std-Dev(sigma)=1,3 RI=[19,91, 25,1]
//
// Glicko2 rating:
// AMPDE - Rating=1.694,1 RD=64,8 ro=0,06 RI=[1564,51, 1823,74]
// ACFPSO - Rating=1.580,9 RD=64,8 ro=0,06 RI=[1451,27, 1710,5]
// CPSO - Rating=1.225 RD=64,8 ro=0,06 RI=[1095,37, 1354,61]
//
// Game results:
// AMPDE [win=43, lose=19, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], CPSO=[win=28, lose=3, draw=0]}
// 	 Problems:{MPBEval1800=[win=43, lose=19, draw=0]}
// ACFPSO [win=36, lose=26, draw=0]
// 	 Against:{CPSO=[win=20, lose=11, draw=0], AMPDE=[win=16, lose=15, draw=0]}
// 	 Problems:{MPBEval1800=[win=36, lose=26, draw=0]}
// CPSO [win=14, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], AMPDE=[win=3, lose=28, draw=0]}
// 	 Problems:{MPBEval1800=[win=14, lose=48, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,83, Std-Dev(sigma)=1,28 RI=[15,27, 20,39]
// ACFPSO - Mean(mu)=14,49, Std-Dev(sigma)=1,23 RI=[12,04, 16,95]
// CPSO - Mean(mu)=13,12, Std-Dev(sigma)=1,21 RI=[10,7, 15,55]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,67, Std-Dev(sigma)=1,24 RI=[25,19, 30,16]
// ACFPSO - Mean(mu)=25,18, Std-Dev(sigma)=1,22 RI=[22,73, 27,63]
// CPSO - Mean(mu)=22,5, Std-Dev(sigma)=1,3 RI=[19,91, 25,1]
//
// Glicko2 rating:
// AMPDE - Rating=1.694,1 RD=64,8 ro=0,06 RI=[1564,51, 1823,74]
// ACFPSO - Rating=1.580,9 RD=64,8 ro=0,06 RI=[1451,27, 1710,5]
// CPSO - Rating=1.225 RD=64,8 ro=0,06 RI=[1095,37, 1354,61]
//
// Game results:
// AMPDE [win=43, lose=19, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], CPSO=[win=28, lose=3, draw=0]}
// 	 Problems:{MPBEval1900=[win=43, lose=19, draw=0]}
// ACFPSO [win=36, lose=26, draw=0]
// 	 Against:{CPSO=[win=20, lose=11, draw=0], AMPDE=[win=16, lose=15, draw=0]}
// 	 Problems:{MPBEval1900=[win=36, lose=26, draw=0]}
// CPSO [win=14, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], AMPDE=[win=3, lose=28, draw=0]}
// 	 Problems:{MPBEval1900=[win=14, lose=48, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,56, Std-Dev(sigma)=1,26 RI=[15,04, 20,08]
// ACFPSO - Mean(mu)=14,61, Std-Dev(sigma)=1,18 RI=[12,25, 16,97]
// CPSO - Mean(mu)=13,92, Std-Dev(sigma)=1,18 RI=[11,56, 16,28]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,35, Std-Dev(sigma)=1,23 RI=[24,89, 29,8]
// ACFPSO - Mean(mu)=24,62, Std-Dev(sigma)=1,19 RI=[22,24, 27,01]
// CPSO - Mean(mu)=23,05, Std-Dev(sigma)=1,25 RI=[20,56, 25,55]
//
// Glicko2 rating:
// AMPDE - Rating=1.694,1 RD=64,8 ro=0,06 RI=[1564,51, 1823,74]
// ACFPSO - Rating=1.532,4 RD=64,8 ro=0,06 RI=[1402,74, 1661,97]
// CPSO - Rating=1.273,5 RD=64,8 ro=0,06 RI=[1143,9, 1403,14]
//
// Game results:
// AMPDE [win=43, lose=19, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], CPSO=[win=27, lose=4, draw=0]}
// 	 Problems:{MPBEval2000=[win=43, lose=19, draw=0]}
// ACFPSO [win=33, lose=29, draw=0]
// 	 Against:{CPSO=[win=18, lose=13, draw=0], AMPDE=[win=15, lose=16, draw=0]}
// 	 Problems:{MPBEval2000=[win=33, lose=29, draw=0]}
// CPSO [win=17, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=13, lose=18, draw=0], AMPDE=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval2000=[win=17, lose=45, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=18,03, Std-Dev(sigma)=1,3 RI=[15,43, 20,62]
// ACFPSO - Mean(mu)=14,96, Std-Dev(sigma)=1,18 RI=[12,6, 17,32]
// CPSO - Mean(mu)=13,96, Std-Dev(sigma)=1,18 RI=[11,61, 16,31]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,77, Std-Dev(sigma)=1,25 RI=[25,27, 30,27]
// ACFPSO - Mean(mu)=24,53, Std-Dev(sigma)=1,19 RI=[22,15, 26,92]
// CPSO - Mean(mu)=22,71, Std-Dev(sigma)=1,25 RI=[20,22, 25,21]
//
// Glicko2 rating:
// AMPDE - Rating=1.726,5 RD=64,8 ro=0,06 RI=[1596,86, 1856,1]
// ACFPSO - Rating=1.516,2 RD=64,8 ro=0,06 RI=[1386,56, 1645,8]
// CPSO - Rating=1.257,3 RD=64,8 ro=0,06 RI=[1127,72, 1386,96]
//
// Game results:
// AMPDE [win=45, lose=17, draw=0]
// 	 Against:{ACFPSO=[win=18, lose=13, draw=0], CPSO=[win=27, lose=4, draw=0]}
// 	 Problems:{MPBEval2100=[win=45, lose=17, draw=0]}
// ACFPSO [win=32, lose=30, draw=0]
// 	 Against:{CPSO=[win=19, lose=12, draw=0], AMPDE=[win=13, lose=18, draw=0]}
// 	 Problems:{MPBEval2100=[win=32, lose=30, draw=0]}
// CPSO [win=16, lose=46, draw=0]
// 	 Against:{ACFPSO=[win=12, lose=19, draw=0], AMPDE=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval2100=[win=16, lose=46, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=18,03, Std-Dev(sigma)=1,3 RI=[15,43, 20,62]
// ACFPSO - Mean(mu)=14,96, Std-Dev(sigma)=1,18 RI=[12,6, 17,32]
// CPSO - Mean(mu)=13,96, Std-Dev(sigma)=1,18 RI=[11,61, 16,31]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,77, Std-Dev(sigma)=1,25 RI=[25,27, 30,27]
// ACFPSO - Mean(mu)=24,53, Std-Dev(sigma)=1,19 RI=[22,15, 26,92]
// CPSO - Mean(mu)=22,71, Std-Dev(sigma)=1,25 RI=[20,22, 25,21]
//
// Glicko2 rating:
// AMPDE - Rating=1.726,5 RD=64,8 ro=0,06 RI=[1596,86, 1856,1]
// ACFPSO - Rating=1.516,2 RD=64,8 ro=0,06 RI=[1386,56, 1645,8]
// CPSO - Rating=1.257,3 RD=64,8 ro=0,06 RI=[1127,72, 1386,96]
//
// Game results:
// AMPDE [win=45, lose=17, draw=0]
// 	 Against:{ACFPSO=[win=18, lose=13, draw=0], CPSO=[win=27, lose=4, draw=0]}
// 	 Problems:{MPBEval2200=[win=45, lose=17, draw=0]}
// ACFPSO [win=32, lose=30, draw=0]
// 	 Against:{CPSO=[win=19, lose=12, draw=0], AMPDE=[win=13, lose=18, draw=0]}
// 	 Problems:{MPBEval2200=[win=32, lose=30, draw=0]}
// CPSO [win=16, lose=46, draw=0]
// 	 Against:{ACFPSO=[win=12, lose=19, draw=0], AMPDE=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval2200=[win=16, lose=46, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,29, Std-Dev(sigma)=1,27 RI=[14,76, 19,83]
// ACFPSO - Mean(mu)=13,96, Std-Dev(sigma)=1,17 RI=[11,62, 16,3]
// CPSO - Mean(mu)=13,61, Std-Dev(sigma)=1,16 RI=[11,29, 15,93]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,66, Std-Dev(sigma)=1,23 RI=[25,21, 30,11]
// ACFPSO - Mean(mu)=24,32, Std-Dev(sigma)=1,19 RI=[21,94, 26,69]
// CPSO - Mean(mu)=23,15, Std-Dev(sigma)=1,22 RI=[20,7, 25,59]
//
// Glicko2 rating:
// AMPDE - Rating=1.710,3 RD=64,8 ro=0,06 RI=[1580,68, 1839,92]
// ACFPSO - Rating=1.500 RD=64,8 ro=0,06 RI=[1370,38, 1629,62]
// CPSO - Rating=1.289,7 RD=64,8 ro=0,06 RI=[1160,08, 1419,32]
//
// Game results:
// AMPDE [win=44, lose=18, draw=0]
// 	 Against:{ACFPSO=[win=18, lose=13, draw=0], CPSO=[win=26, lose=5, draw=0]}
// 	 Problems:{MPBEval2300=[win=44, lose=18, draw=0]}
// ACFPSO [win=31, lose=31, draw=0]
// 	 Against:{CPSO=[win=18, lose=13, draw=0], AMPDE=[win=13, lose=18, draw=0]}
// 	 Problems:{MPBEval2300=[win=31, lose=31, draw=0]}
// CPSO [win=18, lose=44, draw=0]
// 	 Against:{ACFPSO=[win=13, lose=18, draw=0], AMPDE=[win=5, lose=26, draw=0]}
// 	 Problems:{MPBEval2300=[win=18, lose=44, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,73, Std-Dev(sigma)=1,23 RI=[15,26, 20,19]
// CPSO - Mean(mu)=14,25, Std-Dev(sigma)=1,13 RI=[12, 16,5]
// ACFPSO - Mean(mu)=14,17, Std-Dev(sigma)=1,14 RI=[11,9, 16,44]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,65, Std-Dev(sigma)=1,2 RI=[25,25, 30,04]
// ACFPSO - Mean(mu)=23,84, Std-Dev(sigma)=1,17 RI=[21,5, 26,18]
// CPSO - Mean(mu)=23,5, Std-Dev(sigma)=1,18 RI=[21,14, 25,85]
//
// Glicko2 rating:
// AMPDE - Rating=1.694,1 RD=64,8 ro=0,06 RI=[1564,51, 1823,74]
// ACFPSO - Rating=1.451,5 RD=64,8 ro=0,06 RI=[1321,85, 1581,09]
// CPSO - Rating=1.354,4 RD=64,8 ro=0,06 RI=[1224,79, 1484,02]
//
// Game results:
// AMPDE [win=43, lose=19, draw=0]
// 	 Against:{ACFPSO=[win=19, lose=12, draw=0], CPSO=[win=24, lose=7, draw=0]}
// 	 Problems:{MPBEval2400=[win=43, lose=19, draw=0]}
// ACFPSO [win=28, lose=34, draw=0]
// 	 Against:{CPSO=[win=16, lose=15, draw=0], AMPDE=[win=12, lose=19, draw=0]}
// 	 Problems:{MPBEval2400=[win=28, lose=34, draw=0]}
// CPSO [win=22, lose=40, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], AMPDE=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval2400=[win=22, lose=40, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,73, Std-Dev(sigma)=1,23 RI=[15,26, 20,19]
// CPSO - Mean(mu)=14,25, Std-Dev(sigma)=1,13 RI=[12, 16,5]
// ACFPSO - Mean(mu)=14,17, Std-Dev(sigma)=1,14 RI=[11,9, 16,44]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,65, Std-Dev(sigma)=1,2 RI=[25,25, 30,04]
// ACFPSO - Mean(mu)=23,84, Std-Dev(sigma)=1,17 RI=[21,5, 26,18]
// CPSO - Mean(mu)=23,5, Std-Dev(sigma)=1,18 RI=[21,14, 25,85]
//
// Glicko2 rating:
// AMPDE - Rating=1.694,1 RD=64,8 ro=0,06 RI=[1564,51, 1823,74]
// ACFPSO - Rating=1.451,5 RD=64,8 ro=0,06 RI=[1321,85, 1581,09]
// CPSO - Rating=1.354,4 RD=64,8 ro=0,06 RI=[1224,79, 1484,02]
//
// Game results:
// AMPDE [win=43, lose=19, draw=0]
// 	 Against:{ACFPSO=[win=19, lose=12, draw=0], CPSO=[win=24, lose=7, draw=0]}
// 	 Problems:{MPBEval2500=[win=43, lose=19, draw=0]}
// ACFPSO [win=28, lose=34, draw=0]
// 	 Against:{CPSO=[win=16, lose=15, draw=0], AMPDE=[win=12, lose=19, draw=0]}
// 	 Problems:{MPBEval2500=[win=28, lose=34, draw=0]}
// CPSO [win=22, lose=40, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], AMPDE=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval2500=[win=22, lose=40, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=18,13, Std-Dev(sigma)=1,27 RI=[15,59, 20,66]
// CPSO - Mean(mu)=14,37, Std-Dev(sigma)=1,13 RI=[12,11, 16,63]
// ACFPSO - Mean(mu)=14,18, Std-Dev(sigma)=1,12 RI=[11,93, 16,43]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=28,1, Std-Dev(sigma)=1,22 RI=[25,65, 30,55]
// ACFPSO - Mean(mu)=23,5, Std-Dev(sigma)=1,17 RI=[21,16, 25,84]
// CPSO - Mean(mu)=23,48, Std-Dev(sigma)=1,18 RI=[21,11, 25,84]
//
// Glicko2 rating:
// AMPDE - Rating=1.726,5 RD=64,8 ro=0,06 RI=[1596,86, 1856,1]
// ACFPSO - Rating=1.419,1 RD=64,8 ro=0,06 RI=[1289,5, 1548,73]
// CPSO - Rating=1.354,4 RD=64,8 ro=0,06 RI=[1224,79, 1484,02]
//
// Game results:
// AMPDE [win=45, lose=17, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], CPSO=[win=24, lose=7, draw=0]}
// 	 Problems:{MPBEval2600=[win=45, lose=17, draw=0]}
// ACFPSO [win=26, lose=36, draw=0]
// 	 Against:{CPSO=[win=16, lose=15, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{MPBEval2600=[win=26, lose=36, draw=0]}
// CPSO [win=22, lose=40, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], AMPDE=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval2600=[win=22, lose=40, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,87, Std-Dev(sigma)=1,25 RI=[15,38, 20,37]
// CPSO - Mean(mu)=14,66, Std-Dev(sigma)=1,13 RI=[12,4, 16,92]
// ACFPSO - Mean(mu)=14,12, Std-Dev(sigma)=1,13 RI=[11,86, 16,37]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,79, Std-Dev(sigma)=1,21 RI=[25,37, 30,21]
// CPSO - Mean(mu)=23,89, Std-Dev(sigma)=1,17 RI=[21,54, 26,23]
// ACFPSO - Mean(mu)=23,45, Std-Dev(sigma)=1,17 RI=[21,1, 25,79]
//
// Glicko2 rating:
// AMPDE - Rating=1.710,3 RD=64,8 ro=0,06 RI=[1580,68, 1839,92]
// ACFPSO - Rating=1.402,9 RD=64,8 ro=0,06 RI=[1273,32, 1532,56]
// CPSO - Rating=1.386,8 RD=64,8 ro=0,06 RI=[1257,14, 1516,38]
//
// Game results:
// AMPDE [win=44, lose=18, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], CPSO=[win=23, lose=8, draw=0]}
// 	 Problems:{MPBEval2700=[win=44, lose=18, draw=0]}
// ACFPSO [win=25, lose=37, draw=0]
// 	 Against:{CPSO=[win=15, lose=16, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{MPBEval2700=[win=25, lose=37, draw=0]}
// CPSO [win=24, lose=38, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], AMPDE=[win=8, lose=23, draw=0]}
// 	 Problems:{MPBEval2700=[win=24, lose=38, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,7, Std-Dev(sigma)=1,23 RI=[15,24, 20,16]
// CPSO - Mean(mu)=14,53, Std-Dev(sigma)=1,13 RI=[12,28, 16,78]
// ACFPSO - Mean(mu)=14,05, Std-Dev(sigma)=1,13 RI=[11,79, 16,31]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,64, Std-Dev(sigma)=1,2 RI=[25,25, 30,03]
// CPSO - Mean(mu)=23,85, Std-Dev(sigma)=1,17 RI=[21,51, 26,19]
// ACFPSO - Mean(mu)=23,57, Std-Dev(sigma)=1,17 RI=[21,23, 25,92]
//
// Glicko2 rating:
// AMPDE - Rating=1.694,1 RD=64,8 ro=0,06 RI=[1564,51, 1823,74]
// ACFPSO - Rating=1.419,1 RD=64,8 ro=0,06 RI=[1289,5, 1548,73]
// CPSO - Rating=1.386,8 RD=64,8 ro=0,06 RI=[1257,14, 1516,38]
//
// Game results:
// AMPDE [win=43, lose=19, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], CPSO=[win=23, lose=8, draw=0]}
// 	 Problems:{MPBEval2800=[win=43, lose=19, draw=0]}
// ACFPSO [win=26, lose=36, draw=0]
// 	 Against:{CPSO=[win=15, lose=16, draw=0], AMPDE=[win=11, lose=20, draw=0]}
// 	 Problems:{MPBEval2800=[win=26, lose=36, draw=0]}
// CPSO [win=24, lose=38, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], AMPDE=[win=8, lose=23, draw=0]}
// 	 Problems:{MPBEval2800=[win=24, lose=38, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=16,58, Std-Dev(sigma)=1,2 RI=[14,18, 18,99]
// CPSO - Mean(mu)=13,86, Std-Dev(sigma)=1,13 RI=[11,61, 16,12]
// ACFPSO - Mean(mu)=13,28, Std-Dev(sigma)=1,12 RI=[11,04, 15,52]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,61, Std-Dev(sigma)=1,18 RI=[25,25, 29,98]
// CPSO - Mean(mu)=24,46, Std-Dev(sigma)=1,16 RI=[22,13, 26,79]
// ACFPSO - Mean(mu)=23,91, Std-Dev(sigma)=1,17 RI=[21,58, 26,25]
//
// Glicko2 rating:
// AMPDE - Rating=1.661,8 RD=64,8 ro=0,06 RI=[1532,15, 1791,39]
// CPSO - Rating=1.435,3 RD=64,8 ro=0,06 RI=[1305,67, 1564,91]
// ACFPSO - Rating=1.402,9 RD=64,8 ro=0,06 RI=[1273,32, 1532,56]
//
// Game results:
// AMPDE [win=41, lose=21, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], CPSO=[win=21, lose=10, draw=0]}
// 	 Problems:{MPBEval2900=[win=41, lose=21, draw=0]}
// CPSO [win=27, lose=35, draw=0]
// 	 Against:{ACFPSO=[win=17, lose=14, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{MPBEval2900=[win=27, lose=35, draw=0]}
// ACFPSO [win=25, lose=37, draw=0]
// 	 Against:{CPSO=[win=14, lose=17, draw=0], AMPDE=[win=11, lose=20, draw=0]}
// 	 Problems:{MPBEval2900=[win=25, lose=37, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=16,86, Std-Dev(sigma)=1,21 RI=[14,44, 19,29]
// CPSO - Mean(mu)=14,17, Std-Dev(sigma)=1,13 RI=[11,91, 16,44]
// ACFPSO - Mean(mu)=13,4, Std-Dev(sigma)=1,14 RI=[11,13, 15,67]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,51, Std-Dev(sigma)=1,19 RI=[25,14, 29,89]
// CPSO - Mean(mu)=24,4, Std-Dev(sigma)=1,17 RI=[22,06, 26,73]
// ACFPSO - Mean(mu)=23,7, Std-Dev(sigma)=1,18 RI=[21,34, 26,05]
//
// Glicko2 rating:
// AMPDE - Rating=1.677,9 RD=64,8 ro=0,06 RI=[1548,33, 1807,57]
// CPSO - Rating=1.451,5 RD=64,8 ro=0,06 RI=[1321,85, 1581,09]
// ACFPSO - Rating=1.370,6 RD=64,8 ro=0,06 RI=[1240,96, 1500,2]
//
// Game results:
// AMPDE [win=42, lose=20, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], CPSO=[win=21, lose=10, draw=0]}
// 	 Problems:{MPBEval3000=[win=42, lose=20, draw=0]}
// CPSO [win=28, lose=34, draw=0]
// 	 Against:{ACFPSO=[win=18, lose=13, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{MPBEval3000=[win=28, lose=34, draw=0]}
// ACFPSO [win=23, lose=39, draw=0]
// 	 Against:{CPSO=[win=13, lose=18, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{MPBEval3000=[win=23, lose=39, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17, Std-Dev(sigma)=1,22 RI=[14,57, 19,43]
// CPSO - Mean(mu)=14,52, Std-Dev(sigma)=1,14 RI=[12,24, 16,79]
// ACFPSO - Mean(mu)=13,04, Std-Dev(sigma)=1,13 RI=[10,78, 15,3]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,62, Std-Dev(sigma)=1,19 RI=[25,25, 30]
// CPSO - Mean(mu)=24,78, Std-Dev(sigma)=1,16 RI=[22,45, 27,11]
// ACFPSO - Mean(mu)=23,14, Std-Dev(sigma)=1,18 RI=[20,77, 25,51]
//
// Glicko2 rating:
// AMPDE - Rating=1.677,9 RD=64,8 ro=0,06 RI=[1548,33, 1807,57]
// CPSO - Rating=1.483,8 RD=64,8 ro=0,06 RI=[1354,2, 1613,44]
// ACFPSO - Rating=1.338,2 RD=64,8 ro=0,06 RI=[1208,61, 1467,85]
//
// Game results:
// AMPDE [win=42, lose=20, draw=0]
// 	 Against:{ACFPSO=[win=22, lose=9, draw=0], CPSO=[win=20, lose=11, draw=0]}
// 	 Problems:{MPBEval3100=[win=42, lose=20, draw=0]}
// CPSO [win=30, lose=32, draw=0]
// 	 Against:{ACFPSO=[win=19, lose=12, draw=0], AMPDE=[win=11, lose=20, draw=0]}
// 	 Problems:{MPBEval3100=[win=30, lose=32, draw=0]}
// ACFPSO [win=21, lose=41, draw=0]
// 	 Against:{CPSO=[win=12, lose=19, draw=0], AMPDE=[win=9, lose=22, draw=0]}
// 	 Problems:{MPBEval3100=[win=21, lose=41, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=18,23, Std-Dev(sigma)=1,22 RI=[15,79, 20,66]
// CPSO - Mean(mu)=16,47, Std-Dev(sigma)=1,15 RI=[14,16, 18,78]
// ACFPSO - Mean(mu)=14,16, Std-Dev(sigma)=1,14 RI=[11,88, 16,45]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=26,94, Std-Dev(sigma)=1,2 RI=[24,55, 29,33]
// CPSO - Mean(mu)=24,85, Std-Dev(sigma)=1,17 RI=[22,51, 27,2]
// ACFPSO - Mean(mu)=22,31, Std-Dev(sigma)=1,2 RI=[19,9, 24,71]
//
// Glicko2 rating:
// AMPDE - Rating=1.677,9 RD=64,8 ro=0,06 RI=[1548,33, 1807,57]
// CPSO - Rating=1.516,2 RD=64,8 ro=0,06 RI=[1386,56, 1645,8]
// ACFPSO - Rating=1.305,9 RD=64,8 ro=0,06 RI=[1176,26, 1435,49]
//
// Game results:
// AMPDE [win=42, lose=20, draw=0]
// 	 Against:{ACFPSO=[win=23, lose=8, draw=0], CPSO=[win=19, lose=12, draw=0]}
// 	 Problems:{MPBEval3200=[win=42, lose=20, draw=0]}
// CPSO [win=32, lose=30, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], AMPDE=[win=12, lose=19, draw=0]}
// 	 Problems:{MPBEval3200=[win=32, lose=30, draw=0]}
// ACFPSO [win=19, lose=43, draw=0]
// 	 Against:{CPSO=[win=11, lose=20, draw=0], AMPDE=[win=8, lose=23, draw=0]}
// 	 Problems:{MPBEval3200=[win=19, lose=43, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,97, Std-Dev(sigma)=1,2 RI=[15,56, 20,38]
// CPSO - Mean(mu)=16,6, Std-Dev(sigma)=1,16 RI=[14,28, 18,93]
// ACFPSO - Mean(mu)=14,15, Std-Dev(sigma)=1,14 RI=[11,87, 16,43]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=26,61, Std-Dev(sigma)=1,19 RI=[24,23, 28,98]
// CPSO - Mean(mu)=25,16, Std-Dev(sigma)=1,17 RI=[22,81, 27,51]
// ACFPSO - Mean(mu)=22,33, Std-Dev(sigma)=1,2 RI=[19,92, 24,73]
//
// Glicko2 rating:
// AMPDE - Rating=1.661,8 RD=64,8 ro=0,06 RI=[1532,15, 1791,39]
// CPSO - Rating=1.532,4 RD=64,8 ro=0,06 RI=[1402,74, 1661,97]
// ACFPSO - Rating=1.305,9 RD=64,8 ro=0,06 RI=[1176,26, 1435,49]
//
// Game results:
// AMPDE [win=41, lose=21, draw=0]
// 	 Against:{ACFPSO=[win=23, lose=8, draw=0], CPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{MPBEval3300=[win=41, lose=21, draw=0]}
// CPSO [win=33, lose=29, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], AMPDE=[win=13, lose=18, draw=0]}
// 	 Problems:{MPBEval3300=[win=33, lose=29, draw=0]}
// ACFPSO [win=19, lose=43, draw=0]
// 	 Against:{CPSO=[win=11, lose=20, draw=0], AMPDE=[win=8, lose=23, draw=0]}
// 	 Problems:{MPBEval3300=[win=19, lose=43, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=18,22, Std-Dev(sigma)=1,22 RI=[15,78, 20,65]
// CPSO - Mean(mu)=16,73, Std-Dev(sigma)=1,17 RI=[14,4, 19,06]
// ACFPSO - Mean(mu)=14,25, Std-Dev(sigma)=1,14 RI=[11,97, 16,53]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=26,77, Std-Dev(sigma)=1,2 RI=[24,37, 29,17]
// CPSO - Mean(mu)=25,16, Std-Dev(sigma)=1,18 RI=[22,81, 27,52]
// ACFPSO - Mean(mu)=22,19, Std-Dev(sigma)=1,21 RI=[19,77, 24,6]
//
// Glicko2 rating:
// AMPDE - Rating=1.677,9 RD=64,8 ro=0,06 RI=[1548,33, 1807,57]
// CPSO - Rating=1.532,4 RD=64,8 ro=0,06 RI=[1402,74, 1661,97]
// ACFPSO - Rating=1.289,7 RD=64,8 ro=0,06 RI=[1160,08, 1419,32]
//
// Game results:
// AMPDE [win=42, lose=20, draw=0]
// 	 Against:{ACFPSO=[win=24, lose=7, draw=0], CPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{MPBEval3400=[win=42, lose=20, draw=0]}
// CPSO [win=33, lose=29, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], AMPDE=[win=13, lose=18, draw=0]}
// 	 Problems:{MPBEval3400=[win=33, lose=29, draw=0]}
// ACFPSO [win=18, lose=44, draw=0]
// 	 Against:{CPSO=[win=11, lose=20, draw=0], AMPDE=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval3400=[win=18, lose=44, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=16,65, Std-Dev(sigma)=1,2 RI=[14,24, 19,05]
// CPSO - Mean(mu)=15,17, Std-Dev(sigma)=1,16 RI=[12,86, 17,49]
// ACFPSO - Mean(mu)=12,73, Std-Dev(sigma)=1,13 RI=[10,46, 14,99]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,18, Std-Dev(sigma)=1,18 RI=[24,82, 29,55]
// CPSO - Mean(mu)=25,64, Std-Dev(sigma)=1,17 RI=[23,31, 27,98]
// ACFPSO - Mean(mu)=22,72, Std-Dev(sigma)=1,19 RI=[20,34, 25,11]
//
// Glicko2 rating:
// AMPDE - Rating=1.661,8 RD=64,8 ro=0,06 RI=[1532,15, 1791,39]
// CPSO - Rating=1.532,4 RD=64,8 ro=0,06 RI=[1402,74, 1661,97]
// ACFPSO - Rating=1.305,9 RD=64,8 ro=0,06 RI=[1176,26, 1435,49]
//
// Game results:
// AMPDE [win=41, lose=21, draw=0]
// 	 Against:{ACFPSO=[win=23, lose=8, draw=0], CPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{MPBEval3500=[win=41, lose=21, draw=0]}
// CPSO [win=33, lose=29, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], AMPDE=[win=13, lose=18, draw=0]}
// 	 Problems:{MPBEval3500=[win=33, lose=29, draw=0]}
// ACFPSO [win=19, lose=43, draw=0]
// 	 Against:{CPSO=[win=11, lose=20, draw=0], AMPDE=[win=8, lose=23, draw=0]}
// 	 Problems:{MPBEval3500=[win=19, lose=43, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=18,7, Std-Dev(sigma)=1,25 RI=[16,21, 21,19]
// CPSO - Mean(mu)=16,29, Std-Dev(sigma)=1,17 RI=[13,96, 18,62]
// ACFPSO - Mean(mu)=14,27, Std-Dev(sigma)=1,15 RI=[11,98, 16,57]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,22, Std-Dev(sigma)=1,21 RI=[24,79, 29,65]
// CPSO - Mean(mu)=24,69, Std-Dev(sigma)=1,18 RI=[22,32, 27,05]
// ACFPSO - Mean(mu)=22,24, Std-Dev(sigma)=1,21 RI=[19,82, 24,66]
//
// Glicko2 rating:
// AMPDE - Rating=1.710,3 RD=64,8 ro=0,06 RI=[1580,68, 1839,92]
// CPSO - Rating=1.500 RD=64,8 ro=0,06 RI=[1370,38, 1629,62]
// ACFPSO - Rating=1.289,7 RD=64,8 ro=0,06 RI=[1160,08, 1419,32]
//
// Game results:
// AMPDE [win=44, lose=18, draw=0]
// 	 Against:{ACFPSO=[win=24, lose=7, draw=0], CPSO=[win=20, lose=11, draw=0]}
// 	 Problems:{MPBEval3600=[win=44, lose=18, draw=0]}
// CPSO [win=31, lose=31, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], AMPDE=[win=11, lose=20, draw=0]}
// 	 Problems:{MPBEval3600=[win=31, lose=31, draw=0]}
// ACFPSO [win=18, lose=44, draw=0]
// 	 Against:{CPSO=[win=11, lose=20, draw=0], AMPDE=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval3600=[win=18, lose=44, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=16,36, Std-Dev(sigma)=1,19 RI=[13,97, 18,75]
// CPSO - Mean(mu)=14,85, Std-Dev(sigma)=1,15 RI=[12,54, 17,16]
// ACFPSO - Mean(mu)=13,08, Std-Dev(sigma)=1,12 RI=[10,84, 15,31]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,01, Std-Dev(sigma)=1,18 RI=[24,65, 29,37]
// CPSO - Mean(mu)=25,45, Std-Dev(sigma)=1,17 RI=[23,11, 27,79]
// ACFPSO - Mean(mu)=23,2, Std-Dev(sigma)=1,17 RI=[20,85, 25,55]
//
// Glicko2 rating:
// AMPDE - Rating=1.645,6 RD=64,8 ro=0,06 RI=[1515,98, 1775,21]
// CPSO - Rating=1.516,2 RD=64,8 ro=0,06 RI=[1386,56, 1645,8]
// ACFPSO - Rating=1.338,2 RD=64,8 ro=0,06 RI=[1208,61, 1467,85]
//
// Game results:
// AMPDE [win=40, lose=22, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], CPSO=[win=19, lose=12, draw=0]}
// 	 Problems:{MPBEval3700=[win=40, lose=22, draw=0]}
// CPSO [win=32, lose=30, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], AMPDE=[win=12, lose=19, draw=0]}
// 	 Problems:{MPBEval3700=[win=32, lose=30, draw=0]}
// ACFPSO [win=21, lose=41, draw=0]
// 	 Against:{CPSO=[win=11, lose=20, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{MPBEval3700=[win=21, lose=41, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=16,3, Std-Dev(sigma)=1,2 RI=[13,91, 18,7]
// CPSO - Mean(mu)=15,22, Std-Dev(sigma)=1,16 RI=[12,91, 17,54]
// ACFPSO - Mean(mu)=12,71, Std-Dev(sigma)=1,12 RI=[10,47, 14,96]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,04, Std-Dev(sigma)=1,18 RI=[24,68, 29,4]
// CPSO - Mean(mu)=25,76, Std-Dev(sigma)=1,17 RI=[23,43, 28,1]
// ACFPSO - Mean(mu)=22,87, Std-Dev(sigma)=1,18 RI=[20,5, 25,23]
//
// Glicko2 rating:
// AMPDE - Rating=1.645,6 RD=64,8 ro=0,06 RI=[1515,98, 1775,21]
// CPSO - Rating=1.532,4 RD=64,8 ro=0,06 RI=[1402,74, 1661,97]
// ACFPSO - Rating=1.322,1 RD=64,8 ro=0,06 RI=[1192,43, 1451,67]
//
// Game results:
// AMPDE [win=40, lose=22, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], CPSO=[win=19, lose=12, draw=0]}
// 	 Problems:{MPBEval3800=[win=40, lose=22, draw=0]}
// CPSO [win=33, lose=29, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], AMPDE=[win=12, lose=19, draw=0]}
// 	 Problems:{MPBEval3800=[win=33, lose=29, draw=0]}
// ACFPSO [win=20, lose=42, draw=0]
// 	 Against:{CPSO=[win=10, lose=21, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{MPBEval3800=[win=20, lose=42, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,87, Std-Dev(sigma)=1,21 RI=[15,45, 20,29]
// CPSO - Mean(mu)=16,79, Std-Dev(sigma)=1,16 RI=[14,46, 19,12]
// ACFPSO - Mean(mu)=14,24, Std-Dev(sigma)=1,13 RI=[11,98, 16,49]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=26,55, Std-Dev(sigma)=1,2 RI=[24,16, 28,94]
// CPSO - Mean(mu)=25,21, Std-Dev(sigma)=1,18 RI=[22,86, 27,56]
// ACFPSO - Mean(mu)=22,26, Std-Dev(sigma)=1,19 RI=[19,88, 24,64]
//
// Glicko2 rating:
// AMPDE - Rating=1.661,8 RD=64,8 ro=0,06 RI=[1532,15, 1791,39]
// CPSO - Rating=1.532,4 RD=64,8 ro=0,06 RI=[1402,74, 1661,97]
// ACFPSO - Rating=1.305,9 RD=64,8 ro=0,06 RI=[1176,26, 1435,49]
//
// Game results:
// AMPDE [win=41, lose=21, draw=0]
// 	 Against:{ACFPSO=[win=22, lose=9, draw=0], CPSO=[win=19, lose=12, draw=0]}
// 	 Problems:{MPBEval3900=[win=41, lose=21, draw=0]}
// CPSO [win=33, lose=29, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], AMPDE=[win=12, lose=19, draw=0]}
// 	 Problems:{MPBEval3900=[win=33, lose=29, draw=0]}
// ACFPSO [win=19, lose=43, draw=0]
// 	 Against:{CPSO=[win=10, lose=21, draw=0], AMPDE=[win=9, lose=22, draw=0]}
// 	 Problems:{MPBEval3900=[win=19, lose=43, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=16,85, Std-Dev(sigma)=1,22 RI=[14,41, 19,29]
// CPSO - Mean(mu)=15,82, Std-Dev(sigma)=1,18 RI=[13,46, 18,18]
// ACFPSO - Mean(mu)=13,14, Std-Dev(sigma)=1,14 RI=[10,85, 15,43]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,19, Std-Dev(sigma)=1,19 RI=[24,8, 29,57]
// CPSO - Mean(mu)=25,99, Std-Dev(sigma)=1,19 RI=[23,62, 28,36]
// ACFPSO - Mean(mu)=22,88, Std-Dev(sigma)=1,21 RI=[20,46, 25,31]
//
// Glicko2 rating:
// AMPDE - Rating=1.645,6 RD=64,8 ro=0,06 RI=[1515,98, 1775,21]
// CPSO - Rating=1.564,7 RD=64,8 ro=0,06 RI=[1435,09, 1694,33]
// ACFPSO - Rating=1.289,7 RD=64,8 ro=0,06 RI=[1160,08, 1419,32]
//
// Game results:
// AMPDE [win=40, lose=22, draw=0]
// 	 Against:{ACFPSO=[win=22, lose=9, draw=0], CPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{MPBEval4000=[win=40, lose=22, draw=0]}
// CPSO [win=35, lose=27, draw=0]
// 	 Against:{ACFPSO=[win=22, lose=9, draw=0], AMPDE=[win=13, lose=18, draw=0]}
// 	 Problems:{MPBEval4000=[win=35, lose=27, draw=0]}
// ACFPSO [win=18, lose=44, draw=0]
// 	 Against:{CPSO=[win=9, lose=22, draw=0], AMPDE=[win=9, lose=22, draw=0]}
// 	 Problems:{MPBEval4000=[win=18, lose=44, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,09, Std-Dev(sigma)=1,24 RI=[14,61, 19,56]
// CPSO - Mean(mu)=15,59, Std-Dev(sigma)=1,18 RI=[13,24, 17,95]
// ACFPSO - Mean(mu)=13,36, Std-Dev(sigma)=1,15 RI=[11,06, 15,65]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,4, Std-Dev(sigma)=1,21 RI=[24,99, 29,82]
// CPSO - Mean(mu)=25,8, Std-Dev(sigma)=1,19 RI=[23,43, 28,18]
// ACFPSO - Mean(mu)=22,87, Std-Dev(sigma)=1,22 RI=[20,43, 25,31]
//
// Glicko2 rating:
// AMPDE - Rating=1.661,8 RD=64,8 ro=0,06 RI=[1532,15, 1791,39]
// CPSO - Rating=1.564,7 RD=64,8 ro=0,06 RI=[1435,09, 1694,33]
// ACFPSO - Rating=1.273,5 RD=64,8 ro=0,06 RI=[1143,9, 1403,14]
//
// Game results:
// AMPDE [win=41, lose=21, draw=0]
// 	 Against:{ACFPSO=[win=24, lose=7, draw=0], CPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{MPBEval4100=[win=41, lose=21, draw=0]}
// CPSO [win=35, lose=27, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], AMPDE=[win=14, lose=17, draw=0]}
// 	 Problems:{MPBEval4100=[win=35, lose=27, draw=0]}
// ACFPSO [win=17, lose=45, draw=0]
// 	 Against:{CPSO=[win=10, lose=21, draw=0], AMPDE=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval4100=[win=17, lose=45, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=16,76, Std-Dev(sigma)=1,21 RI=[14,33, 19,18]
// CPSO - Mean(mu)=15,82, Std-Dev(sigma)=1,18 RI=[13,45, 18,18]
// ACFPSO - Mean(mu)=13,54, Std-Dev(sigma)=1,13 RI=[11,28, 15,8]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=26,99, Std-Dev(sigma)=1,19 RI=[24,6, 29,37]
// CPSO - Mean(mu)=26,05, Std-Dev(sigma)=1,19 RI=[23,67, 28,43]
// ACFPSO - Mean(mu)=23,04, Std-Dev(sigma)=1,2 RI=[20,64, 25,45]
//
// Glicko2 rating:
// AMPDE - Rating=1.629,4 RD=64,8 ro=0,06 RI=[1499,8, 1759,04]
// CPSO - Rating=1.580,9 RD=64,8 ro=0,06 RI=[1451,27, 1710,5]
// ACFPSO - Rating=1.289,7 RD=64,8 ro=0,06 RI=[1160,08, 1419,32]
//
// Game results:
// AMPDE [win=39, lose=23, draw=0]
// 	 Against:{ACFPSO=[win=23, lose=8, draw=0], CPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{MPBEval4200=[win=39, lose=23, draw=0]}
// CPSO [win=36, lose=26, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], AMPDE=[win=15, lose=16, draw=0]}
// 	 Problems:{MPBEval4200=[win=36, lose=26, draw=0]}
// ACFPSO [win=18, lose=44, draw=0]
// 	 Against:{CPSO=[win=10, lose=21, draw=0], AMPDE=[win=8, lose=23, draw=0]}
// 	 Problems:{MPBEval4200=[win=18, lose=44, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=16,76, Std-Dev(sigma)=1,21 RI=[14,33, 19,18]
// CPSO - Mean(mu)=15,82, Std-Dev(sigma)=1,18 RI=[13,45, 18,18]
// ACFPSO - Mean(mu)=13,54, Std-Dev(sigma)=1,13 RI=[11,28, 15,8]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=26,99, Std-Dev(sigma)=1,19 RI=[24,6, 29,37]
// CPSO - Mean(mu)=26,05, Std-Dev(sigma)=1,19 RI=[23,67, 28,43]
// ACFPSO - Mean(mu)=23,04, Std-Dev(sigma)=1,2 RI=[20,64, 25,45]
//
// Glicko2 rating:
// AMPDE - Rating=1.629,4 RD=64,8 ro=0,06 RI=[1499,8, 1759,04]
// CPSO - Rating=1.580,9 RD=64,8 ro=0,06 RI=[1451,27, 1710,5]
// ACFPSO - Rating=1.289,7 RD=64,8 ro=0,06 RI=[1160,08, 1419,32]
//
// Game results:
// AMPDE [win=39, lose=23, draw=0]
// 	 Against:{ACFPSO=[win=23, lose=8, draw=0], CPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{MPBEval4300=[win=39, lose=23, draw=0]}
// CPSO [win=36, lose=26, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], AMPDE=[win=15, lose=16, draw=0]}
// ...
// AMPDE [win=34, lose=28, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], CPSO=[win=23, lose=8, draw=0]}
// 	 Problems:{MPBEval7300=[win=34, lose=28, draw=0]}
// CPSO [win=17, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=9, lose=22, draw=0], AMPDE=[win=8, lose=23, draw=0]}
// 	 Problems:{MPBEval7300=[win=17, lose=45, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=16,31, Std-Dev(sigma)=1,22 RI=[13,87, 18,75]
// AMPDE - Mean(mu)=15,62, Std-Dev(sigma)=1,17 RI=[13,27, 17,96]
// CPSO - Mean(mu)=11,53, Std-Dev(sigma)=1,15 RI=[9,24, 13,82]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=27,4, Std-Dev(sigma)=1,18 RI=[25,03, 29,76]
// AMPDE - Mean(mu)=26,13, Std-Dev(sigma)=1,17 RI=[23,79, 28,47]
// CPSO - Mean(mu)=21,53, Std-Dev(sigma)=1,22 RI=[19,08, 23,98]
//
// Glicko2 rating:
// ACFPSO - Rating=1.661,8 RD=64,8 ro=0,06 RI=[1532,15, 1791,39]
// AMPDE - Rating=1.564,7 RD=64,8 ro=0,06 RI=[1435,09, 1694,33]
// CPSO - Rating=1.273,5 RD=64,8 ro=0,06 RI=[1143,9, 1403,14]
//
// Game results:
// ACFPSO [win=41, lose=21, draw=0]
// 	 Against:{CPSO=[win=22, lose=9, draw=0], AMPDE=[win=19, lose=12, draw=0]}
// 	 Problems:{MPBEval7400=[win=41, lose=21, draw=0]}
// AMPDE [win=35, lose=27, draw=0]
// 	 Against:{ACFPSO=[win=12, lose=19, draw=0], CPSO=[win=23, lose=8, draw=0]}
// 	 Problems:{MPBEval7400=[win=35, lose=27, draw=0]}
// CPSO [win=17, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=9, lose=22, draw=0], AMPDE=[win=8, lose=23, draw=0]}
// 	 Problems:{MPBEval7400=[win=17, lose=45, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=16,48, Std-Dev(sigma)=1,24 RI=[14,01, 18,95]
// AMPDE - Mean(mu)=15,59, Std-Dev(sigma)=1,17 RI=[13,26, 17,92]
// CPSO - Mean(mu)=11,57, Std-Dev(sigma)=1,15 RI=[9,27, 13,86]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=27,58, Std-Dev(sigma)=1,19 RI=[25,19, 29,97]
// AMPDE - Mean(mu)=25,96, Std-Dev(sigma)=1,17 RI=[23,62, 28,3]
// CPSO - Mean(mu)=21,51, Std-Dev(sigma)=1,22 RI=[19,06, 23,95]
//
// Glicko2 rating:
// ACFPSO - Rating=1.677,9 RD=64,8 ro=0,06 RI=[1548,33, 1807,57]
// AMPDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.273,5 RD=64,8 ro=0,06 RI=[1143,9, 1403,14]
//
// Game results:
// ACFPSO [win=42, lose=20, draw=0]
// 	 Against:{CPSO=[win=22, lose=9, draw=0], AMPDE=[win=20, lose=11, draw=0]}
// 	 Problems:{MPBEval7500=[win=42, lose=20, draw=0]}
// AMPDE [win=34, lose=28, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], CPSO=[win=23, lose=8, draw=0]}
// 	 Problems:{MPBEval7500=[win=34, lose=28, draw=0]}
// CPSO [win=17, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=9, lose=22, draw=0], AMPDE=[win=8, lose=23, draw=0]}
// 	 Problems:{MPBEval7500=[win=17, lose=45, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=16,48, Std-Dev(sigma)=1,24 RI=[14,01, 18,95]
// AMPDE - Mean(mu)=15,59, Std-Dev(sigma)=1,17 RI=[13,26, 17,92]
// CPSO - Mean(mu)=11,57, Std-Dev(sigma)=1,15 RI=[9,27, 13,86]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=27,58, Std-Dev(sigma)=1,19 RI=[25,19, 29,97]
// AMPDE - Mean(mu)=25,96, Std-Dev(sigma)=1,17 RI=[23,62, 28,3]
// CPSO - Mean(mu)=21,51, Std-Dev(sigma)=1,22 RI=[19,06, 23,95]
//
// Glicko2 rating:
// ACFPSO - Rating=1.677,9 RD=64,8 ro=0,06 RI=[1548,33, 1807,57]
// AMPDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.273,5 RD=64,8 ro=0,06 RI=[1143,9, 1403,14]
//
// Game results:
// ACFPSO [win=42, lose=20, draw=0]
// 	 Against:{CPSO=[win=22, lose=9, draw=0], AMPDE=[win=20, lose=11, draw=0]}
// 	 Problems:{MPBEval7600=[win=42, lose=20, draw=0]}
// AMPDE [win=34, lose=28, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], CPSO=[win=23, lose=8, draw=0]}
// 	 Problems:{MPBEval7600=[win=34, lose=28, draw=0]}
// CPSO [win=17, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=9, lose=22, draw=0], AMPDE=[win=8, lose=23, draw=0]}
// 	 Problems:{MPBEval7600=[win=17, lose=45, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=16,31, Std-Dev(sigma)=1,22 RI=[13,87, 18,75]
// AMPDE - Mean(mu)=15,62, Std-Dev(sigma)=1,17 RI=[13,27, 17,96]
// CPSO - Mean(mu)=11,53, Std-Dev(sigma)=1,15 RI=[9,24, 13,82]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=27,4, Std-Dev(sigma)=1,18 RI=[25,03, 29,76]
// AMPDE - Mean(mu)=26,13, Std-Dev(sigma)=1,17 RI=[23,79, 28,47]
// CPSO - Mean(mu)=21,53, Std-Dev(sigma)=1,22 RI=[19,08, 23,98]
//
// Glicko2 rating:
// ACFPSO - Rating=1.661,8 RD=64,8 ro=0,06 RI=[1532,15, 1791,39]
// AMPDE - Rating=1.564,7 RD=64,8 ro=0,06 RI=[1435,09, 1694,33]
// CPSO - Rating=1.273,5 RD=64,8 ro=0,06 RI=[1143,9, 1403,14]
//
// Game results:
// ACFPSO [win=41, lose=21, draw=0]
// 	 Against:{CPSO=[win=22, lose=9, draw=0], AMPDE=[win=19, lose=12, draw=0]}
// 	 Problems:{MPBEval7700=[win=41, lose=21, draw=0]}
// AMPDE [win=35, lose=27, draw=0]
// 	 Against:{ACFPSO=[win=12, lose=19, draw=0], CPSO=[win=23, lose=8, draw=0]}
// 	 Problems:{MPBEval7700=[win=35, lose=27, draw=0]}
// CPSO [win=17, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=9, lose=22, draw=0], AMPDE=[win=8, lose=23, draw=0]}
// 	 Problems:{MPBEval7700=[win=17, lose=45, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=16,89, Std-Dev(sigma)=1,28 RI=[14,34, 19,45]
// AMPDE - Mean(mu)=15,51, Std-Dev(sigma)=1,17 RI=[13,16, 17,85]
// CPSO - Mean(mu)=10,94, Std-Dev(sigma)=1,18 RI=[8,57, 13,3]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=28,21, Std-Dev(sigma)=1,21 RI=[25,8, 30,63]
// AMPDE - Mean(mu)=25,86, Std-Dev(sigma)=1,17 RI=[23,51, 28,2]
// CPSO - Mean(mu)=20,89, Std-Dev(sigma)=1,26 RI=[18,37, 23,41]
//
// Glicko2 rating:
// ACFPSO - Rating=1.710,3 RD=64,8 ro=0,06 RI=[1580,68, 1839,92]
// AMPDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.241,2 RD=64,8 ro=0,06 RI=[1111,55, 1370,78]
//
// Game results:
// ACFPSO [win=44, lose=18, draw=0]
// 	 Against:{CPSO=[win=23, lose=8, draw=0], AMPDE=[win=21, lose=10, draw=0]}
// 	 Problems:{MPBEval7800=[win=44, lose=18, draw=0]}
// AMPDE [win=34, lose=28, draw=0]
// 	 Against:{ACFPSO=[win=10, lose=21, draw=0], CPSO=[win=24, lose=7, draw=0]}
// 	 Problems:{MPBEval7800=[win=34, lose=28, draw=0]}
// CPSO [win=15, lose=47, draw=0]
// 	 Against:{ACFPSO=[win=8, lose=23, draw=0], AMPDE=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval7800=[win=15, lose=47, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=17,52, Std-Dev(sigma)=1,32 RI=[14,88, 20,17]
// AMPDE - Mean(mu)=15,62, Std-Dev(sigma)=1,17 RI=[13,28, 17,97]
// CPSO - Mean(mu)=11,03, Std-Dev(sigma)=1,18 RI=[8,66, 13,4]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=28,74, Std-Dev(sigma)=1,24 RI=[26,25, 31,22]
// AMPDE - Mean(mu)=25,68, Std-Dev(sigma)=1,18 RI=[23,32, 28,03]
// CPSO - Mean(mu)=20,57, Std-Dev(sigma)=1,27 RI=[18,03, 23,11]
//
// Glicko2 rating:
// ACFPSO - Rating=1.742,7 RD=64,8 ro=0,06 RI=[1613,04, 1872,28]
// AMPDE - Rating=1.532,4 RD=64,8 ro=0,06 RI=[1402,74, 1661,97]
// CPSO - Rating=1.225 RD=64,8 ro=0,06 RI=[1095,37, 1354,61]
//
// Game results:
// ACFPSO [win=46, lose=16, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=22, lose=9, draw=0]}
// 	 Problems:{MPBEval7900=[win=46, lose=16, draw=0]}
// AMPDE [win=33, lose=29, draw=0]
// 	 Against:{ACFPSO=[win=9, lose=22, draw=0], CPSO=[win=24, lose=7, draw=0]}
// 	 Problems:{MPBEval7900=[win=33, lose=29, draw=0]}
// CPSO [win=14, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=7, lose=24, draw=0], AMPDE=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval7900=[win=14, lose=48, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=17,27, Std-Dev(sigma)=1,3 RI=[14,66, 19,87]
// AMPDE - Mean(mu)=15,61, Std-Dev(sigma)=1,18 RI=[13,25, 17,96]
// CPSO - Mean(mu)=10,95, Std-Dev(sigma)=1,18 RI=[8,59, 13,31]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=28,55, Std-Dev(sigma)=1,23 RI=[26,1, 31]
// AMPDE - Mean(mu)=25,81, Std-Dev(sigma)=1,18 RI=[23,46, 28,17]
// CPSO - Mean(mu)=20,61, Std-Dev(sigma)=1,27 RI=[18,07, 23,15]
//
// Glicko2 rating:
// ACFPSO - Rating=1.726,5 RD=64,8 ro=0,06 RI=[1596,86, 1856,1]
// AMPDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.225 RD=64,8 ro=0,06 RI=[1095,37, 1354,61]
//
// Game results:
// ACFPSO [win=45, lose=17, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=21, lose=10, draw=0]}
// 	 Problems:{MPBEval8000=[win=45, lose=17, draw=0]}
// AMPDE [win=34, lose=28, draw=0]
// 	 Against:{ACFPSO=[win=10, lose=21, draw=0], CPSO=[win=24, lose=7, draw=0]}
// 	 Problems:{MPBEval8000=[win=34, lose=28, draw=0]}
// CPSO [win=14, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=7, lose=24, draw=0], AMPDE=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval8000=[win=14, lose=48, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=17,27, Std-Dev(sigma)=1,3 RI=[14,66, 19,87]
// AMPDE - Mean(mu)=15,61, Std-Dev(sigma)=1,18 RI=[13,25, 17,96]
// CPSO - Mean(mu)=10,95, Std-Dev(sigma)=1,18 RI=[8,59, 13,31]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=28,55, Std-Dev(sigma)=1,23 RI=[26,1, 31]
// AMPDE - Mean(mu)=25,81, Std-Dev(sigma)=1,18 RI=[23,46, 28,17]
// CPSO - Mean(mu)=20,61, Std-Dev(sigma)=1,27 RI=[18,07, 23,15]
//
// Glicko2 rating:
// ACFPSO - Rating=1.726,5 RD=64,8 ro=0,06 RI=[1596,86, 1856,1]
// AMPDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.225 RD=64,8 ro=0,06 RI=[1095,37, 1354,61]
//
// Game results:
// ACFPSO [win=45, lose=17, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=21, lose=10, draw=0]}
// 	 Problems:{MPBEval8100=[win=45, lose=17, draw=0]}
// AMPDE [win=34, lose=28, draw=0]
// 	 Against:{ACFPSO=[win=10, lose=21, draw=0], CPSO=[win=24, lose=7, draw=0]}
// 	 Problems:{MPBEval8100=[win=34, lose=28, draw=0]}
// CPSO [win=14, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=7, lose=24, draw=0], AMPDE=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval8100=[win=14, lose=48, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=17,27, Std-Dev(sigma)=1,3 RI=[14,66, 19,87]
// AMPDE - Mean(mu)=15,61, Std-Dev(sigma)=1,18 RI=[13,25, 17,96]
// CPSO - Mean(mu)=10,95, Std-Dev(sigma)=1,18 RI=[8,59, 13,31]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=28,55, Std-Dev(sigma)=1,23 RI=[26,1, 31]
// AMPDE - Mean(mu)=25,81, Std-Dev(sigma)=1,18 RI=[23,46, 28,17]
// CPSO - Mean(mu)=20,61, Std-Dev(sigma)=1,27 RI=[18,07, 23,15]
//
// Glicko2 rating:
// ACFPSO - Rating=1.726,5 RD=64,8 ro=0,06 RI=[1596,86, 1856,1]
// AMPDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.225 RD=64,8 ro=0,06 RI=[1095,37, 1354,61]
//
// Game results:
// ACFPSO [win=45, lose=17, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=21, lose=10, draw=0]}
// 	 Problems:{MPBEval8200=[win=45, lose=17, draw=0]}
// AMPDE [win=34, lose=28, draw=0]
// 	 Against:{ACFPSO=[win=10, lose=21, draw=0], CPSO=[win=24, lose=7, draw=0]}
// 	 Problems:{MPBEval8200=[win=34, lose=28, draw=0]}
// CPSO [win=14, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=7, lose=24, draw=0], AMPDE=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval8200=[win=14, lose=48, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=17,27, Std-Dev(sigma)=1,3 RI=[14,66, 19,87]
// AMPDE - Mean(mu)=15,61, Std-Dev(sigma)=1,18 RI=[13,25, 17,96]
// CPSO - Mean(mu)=10,95, Std-Dev(sigma)=1,18 RI=[8,59, 13,31]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=28,55, Std-Dev(sigma)=1,23 RI=[26,1, 31]
// AMPDE - Mean(mu)=25,81, Std-Dev(sigma)=1,18 RI=[23,46, 28,17]
// CPSO - Mean(mu)=20,61, Std-Dev(sigma)=1,27 RI=[18,07, 23,15]
//
// Glicko2 rating:
// ACFPSO - Rating=1.726,5 RD=64,8 ro=0,06 RI=[1596,86, 1856,1]
// AMPDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.225 RD=64,8 ro=0,06 RI=[1095,37, 1354,61]
//
// Game results:
// ACFPSO [win=45, lose=17, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=21, lose=10, draw=0]}
// 	 Problems:{MPBEval8300=[win=45, lose=17, draw=0]}
// AMPDE [win=34, lose=28, draw=0]
// 	 Against:{ACFPSO=[win=10, lose=21, draw=0], CPSO=[win=24, lose=7, draw=0]}
// 	 Problems:{MPBEval8300=[win=34, lose=28, draw=0]}
// CPSO [win=14, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=7, lose=24, draw=0], AMPDE=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval8300=[win=14, lose=48, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=17, Std-Dev(sigma)=1,28 RI=[14,44, 19,57]
// AMPDE - Mean(mu)=15,73, Std-Dev(sigma)=1,19 RI=[13,36, 18,1]
// CPSO - Mean(mu)=10,94, Std-Dev(sigma)=1,18 RI=[8,58, 13,3]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=28,18, Std-Dev(sigma)=1,22 RI=[25,75, 30,61]
// AMPDE - Mean(mu)=26,15, Std-Dev(sigma)=1,18 RI=[23,79, 28,51]
// CPSO - Mean(mu)=20,64, Std-Dev(sigma)=1,27 RI=[18,1, 23,18]
//
// Glicko2 rating:
// ACFPSO - Rating=1.710,3 RD=64,8 ro=0,06 RI=[1580,68, 1839,92]
// AMPDE - Rating=1.564,7 RD=64,8 ro=0,06 RI=[1435,09, 1694,33]
// CPSO - Rating=1.225 RD=64,8 ro=0,06 RI=[1095,37, 1354,61]
//
// Game results:
// ACFPSO [win=44, lose=18, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=20, lose=11, draw=0]}
// 	 Problems:{MPBEval8400=[win=44, lose=18, draw=0]}
// AMPDE [win=35, lose=27, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], CPSO=[win=24, lose=7, draw=0]}
// 	 Problems:{MPBEval8400=[win=35, lose=27, draw=0]}
// CPSO [win=14, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=7, lose=24, draw=0], AMPDE=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval8400=[win=14, lose=48, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=16,55, Std-Dev(sigma)=1,27 RI=[14,01, 19,08]
// AMPDE - Mean(mu)=15,87, Std-Dev(sigma)=1,18 RI=[13,51, 18,23]
// CPSO - Mean(mu)=11,34, Std-Dev(sigma)=1,17 RI=[9,01, 13,67]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=27,86, Std-Dev(sigma)=1,21 RI=[25,43, 30,28]
// AMPDE - Mean(mu)=26,08, Std-Dev(sigma)=1,18 RI=[23,73, 28,44]
// CPSO - Mean(mu)=21,05, Std-Dev(sigma)=1,25 RI=[18,55, 23,55]
//
// Glicko2 rating:
// ACFPSO - Rating=1.694,1 RD=64,8 ro=0,06 RI=[1564,51, 1823,74]
// AMPDE - Rating=1.564,7 RD=64,8 ro=0,06 RI=[1435,09, 1694,33]
// CPSO - Rating=1.241,2 RD=64,8 ro=0,06 RI=[1111,55, 1370,78]
//
// Game results:
// ACFPSO [win=43, lose=19, draw=0]
// 	 Against:{CPSO=[win=23, lose=8, draw=0], AMPDE=[win=20, lose=11, draw=0]}
// 	 Problems:{MPBEval8500=[win=43, lose=19, draw=0]}
// AMPDE [win=35, lose=27, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], CPSO=[win=24, lose=7, draw=0]}
// 	 Problems:{MPBEval8500=[win=35, lose=27, draw=0]}
// CPSO [win=15, lose=47, draw=0]
// 	 Against:{ACFPSO=[win=8, lose=23, draw=0], AMPDE=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval8500=[win=15, lose=47, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=16,67, Std-Dev(sigma)=1,26 RI=[14,15, 19,19]
// AMPDE - Mean(mu)=15,59, Std-Dev(sigma)=1,17 RI=[13,25, 17,93]
// CPSO - Mean(mu)=11,66, Std-Dev(sigma)=1,15 RI=[9,35, 13,96]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=27,82, Std-Dev(sigma)=1,21 RI=[25,39, 30,24]
// AMPDE - Mean(mu)=25,83, Std-Dev(sigma)=1,18 RI=[23,48, 28,18]
// CPSO - Mean(mu)=21,37, Std-Dev(sigma)=1,23 RI=[18,91, 23,84]
//
// Glicko2 rating:
// ACFPSO - Rating=1.694,1 RD=64,8 ro=0,06 RI=[1564,51, 1823,74]
// AMPDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.257,3 RD=64,8 ro=0,06 RI=[1127,72, 1386,96]
//
// Game results:
// ACFPSO [win=43, lose=19, draw=0]
// 	 Against:{CPSO=[win=23, lose=8, draw=0], AMPDE=[win=20, lose=11, draw=0]}
// 	 Problems:{MPBEval8600=[win=43, lose=19, draw=0]}
// AMPDE [win=34, lose=28, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], CPSO=[win=23, lose=8, draw=0]}
// 	 Problems:{MPBEval8600=[win=34, lose=28, draw=0]}
// CPSO [win=16, lose=46, draw=0]
// 	 Against:{ACFPSO=[win=8, lose=23, draw=0], AMPDE=[win=8, lose=23, draw=0]}
// 	 Problems:{MPBEval8600=[win=16, lose=46, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=16,67, Std-Dev(sigma)=1,26 RI=[14,15, 19,19]
// AMPDE - Mean(mu)=15,59, Std-Dev(sigma)=1,17 RI=[13,25, 17,93]
// CPSO - Mean(mu)=11,66, Std-Dev(sigma)=1,15 RI=[9,35, 13,96]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=27,82, Std-Dev(sigma)=1,21 RI=[25,39, 30,24]
// AMPDE - Mean(mu)=25,83, Std-Dev(sigma)=1,18 RI=[23,48, 28,18]
// CPSO - Mean(mu)=21,37, Std-Dev(sigma)=1,23 RI=[18,91, 23,84]
//
// Glicko2 rating:
// ACFPSO - Rating=1.694,1 RD=64,8 ro=0,06 RI=[1564,51, 1823,74]
// AMPDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.257,3 RD=64,8 ro=0,06 RI=[1127,72, 1386,96]
//
// Game results:
// ACFPSO [win=43, lose=19, draw=0]
// 	 Against:{CPSO=[win=23, lose=8, draw=0], AMPDE=[win=20, lose=11, draw=0]}
// 	 Problems:{MPBEval8700=[win=43, lose=19, draw=0]}
// AMPDE [win=34, lose=28, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], CPSO=[win=23, lose=8, draw=0]}
// 	 Problems:{MPBEval8700=[win=34, lose=28, draw=0]}
// CPSO [win=16, lose=46, draw=0]
// 	 Against:{ACFPSO=[win=8, lose=23, draw=0], AMPDE=[win=8, lose=23, draw=0]}
// 	 Problems:{MPBEv

// %%
fun generateSequence(changeFrequency: Int, environmentNumber: Int, sampleInterval: Int = 1000): List<Int> {
    val result = mutableListOf<Int>()
    // generate numbers increasing by sampleInterval
    for (i in sampleInterval..changeFrequency * environmentNumber step sampleInterval) {
        result.add(i)
        if (i % changeFrequency == 0 && i != changeFrequency * environmentNumber) {
            result.add(i + 1)   // add the next (evaluation) number just after the change happens
        }
    }
    return result
}

// %%
import org.jetbrains.letsPlot.commons.values.Color

val numAlgorithms = algPerf.size
val xValues = generateSequence(changeFrequency, environmentNumber, sampleInterval)

var plot = letsPlot(mapOf("eval" to xValues))

for (i in 0 until numAlgorithms) {
    val yValues = algPerf[i].evalData.values.map { it.rating } // // extract the rating values for the current algorithm

    // calculate the lower and upper bounds for the rating deviations
    val lowerBounds = algPerf[i].evalData.values.map { it.rating - 2 * it.ratingDeviation }
    val upperBounds = algPerf[i].evalData.values.map { it.rating + 2 * it.ratingDeviation }

    // prepare data for the current algorithm
    val data = mapOf(
        "Number of Fitness Evaluations" to xValues,
        "Rating" to yValues,
        "lowerBounds" to lowerBounds,
        "upperBounds" to upperBounds,
        "DMA:" to List(yValues.size) { algPerf[i].name }  // label each algorithm
    )

    // add rating line to the plot (cycling through predefined colors)
    plot += geomLine(data = data) {
        x = "Number of Fitness Evaluations"
        y = "Rating"
        color = "DMA:"
    }

    // add rating deviation ribbon to the plot (using the same color with transparency)
    plot += geomRibbon(data = data, alpha = 0.2) {
        x = "Number of Fitness Evaluations"
        ymin = "lowerBounds"
        ymax = "upperBounds"
        color = "DMA:"
        fill = "DMA:"
    }

    // add points at the same locations as the line
    plot += geomPoint(data = data) {
        x = "Number of Fitness Evaluations"
        y = "Rating"
        color = "DMA:"
    }
}

val minX = 0
val maxX = 25000

val shownTicks = xValues.withIndex()
    .filter { it.value % 5000 == 0 }
    .map { it.value }

plot += scaleXContinuous(
    breaks = shownTicks,
    labels = shownTicks.map { it.toInt().toString() }, // specify the tick marks   .take(valuesToShow)
    limits = minX to maxX
)

val verticalLines = (changeFrequency..changeFrequency * environmentNumber step changeFrequency).toList()
verticalLines.forEach { evalPoint ->
    plot += geomVLine(xintercept = evalPoint, color = "grey", linetype = "dashed") {
        // you can customize the appearance here
    }
}

// val width = 1000; val height = 750   // article dimensions
val width = 2000; val height = 750  // presentation dimensions

plot += ggsize(width, height)
plot += theme(
    title = elementText(face = "bold"), // 'title' applies to plot's title, subtitle, caption
    axisTitleX = elementText(size = 24),
    axisTextX = elementText(size = 20, angle = 0),
    axisTitleY = elementText(size = 24),
    axisTextY = elementText(size = 20),
    legendTitle = elementText(size = 24),
    legendText = elementText(size = 20)
).legendPositionTop()
plot += ggtb()  // enable Zoom and Pan interactivity

plot.show()
// Out:
//    <div id="k45QIe"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("k45QIe");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":2000.0,
// "height":750.0
// },
// "kind":"plot",
// "ggtoolbar":{
// },
// "scales":[{
// "aesthetic":"x",
// "breaks":[5000.0,10000.0,15000.0,20000.0,25000.0,30000.0,35000.0,40000.0,45000.0,50000.0,55000.0,60000.0,65000.0,70000.0,75000.0,80000.0,85000.0,90000.0,95000.0,100000.0,105000.0,110000.0,115000.0,120000.0,125000.0,130000.0,135000.0,140000.0,145000.0,150000.0,155000.0,160000.0,165000.0,170000.0,175000.0,180000.0,185000.0,190000.0,195000.0,200000.0,205000.0,210000.0,215000.0,220000.0,225000.0,230000.0,235000.0,240000.0,245000.0,250000.0,255000.0,260000.0,265000.0,270000.0,275000.0,280000.0,285000.0,290000.0,295000.0,300000.0,305000.0,310000.0,315000.0,320000.0,325000.0,330000.0,335000.0,340000.0,345000.0,350000.0,355000.0,360000.0,365000.0,370000.0,375000.0,380000.0,385000.0,390000.0,395000.0,400000.0,405000.0,410000.0,415000.0,420000.0,425000.0,430000.0,435000.0,440000.0,445000.0,450000.0,455000.0,460000.0,465000.0,470000.0,475000.0,480000.0,485000.0,490000.0,495000.0,500000.0],
// "limits":[0.0,25000.0],
// "labels":["5000","10000","15000","20000","25000","30000","35000","40000","45000","50000","55000","60000","65000","70000","75000","80000","85000","90000","95000","100000","105000","110000","115000","120000","125000","130000","135000","140000","145000","150000","155000","160000","165000","170000","175000","180000","185000","190000","195000","200000","205000","210000","215000","220000","225000","230000","235000","240000","245000","250000","255000","260000","265000","270000","275000","280000","285000","290000","295000","300000","305000","310000","315000","320000","325000","330000","335000","340000","345000","350000","355000","360000","365000","370000","375000","380000","385000","390000","395000","400000","405000","410000","415000","420000","425000","430000","435000","440000","445000","450000","455000","460000","465000","470000","475000","480000","485000","490000","495000","500000"]
// }],
// "layers":[{
// "mapping":{
// "x":"Number of Fitness Evaluations",
// "y":"Rating",
// "color":"DMA:"
// },
// "stat":"identity",
// "data":{
// "DMA:":["ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFPSO","ACFP ...
