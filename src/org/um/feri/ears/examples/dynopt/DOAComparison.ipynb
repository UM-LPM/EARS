// %% [markdown]
// # Example of how to (visually) compare dynamic optimization algorithms
//
// Visualization of comparison results is done using Lets-Plot library using [Lets-Plot Kotlin API](https://lets-plot.org/kotlin). You can see the latest release in JetBrain's [lets-plot-kotlin](https://github.com/JetBrains/lets-plot-kotlin) repository and check some starting examples in their [Lets-Plot Usage Guide](https://nbviewer.org/github/JetBrains/lets-plot-kotlin/blob/master/docs/guide/user_guide.ipynb). Also, see [some examples](https://nbviewer.org/github/JetBrains/lets-plot-kotlin/tree/master/docs/examples/jupyter-notebooks/) by specific release.

// %% [markdown]
// #### "Line Magics"
//
// This (`%use lets-plot`) "line magic" will apply **Lets-Plot library descriptor**, which adds to your notebook all the boilerplate code necessary to create plots. `%useLatestDescriptors` is needed for function `ggtb()`, which enables zoom/pan interactivity on the plot.

// %%
%useLatestDescriptors
%use lets-plot

// %% [markdown]
// #### EARS dependency
//
// Import all EARS classes needed to perform the comparison.

// %%
import org.um.feri.ears.algorithms.DummyAlgorithm
import org.um.feri.ears.algorithms.NumberAlgorithm
import org.um.feri.ears.benchmark.Benchmark
import org.um.feri.ears.examples.dynopt.AlgorithmPerformance
import org.um.feri.ears.examples.dynopt.GMPBBenchmark
import org.um.feri.ears.statistic.rating_system.RatingType
import org.um.feri.ears.visualization.rating.RatingIntervalPlot
import java.io.File

// %% [markdown]
// #### Set the configuration for the comparison using EARS
//
// Define the directory path for storing algorithm results.

// %%
val algResultsDir =
    "D:${File.separator}" +
            "EDOLAB-MATLAB${File.separator}" +
            "Results${File.separator}" +
            "Comparison${File.separator}" +
            "CEC2024${File.separator}" +
            "GMPB_Peaks5_ChangeFrequency5000_D5_ShiftSeverity1_Environments100"

// %% [markdown]
// Configure benchmark settings and disable certain features.

// %%
Benchmark.printInfo = false
//DummyAlgorithm.readFromJson = false
val displayRatingChart = false

// %% [markdown]
// Create a list of algorithms to be compared.

// %%
val players = arrayListOf<NumberAlgorithm>(
    //DummyAlgorithm("ACFPSO", algResultsDir),
    DummyAlgorithm("AMPDE", algResultsDir),
    //DummyAlgorithm("AMPPSO", algResultsDir),
    //DummyAlgorithm("AMSO", algResultsDir),
    //DummyAlgorithm("AmQSO", algResultsDir),
    //DummyAlgorithm("CDE", algResultsDir),
    //DummyAlgorithm("CESO", algResultsDir),
    DummyAlgorithm("CPSO", algResultsDir),
    //DummyAlgorithm("CPSOR", algResultsDir),
    //DummyAlgorithm("DSPSO", algResultsDir),
    //DummyAlgorithm("DynDE", algResultsDir),
    //DummyAlgorithm("DynPopDE", algResultsDir),
    //DummyAlgorithm("FTMPSO", algResultsDir),
    //DummyAlgorithm("HmSO", algResultsDir),
    //DummyAlgorithm("IDSPSO", algResultsDir),
    //DummyAlgorithm("ImQSO", algResultsDir),
    //DummyAlgorithm("RPSO", algResultsDir),
    //DummyAlgorithm("SPSO_AP_AD", algResultsDir),
    //DummyAlgorithm("TMIPSO", algResultsDir),
    //DummyAlgorithm("mCMAES", algResultsDir),
    //DummyAlgorithm("mDE", algResultsDir),
    //DummyAlgorithm("mPSO", algResultsDir),
    //DummyAlgorithm("mQSO", algResultsDir),
    DummyAlgorithm("mjDE", algResultsDir),
    //DummyAlgorithm("psfNBC", algResultsDir)
)

// %% [markdown]
// Initialize objects that will store algorithms' performance, set the number of runs, and calculate the total number of problems.

// %%
val algPerf = players.map { AlgorithmPerformance(it.id) }.toMutableList() // Prepare objects for storing the algorithms data.

val runNumber = 31

val changeFrequency = 5000
val environmentNumber = 100
val sampleInterval = 100
val numOfProblems = (changeFrequency / sampleInterval) * environmentNumber + environmentNumber - 1

// %% [markdown]
// #### Perform the comparison using EARS
//
// * Initialize the evaluation number and iterate through all problems.
// * For each problem, create and execute benchmarks, then store and optionally display the results.
// * Update the evaluation number based on the defined interval.

// %%
var evaluationNumber = sampleInterval
for (i in 0 until numOfProblems) {
    // Create and execute benchmarks for every evaluation defined with sampleInterval.
    val gmpbBenchmark = GMPBBenchmark(evaluationNumber).apply {
        setDisplayRatingCharts(false)
        addAlgorithms(players)
        run(runNumber)
    }

    val tournamentResults = gmpbBenchmark.tournamentResults

    if (displayRatingChart) {
        RatingIntervalPlot.displayChart(
            tournamentResults.players,
            RatingType.GLICKO2,
            "Rating Interval for Eval$evaluationNumber"
        )
    }

    // Store tournament results for every player (algorithm).
    tournamentResults.players.forEach { player ->
        algPerf.firstOrNull { it.name == player.id }?.apply {
            addRating(
                "mpbeval$evaluationNumber",
                player.glicko2Rating.rating,
                player.glicko2Rating.ratingDeviation
            )
        }
    }

    if (evaluationNumber % changeFrequency == 0) {
        // first evaluation after environment/problem change
        evaluationNumber++
    } else if (evaluationNumber % sampleInterval == 0) {
        // evaluation every 'sampleInterval'
        evaluationNumber += sampleInterval
    } else {
        // next evaluation after environment/problem change
        evaluationNumber = evaluationNumber + sampleInterval - 1
    }
}
// Out:
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=19,27, Std-Dev(sigma)=1,22 RI=[16,83, 21,72]
// AMPDE - Mean(mu)=18,8, Std-Dev(sigma)=1,13 RI=[16,54, 21,06]
// CPSO - Mean(mu)=18,02, Std-Dev(sigma)=1,03 RI=[15,96, 20,07]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26,94, Std-Dev(sigma)=1,24 RI=[24,46, 29,42]
// AMPDE - Mean(mu)=25,39, Std-Dev(sigma)=1,11 RI=[23,16, 27,61]
// CPSO - Mean(mu)=24,3, Std-Dev(sigma)=1,12 RI=[22,06, 26,53]
//
// Glicko2 rating:
// mjDE - Rating=1.645,6 RD=64,8 ro=0,06 RI=[1515,98, 1775,21]
// AMPDE - Rating=1.491,9 RD=64,8 ro=0,06 RI=[1362,29, 1621,53]
// CPSO - Rating=1.362,5 RD=64,8 ro=0,06 RI=[1232,88, 1492,11]
//
// Game results:
// mjDE [win=40, lose=22, draw=0]
// 	 Against:{CPSO=[win=22, lose=9, draw=0], AMPDE=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval100=[win=40, lose=22, draw=0]}
// AMPDE [win=23, lose=24, draw=15]
// 	 Against:{CPSO=[win=10, lose=6, draw=15], mjDE=[win=13, lose=18, draw=0]}
// 	 Problems:{GMPBEval100=[win=23, lose=24, draw=15]}
// CPSO [win=15, lose=32, draw=15]
// 	 Against:{AMPDE=[win=6, lose=10, draw=15], mjDE=[win=9, lose=22, draw=0]}
// 	 Problems:{GMPBEval100=[win=15, lose=32, draw=15]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=19,48, Std-Dev(sigma)=1,3 RI=[16,88, 22,08]
// CPSO - Mean(mu)=17,26, Std-Dev(sigma)=1,15 RI=[14,96, 19,57]
// AMPDE - Mean(mu)=15,3, Std-Dev(sigma)=1,14 RI=[13,02, 17,59]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=27,27, Std-Dev(sigma)=1,29 RI=[24,69, 29,85]
// CPSO - Mean(mu)=24,56, Std-Dev(sigma)=1,19 RI=[22,19, 26,93]
// AMPDE - Mean(mu)=22,45, Std-Dev(sigma)=1,2 RI=[20,04, 24,86]
//
// Glicko2 rating:
// mjDE - Rating=1.758,8 RD=64,8 ro=0,06 RI=[1629,22, 1888,45]
// CPSO - Rating=1.451,5 RD=64,8 ro=0,06 RI=[1321,85, 1581,09]
// AMPDE - Rating=1.289,7 RD=64,8 ro=0,06 RI=[1160,08, 1419,32]
//
// Game results:
// mjDE [win=47, lose=15, draw=0]
// 	 Against:{CPSO=[win=23, lose=8, draw=0], AMPDE=[win=24, lose=7, draw=0]}
// 	 Problems:{GMPBEval200=[win=47, lose=15, draw=0]}
// CPSO [win=26, lose=32, draw=4]
// 	 Against:{mjDE=[win=8, lose=23, draw=0], AMPDE=[win=18, lose=9, draw=4]}
// 	 Problems:{GMPBEval200=[win=26, lose=32, draw=4]}
// AMPDE [win=16, lose=42, draw=4]
// 	 Against:{CPSO=[win=9, lose=18, draw=4], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval200=[win=16, lose=42, draw=4]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=17,75, Std-Dev(sigma)=1,3 RI=[15,15, 20,35]
// CPSO - Mean(mu)=15,65, Std-Dev(sigma)=1,16 RI=[13,34, 17,96]
// AMPDE - Mean(mu)=14,32, Std-Dev(sigma)=1,15 RI=[12,02, 16,62]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=27,48, Std-Dev(sigma)=1,28 RI=[24,92, 30,04]
// CPSO - Mean(mu)=24,34, Std-Dev(sigma)=1,2 RI=[21,94, 26,74]
// AMPDE - Mean(mu)=23,3, Std-Dev(sigma)=1,2 RI=[20,91, 25,69]
//
// Glicko2 rating:
// mjDE - Rating=1.742,7 RD=64,8 ro=0,06 RI=[1613,04, 1872,28]
// CPSO - Rating=1.402,9 RD=64,8 ro=0,06 RI=[1273,32, 1532,56]
// AMPDE - Rating=1.354,4 RD=64,8 ro=0,06 RI=[1224,79, 1484,02]
//
// Game results:
// mjDE [win=46, lose=16, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=22, lose=9, draw=0]}
// 	 Problems:{GMPBEval300=[win=46, lose=16, draw=0]}
// CPSO [win=24, lose=36, draw=2]
// 	 Against:{mjDE=[win=7, lose=24, draw=0], AMPDE=[win=17, lose=12, draw=2]}
// 	 Problems:{GMPBEval300=[win=24, lose=36, draw=2]}
// AMPDE [win=21, lose=39, draw=2]
// 	 Against:{CPSO=[win=12, lose=17, draw=2], mjDE=[win=9, lose=22, draw=0]}
// 	 Problems:{GMPBEval300=[win=21, lose=39, draw=2]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=21,84, Std-Dev(sigma)=1,39 RI=[19,07, 24,62]
// CPSO - Mean(mu)=17,01, Std-Dev(sigma)=1,18 RI=[14,65, 19,37]
// AMPDE - Mean(mu)=15,69, Std-Dev(sigma)=1,16 RI=[13,37, 18,01]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=28,93, Std-Dev(sigma)=1,32 RI=[26,29, 31,56]
// CPSO - Mean(mu)=23,58, Std-Dev(sigma)=1,22 RI=[21,14, 26,02]
// AMPDE - Mean(mu)=22,09, Std-Dev(sigma)=1,22 RI=[19,65, 24,53]
//
// Glicko2 rating:
// mjDE - Rating=1.823,5 RD=64,8 ro=0,06 RI=[1693,92, 1953,16]
// CPSO - Rating=1.362,5 RD=64,8 ro=0,06 RI=[1232,88, 1492,11]
// AMPDE - Rating=1.314 RD=64,8 ro=0,06 RI=[1184,34, 1443,58]
//
// Game results:
// mjDE [win=51, lose=11, draw=0]
// 	 Against:{CPSO=[win=25, lose=6, draw=0], AMPDE=[win=26, lose=5, draw=0]}
// 	 Problems:{GMPBEval400=[win=51, lose=11, draw=0]}
// CPSO [win=22, lose=39, draw=1]
// 	 Against:{mjDE=[win=6, lose=25, draw=0], AMPDE=[win=16, lose=14, draw=1]}
// 	 Problems:{GMPBEval400=[win=22, lose=39, draw=1]}
// AMPDE [win=19, lose=42, draw=1]
// 	 Against:{CPSO=[win=14, lose=16, draw=1], mjDE=[win=5, lose=26, draw=0]}
// 	 Problems:{GMPBEval400=[win=19, lose=42, draw=1]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=22,23, Std-Dev(sigma)=1,57 RI=[19,08, 25,38]
// AMPDE - Mean(mu)=15,38, Std-Dev(sigma)=1,18 RI=[13,02, 17,74]
// CPSO - Mean(mu)=15,16, Std-Dev(sigma)=1,23 RI=[12,71, 17,61]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=29,77, Std-Dev(sigma)=1,45 RI=[26,86, 32,68]
// CPSO - Mean(mu)=22,04, Std-Dev(sigma)=1,26 RI=[19,52, 24,56]
// AMPDE - Mean(mu)=21,68, Std-Dev(sigma)=1,25 RI=[19,19, 24,18]
//
// Glicko2 rating:
// mjDE - Rating=1.888,3 RD=64,8 ro=0,06 RI=[1758,63, 2017,87]
// CPSO - Rating=1.314 RD=64,8 ro=0,06 RI=[1184,34, 1443,58]
// AMPDE - Rating=1.297,8 RD=64,8 ro=0,06 RI=[1168,17, 1427,4]
//
// Game results:
// mjDE [win=55, lose=7, draw=0]
// 	 Against:{CPSO=[win=26, lose=5, draw=0], AMPDE=[win=29, lose=2, draw=0]}
// 	 Problems:{GMPBEval500=[win=55, lose=7, draw=0]}
// CPSO [win=19, lose=42, draw=1]
// 	 Against:{mjDE=[win=5, lose=26, draw=0], AMPDE=[win=14, lose=16, draw=1]}
// 	 Problems:{GMPBEval500=[win=19, lose=42, draw=1]}
// AMPDE [win=18, lose=43, draw=1]
// 	 Against:{CPSO=[win=16, lose=14, draw=1], mjDE=[win=2, lose=29, draw=0]}
// 	 Problems:{GMPBEval500=[win=18, lose=43, draw=1]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=23, Std-Dev(sigma)=1,65 RI=[19,71, 26,29]
// CPSO - Mean(mu)=15,81, Std-Dev(sigma)=1,23 RI=[13,34, 18,28]
// AMPDE - Mean(mu)=15,13, Std-Dev(sigma)=1,2 RI=[12,73, 17,53]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=30,42, Std-Dev(sigma)=1,52 RI=[27,39, 33,45]
// CPSO - Mean(mu)=22,3, Std-Dev(sigma)=1,27 RI=[19,76, 24,85]
// AMPDE - Mean(mu)=21,17, Std-Dev(sigma)=1,27 RI=[18,63, 23,71]
//
// Glicko2 rating:
// mjDE - Rating=1.904,4 RD=64,8 ro=0,06 RI=[1774,81, 2034,05]
// CPSO - Rating=1.314 RD=64,8 ro=0,06 RI=[1184,34, 1443,58]
// AMPDE - Rating=1.281,6 RD=64,8 ro=0,06 RI=[1151,99, 1411,23]
//
// Game results:
// mjDE [win=56, lose=6, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=29, lose=2, draw=0]}
// 	 Problems:{GMPBEval600=[win=56, lose=6, draw=0]}
// CPSO [win=19, lose=42, draw=1]
// 	 Against:{mjDE=[win=4, lose=27, draw=0], AMPDE=[win=15, lose=15, draw=1]}
// 	 Problems:{GMPBEval600=[win=19, lose=42, draw=1]}
// AMPDE [win=17, lose=44, draw=1]
// 	 Against:{CPSO=[win=15, lose=15, draw=1], mjDE=[win=2, lose=29, draw=0]}
// 	 Problems:{GMPBEval600=[win=17, lose=44, draw=1]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=23,08, Std-Dev(sigma)=1,67 RI=[19,73, 26,43]
// CPSO - Mean(mu)=15,89, Std-Dev(sigma)=1,22 RI=[13,46, 18,33]
// AMPDE - Mean(mu)=14,28, Std-Dev(sigma)=1,22 RI=[11,85, 16,72]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=31,03, Std-Dev(sigma)=1,5 RI=[28,03, 34,04]
// CPSO - Mean(mu)=23,06, Std-Dev(sigma)=1,24 RI=[20,58, 25,54]
// AMPDE - Mean(mu)=21,04, Std-Dev(sigma)=1,27 RI=[18,5, 23,58]
//
// Glicko2 rating:
// mjDE - Rating=1.904,4 RD=64,8 ro=0,06 RI=[1774,81, 2034,05]
// CPSO - Rating=1.362,5 RD=64,8 ro=0,06 RI=[1232,88, 1492,11]
// AMPDE - Rating=1.233,1 RD=64,8 ro=0,06 RI=[1103,46, 1362,7]
//
// Game results:
// mjDE [win=56, lose=6, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=29, lose=2, draw=0]}
// 	 Problems:{GMPBEval700=[win=56, lose=6, draw=0]}
// CPSO [win=22, lose=39, draw=1]
// 	 Against:{mjDE=[win=4, lose=27, draw=0], AMPDE=[win=18, lose=12, draw=1]}
// 	 Problems:{GMPBEval700=[win=22, lose=39, draw=1]}
// AMPDE [win=14, lose=47, draw=1]
// 	 Against:{CPSO=[win=12, lose=18, draw=1], mjDE=[win=2, lose=29, draw=0]}
// 	 Problems:{GMPBEval700=[win=14, lose=47, draw=1]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=23,22, Std-Dev(sigma)=1,56 RI=[20,09, 26,35]
// CPSO - Mean(mu)=15,59, Std-Dev(sigma)=1,18 RI=[13,23, 17,95]
// AMPDE - Mean(mu)=15,45, Std-Dev(sigma)=1,17 RI=[13,12, 17,79]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=30,8, Std-Dev(sigma)=1,44 RI=[27,92, 33,68]
// CPSO - Mean(mu)=22,33, Std-Dev(sigma)=1,23 RI=[19,88, 24,78]
// AMPDE - Mean(mu)=21,86, Std-Dev(sigma)=1,23 RI=[19,4, 24,32]
//
// Glicko2 rating:
// mjDE - Rating=1.888,3 RD=64,8 ro=0,06 RI=[1758,63, 2017,87]
// CPSO - Rating=1.330,1 RD=64,8 ro=0,06 RI=[1200,52, 1459,76]
// AMPDE - Rating=1.281,6 RD=64,8 ro=0,06 RI=[1151,99, 1411,23]
//
// Game results:
// mjDE [win=55, lose=7, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=28, lose=3, draw=0]}
// 	 Problems:{GMPBEval800=[win=55, lose=7, draw=0]}
// CPSO [win=20, lose=41, draw=1]
// 	 Against:{mjDE=[win=4, lose=27, draw=0], AMPDE=[win=16, lose=14, draw=1]}
// 	 Problems:{GMPBEval800=[win=20, lose=41, draw=1]}
// AMPDE [win=17, lose=44, draw=1]
// 	 Against:{CPSO=[win=14, lose=16, draw=1], mjDE=[win=3, lose=28, draw=0]}
// 	 Problems:{GMPBEval800=[win=17, lose=44, draw=1]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=24,19, Std-Dev(sigma)=1,79 RI=[20,6, 27,78]
// CPSO - Mean(mu)=16,89, Std-Dev(sigma)=1,25 RI=[14,38, 19,4]
// AMPDE - Mean(mu)=16,11, Std-Dev(sigma)=1,23 RI=[13,65, 18,58]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=30,48, Std-Dev(sigma)=1,66 RI=[27,16, 33,8]
// CPSO - Mean(mu)=21,99, Std-Dev(sigma)=1,28 RI=[19,42, 24,55]
// AMPDE - Mean(mu)=20,85, Std-Dev(sigma)=1,29 RI=[18,26, 23,43]
//
// Glicko2 rating:
// mjDE - Rating=1.920,6 RD=64,8 ro=0,06 RI=[1790,99, 2050,23]
// CPSO - Rating=1.314 RD=64,8 ro=0,06 RI=[1184,34, 1443,58]
// AMPDE - Rating=1.265,4 RD=64,8 ro=0,06 RI=[1135,81, 1395,05]
//
// Game results:
// mjDE [win=57, lose=5, draw=0]
// 	 Against:{CPSO=[win=28, lose=3, draw=0], AMPDE=[win=29, lose=2, draw=0]}
// 	 Problems:{GMPBEval900=[win=57, lose=5, draw=0]}
// CPSO [win=19, lose=42, draw=1]
// 	 Against:{mjDE=[win=3, lose=28, draw=0], AMPDE=[win=16, lose=14, draw=1]}
// 	 Problems:{GMPBEval900=[win=19, lose=42, draw=1]}
// AMPDE [win=16, lose=45, draw=1]
// 	 Against:{CPSO=[win=14, lose=16, draw=1], mjDE=[win=2, lose=29, draw=0]}
// 	 Problems:{GMPBEval900=[win=16, lose=45, draw=1]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=21,76, Std-Dev(sigma)=1,68 RI=[18,41, 25,12]
// AMPDE - Mean(mu)=13,88, Std-Dev(sigma)=1,22 RI=[11,43, 16,32]
// CPSO - Mean(mu)=13,28, Std-Dev(sigma)=1,26 RI=[10,76, 15,8]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=31,55, Std-Dev(sigma)=1,5 RI=[28,54, 34,56]
// AMPDE - Mean(mu)=22,63, Std-Dev(sigma)=1,26 RI=[20,1, 25,16]
// CPSO - Mean(mu)=22,35, Std-Dev(sigma)=1,3 RI=[19,74, 24,96]
//
// Glicko2 rating:
// mjDE - Rating=1.888,3 RD=64,8 ro=0,06 RI=[1758,63, 2017,87]
// AMPDE - Rating=1.354,4 RD=64,8 ro=0,06 RI=[1224,79, 1484,02]
// CPSO - Rating=1.257,3 RD=64,8 ro=0,06 RI=[1127,72, 1386,96]
//
// Game results:
// mjDE [win=55, lose=7, draw=0]
// 	 Against:{CPSO=[win=28, lose=3, draw=0], AMPDE=[win=27, lose=4, draw=0]}
// 	 Problems:{GMPBEval1000=[win=55, lose=7, draw=0]}
// AMPDE [win=22, lose=40, draw=0]
// 	 Against:{CPSO=[win=18, lose=13, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval1000=[win=22, lose=40, draw=0]}
// CPSO [win=16, lose=46, draw=0]
// 	 Against:{AMPDE=[win=13, lose=18, draw=0], mjDE=[win=3, lose=28, draw=0]}
// 	 Problems:{GMPBEval1000=[win=16, lose=46, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=21,67, Std-Dev(sigma)=1,64 RI=[18,4, 24,95]
// AMPDE - Mean(mu)=16,04, Std-Dev(sigma)=1,17 RI=[13,71, 18,38]
// CPSO - Mean(mu)=13,23, Std-Dev(sigma)=1,24 RI=[10,75, 15,72]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=30,96, Std-Dev(sigma)=1,5 RI=[27,97, 33,96]
// AMPDE - Mean(mu)=23,36, Std-Dev(sigma)=1,22 RI=[20,91, 25,8]
// CPSO - Mean(mu)=20,78, Std-Dev(sigma)=1,28 RI=[18,21, 23,34]
//
// Glicko2 rating:
// mjDE - Rating=1.872,1 RD=64,8 ro=0,06 RI=[1742,46, 2001,69]
// AMPDE - Rating=1.370,6 RD=64,8 ro=0,06 RI=[1240,96, 1500,2]
// CPSO - Rating=1.257,3 RD=64,8 ro=0,06 RI=[1127,72, 1386,96]
//
// Game results:
// mjDE [win=54, lose=8, draw=0]
// 	 Against:{CPSO=[win=26, lose=5, draw=0], AMPDE=[win=28, lose=3, draw=0]}
// 	 Problems:{GMPBEval1100=[win=54, lose=8, draw=0]}
// AMPDE [win=23, lose=39, draw=0]
// 	 Against:{CPSO=[win=20, lose=11, draw=0], mjDE=[win=3, lose=28, draw=0]}
// 	 Problems:{GMPBEval1100=[win=23, lose=39, draw=0]}
// CPSO [win=16, lose=46, draw=0]
// 	 Against:{AMPDE=[win=11, lose=20, draw=0], mjDE=[win=5, lose=26, draw=0]}
// 	 Problems:{GMPBEval1100=[win=16, lose=46, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=21,47, Std-Dev(sigma)=1,66 RI=[18,15, 24,8]
// AMPDE - Mean(mu)=16,01, Std-Dev(sigma)=1,18 RI=[13,65, 18,37]
// CPSO - Mean(mu)=13,6, Std-Dev(sigma)=1,26 RI=[11,07, 16,12]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=30,66, Std-Dev(sigma)=1,55 RI=[27,57, 33,75]
// AMPDE - Mean(mu)=23,04, Std-Dev(sigma)=1,23 RI=[20,57, 25,51]
// CPSO - Mean(mu)=20,91, Std-Dev(sigma)=1,31 RI=[18,3, 23,52]
//
// Glicko2 rating:
// mjDE - Rating=1.872,1 RD=64,8 ro=0,06 RI=[1742,46, 2001,69]
// AMPDE - Rating=1.370,6 RD=64,8 ro=0,06 RI=[1240,96, 1500,2]
// CPSO - Rating=1.257,3 RD=64,8 ro=0,06 RI=[1127,72, 1386,96]
//
// Game results:
// mjDE [win=54, lose=8, draw=0]
// 	 Against:{CPSO=[win=26, lose=5, draw=0], AMPDE=[win=28, lose=3, draw=0]}
// 	 Problems:{GMPBEval1200=[win=54, lose=8, draw=0]}
// AMPDE [win=23, lose=39, draw=0]
// 	 Against:{CPSO=[win=20, lose=11, draw=0], mjDE=[win=3, lose=28, draw=0]}
// 	 Problems:{GMPBEval1200=[win=23, lose=39, draw=0]}
// CPSO [win=16, lose=46, draw=0]
// 	 Against:{AMPDE=[win=11, lose=20, draw=0], mjDE=[win=5, lose=26, draw=0]}
// 	 Problems:{GMPBEval1200=[win=16, lose=46, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=22,42, Std-Dev(sigma)=1,72 RI=[18,99, 25,86]
// AMPDE - Mean(mu)=15,73, Std-Dev(sigma)=1,2 RI=[13,33, 18,12]
// CPSO - Mean(mu)=13,74, Std-Dev(sigma)=1,26 RI=[11,22, 16,26]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=31,11, Std-Dev(sigma)=1,56 RI=[27,99, 34,23]
// AMPDE - Mean(mu)=22,75, Std-Dev(sigma)=1,25 RI=[20,24, 25,25]
// CPSO - Mean(mu)=21,23, Std-Dev(sigma)=1,29 RI=[18,65, 23,8]
//
// Glicko2 rating:
// mjDE - Rating=1.888,3 RD=64,8 ro=0,06 RI=[1758,63, 2017,87]
// AMPDE - Rating=1.338,2 RD=64,8 ro=0,06 RI=[1208,61, 1467,85]
// CPSO - Rating=1.273,5 RD=64,8 ro=0,06 RI=[1143,9, 1403,14]
//
// Game results:
// mjDE [win=55, lose=7, draw=0]
// 	 Against:{CPSO=[win=26, lose=5, draw=0], AMPDE=[win=29, lose=2, draw=0]}
// 	 Problems:{GMPBEval1300=[win=55, lose=7, draw=0]}
// AMPDE [win=21, lose=41, draw=0]
// 	 Against:{CPSO=[win=19, lose=12, draw=0], mjDE=[win=2, lose=29, draw=0]}
// 	 Problems:{GMPBEval1300=[win=21, lose=41, draw=0]}
// CPSO [win=17, lose=45, draw=0]
// 	 Against:{AMPDE=[win=12, lose=19, draw=0], mjDE=[win=5, lose=26, draw=0]}
// 	 Problems:{GMPBEval1300=[win=17, lose=45, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=25,25, Std-Dev(sigma)=1,83 RI=[21,59, 28,92]
// AMPDE - Mean(mu)=16,87, Std-Dev(sigma)=1,2 RI=[14,47, 19,28]
// CPSO - Mean(mu)=14,8, Std-Dev(sigma)=1,26 RI=[12,29, 17,32]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=32,21, Std-Dev(sigma)=1,66 RI=[28,88, 35,53]
// AMPDE - Mean(mu)=22,14, Std-Dev(sigma)=1,26 RI=[19,62, 24,65]
// CPSO - Mean(mu)=20,01, Std-Dev(sigma)=1,31 RI=[17,4, 22,63]
//
// Glicko2 rating:
// mjDE - Rating=1.904,4 RD=64,8 ro=0,06 RI=[1774,81, 2034,05]
// AMPDE - Rating=1.354,4 RD=64,8 ro=0,06 RI=[1224,79, 1484,02]
// CPSO - Rating=1.241,2 RD=64,8 ro=0,06 RI=[1111,55, 1370,78]
//
// Game results:
// mjDE [win=56, lose=6, draw=0]
// 	 Against:{CPSO=[win=28, lose=3, draw=0], AMPDE=[win=28, lose=3, draw=0]}
// 	 Problems:{GMPBEval1400=[win=56, lose=6, draw=0]}
// AMPDE [win=22, lose=40, draw=0]
// 	 Against:{CPSO=[win=19, lose=12, draw=0], mjDE=[win=3, lose=28, draw=0]}
// 	 Problems:{GMPBEval1400=[win=22, lose=40, draw=0]}
// CPSO [win=15, lose=47, draw=0]
// 	 Against:{AMPDE=[win=12, lose=19, draw=0], mjDE=[win=3, lose=28, draw=0]}
// 	 Problems:{GMPBEval1400=[win=15, lose=47, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=23,95, Std-Dev(sigma)=1,75 RI=[20,45, 27,46]
// AMPDE - Mean(mu)=16,86, Std-Dev(sigma)=1,2 RI=[14,47, 19,25]
// CPSO - Mean(mu)=14,51, Std-Dev(sigma)=1,27 RI=[11,96, 17,05]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=31,34, Std-Dev(sigma)=1,59 RI=[28,17, 34,51]
// AMPDE - Mean(mu)=22,44, Std-Dev(sigma)=1,26 RI=[19,93, 24,95]
// CPSO - Mean(mu)=20,25, Std-Dev(sigma)=1,31 RI=[17,62, 22,88]
//
// Glicko2 rating:
// mjDE - Rating=1.888,3 RD=64,8 ro=0,06 RI=[1758,63, 2017,87]
// AMPDE - Rating=1.370,6 RD=64,8 ro=0,06 RI=[1240,96, 1500,2]
// CPSO - Rating=1.241,2 RD=64,8 ro=0,06 RI=[1111,55, 1370,78]
//
// Game results:
// mjDE [win=55, lose=7, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=28, lose=3, draw=0]}
// 	 Problems:{GMPBEval1500=[win=55, lose=7, draw=0]}
// AMPDE [win=23, lose=39, draw=0]
// 	 Against:{CPSO=[win=20, lose=11, draw=0], mjDE=[win=3, lose=28, draw=0]}
// 	 Problems:{GMPBEval1500=[win=23, lose=39, draw=0]}
// CPSO [win=15, lose=47, draw=0]
// 	 Against:{AMPDE=[win=11, lose=20, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval1500=[win=15, lose=47, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=22,21, Std-Dev(sigma)=1,59 RI=[19,03, 25,39]
// AMPDE - Mean(mu)=16,41, Std-Dev(sigma)=1,18 RI=[14,05, 18,77]
// CPSO - Mean(mu)=13,95, Std-Dev(sigma)=1,25 RI=[11,45, 16,44]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=30,19, Std-Dev(sigma)=1,45 RI=[27,3, 33,09]
// AMPDE - Mean(mu)=23,07, Std-Dev(sigma)=1,23 RI=[20,61, 25,53]
// CPSO - Mean(mu)=20,66, Std-Dev(sigma)=1,29 RI=[18,08, 23,24]
//
// Glicko2 rating:
// mjDE - Rating=1.855,9 RD=64,8 ro=0,06 RI=[1726,28, 1985,52]
// AMPDE - Rating=1.386,8 RD=64,8 ro=0,06 RI=[1257,14, 1516,38]
// CPSO - Rating=1.257,3 RD=64,8 ro=0,06 RI=[1127,72, 1386,96]
//
// Game results:
// mjDE [win=53, lose=9, draw=0]
// 	 Against:{CPSO=[win=26, lose=5, draw=0], AMPDE=[win=27, lose=4, draw=0]}
// 	 Problems:{GMPBEval1600=[win=53, lose=9, draw=0]}
// AMPDE [win=24, lose=38, draw=0]
// 	 Against:{CPSO=[win=20, lose=11, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval1600=[win=24, lose=38, draw=0]}
// CPSO [win=16, lose=46, draw=0]
// 	 Against:{AMPDE=[win=11, lose=20, draw=0], mjDE=[win=5, lose=26, draw=0]}
// 	 Problems:{GMPBEval1600=[win=16, lose=46, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=21,24, Std-Dev(sigma)=1,57 RI=[18,11, 24,37]
// AMPDE - Mean(mu)=16,73, Std-Dev(sigma)=1,17 RI=[14,38, 19,08]
// CPSO - Mean(mu)=14,12, Std-Dev(sigma)=1,25 RI=[11,63, 16,61]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=29,77, Std-Dev(sigma)=1,44 RI=[26,89, 32,66]
// AMPDE - Mean(mu)=23,18, Std-Dev(sigma)=1,23 RI=[20,73, 25,64]
// CPSO - Mean(mu)=20,86, Std-Dev(sigma)=1,29 RI=[18,29, 23,44]
//
// Glicko2 rating:
// mjDE - Rating=1.839,7 RD=64,8 ro=0,06 RI=[1710,1, 1969,34]
// AMPDE - Rating=1.402,9 RD=64,8 ro=0,06 RI=[1273,32, 1532,56]
// CPSO - Rating=1.257,3 RD=64,8 ro=0,06 RI=[1127,72, 1386,96]
//
// Game results:
// mjDE [win=52, lose=10, draw=0]
// 	 Against:{CPSO=[win=25, lose=6, draw=0], AMPDE=[win=27, lose=4, draw=0]}
// 	 Problems:{GMPBEval1700=[win=52, lose=10, draw=0]}
// AMPDE [win=25, lose=37, draw=0]
// 	 Against:{CPSO=[win=21, lose=10, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval1700=[win=25, lose=37, draw=0]}
// CPSO [win=16, lose=46, draw=0]
// 	 Against:{AMPDE=[win=10, lose=21, draw=0], mjDE=[win=6, lose=25, draw=0]}
// 	 Problems:{GMPBEval1700=[win=16, lose=46, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=20,82, Std-Dev(sigma)=1,51 RI=[17,81, 23,84]
// AMPDE - Mean(mu)=16,23, Std-Dev(sigma)=1,17 RI=[13,89, 18,57]
// CPSO - Mean(mu)=14,36, Std-Dev(sigma)=1,23 RI=[11,89, 16,82]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=29,35, Std-Dev(sigma)=1,4 RI=[26,55, 32,14]
// AMPDE - Mean(mu)=23,15, Std-Dev(sigma)=1,22 RI=[20,72, 25,59]
// CPSO - Mean(mu)=21,37, Std-Dev(sigma)=1,28 RI=[18,82, 23,93]
//
// Glicko2 rating:
// mjDE - Rating=1.823,5 RD=64,8 ro=0,06 RI=[1693,92, 1953,16]
// AMPDE - Rating=1.402,9 RD=64,8 ro=0,06 RI=[1273,32, 1532,56]
// CPSO - Rating=1.273,5 RD=64,8 ro=0,06 RI=[1143,9, 1403,14]
//
// Game results:
// mjDE [win=51, lose=11, draw=0]
// 	 Against:{CPSO=[win=25, lose=6, draw=0], AMPDE=[win=26, lose=5, draw=0]}
// 	 Problems:{GMPBEval1800=[win=51, lose=11, draw=0]}
// AMPDE [win=25, lose=37, draw=0]
// 	 Against:{CPSO=[win=20, lose=11, draw=0], mjDE=[win=5, lose=26, draw=0]}
// 	 Problems:{GMPBEval1800=[win=25, lose=37, draw=0]}
// CPSO [win=17, lose=45, draw=0]
// 	 Against:{AMPDE=[win=11, lose=20, draw=0], mjDE=[win=6, lose=25, draw=0]}
// 	 Problems:{GMPBEval1800=[win=17, lose=45, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=20,82, Std-Dev(sigma)=1,51 RI=[17,81, 23,84]
// AMPDE - Mean(mu)=16,23, Std-Dev(sigma)=1,17 RI=[13,89, 18,57]
// CPSO - Mean(mu)=14,36, Std-Dev(sigma)=1,23 RI=[11,89, 16,82]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=29,35, Std-Dev(sigma)=1,4 RI=[26,55, 32,14]
// AMPDE - Mean(mu)=23,15, Std-Dev(sigma)=1,22 RI=[20,72, 25,59]
// CPSO - Mean(mu)=21,37, Std-Dev(sigma)=1,28 RI=[18,82, 23,93]
//
// Glicko2 rating:
// mjDE - Rating=1.823,5 RD=64,8 ro=0,06 RI=[1693,92, 1953,16]
// AMPDE - Rating=1.402,9 RD=64,8 ro=0,06 RI=[1273,32, 1532,56]
// CPSO - Rating=1.273,5 RD=64,8 ro=0,06 RI=[1143,9, 1403,14]
//
// Game results:
// mjDE [win=51, lose=11, draw=0]
// 	 Against:{CPSO=[win=25, lose=6, draw=0], AMPDE=[win=26, lose=5, draw=0]}
// 	 Problems:{GMPBEval1900=[win=51, lose=11, draw=0]}
// AMPDE [win=25, lose=37, draw=0]
// 	 Against:{CPSO=[win=20, lose=11, draw=0], mjDE=[win=5, lose=26, draw=0]}
// 	 Problems:{GMPBEval1900=[win=25, lose=37, draw=0]}
// CPSO [win=17, lose=45, draw=0]
// 	 Against:{AMPDE=[win=11, lose=20, draw=0], mjDE=[win=6, lose=25, draw=0]}
// 	 Problems:{GMPBEval1900=[win=17, lose=45, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=19,64, Std-Dev(sigma)=1,53 RI=[16,59, 22,7]
// AMPDE - Mean(mu)=14,95, Std-Dev(sigma)=1,18 RI=[12,58, 17,32]
// CPSO - Mean(mu)=13,09, Std-Dev(sigma)=1,24 RI=[10,6, 15,58]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=29,53, Std-Dev(sigma)=1,4 RI=[26,72, 32,34]
// AMPDE - Mean(mu)=23,28, Std-Dev(sigma)=1,22 RI=[20,84, 25,73]
// CPSO - Mean(mu)=21,52, Std-Dev(sigma)=1,28 RI=[18,96, 24,07]
//
// Glicko2 rating:
// mjDE - Rating=1.839,7 RD=64,8 ro=0,06 RI=[1710,1, 1969,34]
// AMPDE - Rating=1.386,8 RD=64,8 ro=0,06 RI=[1257,14, 1516,38]
// CPSO - Rating=1.273,5 RD=64,8 ro=0,06 RI=[1143,9, 1403,14]
//
// Game results:
// mjDE [win=52, lose=10, draw=0]
// 	 Against:{CPSO=[win=25, lose=6, draw=0], AMPDE=[win=27, lose=4, draw=0]}
// 	 Problems:{GMPBEval2000=[win=52, lose=10, draw=0]}
// AMPDE [win=24, lose=38, draw=0]
// 	 Against:{CPSO=[win=20, lose=11, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval2000=[win=24, lose=38, draw=0]}
// CPSO [win=17, lose=45, draw=0]
// 	 Against:{mjDE=[win=6, lose=25, draw=0], AMPDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval2000=[win=17, lose=45, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=19,62, Std-Dev(sigma)=1,52 RI=[16,57, 22,66]
// AMPDE - Mean(mu)=14,89, Std-Dev(sigma)=1,18 RI=[12,53, 17,25]
// CPSO - Mean(mu)=12,98, Std-Dev(sigma)=1,24 RI=[10,51, 15,46]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=29,59, Std-Dev(sigma)=1,39 RI=[26,81, 32,38]
// AMPDE - Mean(mu)=23,26, Std-Dev(sigma)=1,22 RI=[20,82, 25,69]
// CPSO - Mean(mu)=21,51, Std-Dev(sigma)=1,27 RI=[18,96, 24,06]
//
// Glicko2 rating:
// mjDE - Rating=1.839,7 RD=64,8 ro=0,06 RI=[1710,1, 1969,34]
// AMPDE - Rating=1.386,8 RD=64,8 ro=0,06 RI=[1257,14, 1516,38]
// CPSO - Rating=1.273,5 RD=64,8 ro=0,06 RI=[1143,9, 1403,14]
//
// Game results:
// mjDE [win=52, lose=10, draw=0]
// 	 Against:{CPSO=[win=25, lose=6, draw=0], AMPDE=[win=27, lose=4, draw=0]}
// 	 Problems:{GMPBEval2100=[win=52, lose=10, draw=0]}
// AMPDE [win=24, lose=38, draw=0]
// 	 Against:{CPSO=[win=20, lose=11, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval2100=[win=24, lose=38, draw=0]}
// CPSO [win=17, lose=45, draw=0]
// 	 Against:{mjDE=[win=6, lose=25, draw=0], AMPDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval2100=[win=17, lose=45, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=21,32, Std-Dev(sigma)=1,61 RI=[18,1, 24,54]
// AMPDE - Mean(mu)=15,61, Std-Dev(sigma)=1,19 RI=[13,22, 17,99]
// CPSO - Mean(mu)=13,91, Std-Dev(sigma)=1,25 RI=[11,41, 16,41]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=30,37, Std-Dev(sigma)=1,49 RI=[27,4, 33,34]
// AMPDE - Mean(mu)=22,86, Std-Dev(sigma)=1,25 RI=[20,37, 25,35]
// CPSO - Mean(mu)=21,18, Std-Dev(sigma)=1,31 RI=[18,56, 23,79]
//
// Glicko2 rating:
// mjDE - Rating=1.872,1 RD=64,8 ro=0,06 RI=[1742,46, 2001,69]
// AMPDE - Rating=1.386,8 RD=64,8 ro=0,06 RI=[1257,14, 1516,38]
// CPSO - Rating=1.241,2 RD=64,8 ro=0,06 RI=[1111,55, 1370,78]
//
// Game results:
// mjDE [win=54, lose=8, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=27, lose=4, draw=0]}
// 	 Problems:{GMPBEval2200=[win=54, lose=8, draw=0]}
// AMPDE [win=24, lose=38, draw=0]
// 	 Against:{CPSO=[win=20, lose=11, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval2200=[win=24, lose=38, draw=0]}
// CPSO [win=15, lose=47, draw=0]
// 	 Against:{mjDE=[win=4, lose=27, draw=0], AMPDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval2200=[win=15, lose=47, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=20,76, Std-Dev(sigma)=1,56 RI=[17,63, 23,88]
// AMPDE - Mean(mu)=15,69, Std-Dev(sigma)=1,2 RI=[13,3, 18,08]
// CPSO - Mean(mu)=13,81, Std-Dev(sigma)=1,24 RI=[11,32, 16,3]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=29,74, Std-Dev(sigma)=1,45 RI=[26,83, 32,65]
// AMPDE - Mean(mu)=23,3, Std-Dev(sigma)=1,24 RI=[20,82, 25,78]
// CPSO - Mean(mu)=21,2, Std-Dev(sigma)=1,3 RI=[18,59, 23,81]
//
// Glicko2 rating:
// mjDE - Rating=1.855,9 RD=64,8 ro=0,06 RI=[1726,28, 1985,52]
// AMPDE - Rating=1.402,9 RD=64,8 ro=0,06 RI=[1273,32, 1532,56]
// CPSO - Rating=1.241,2 RD=64,8 ro=0,06 RI=[1111,55, 1370,78]
//
// Game results:
// mjDE [win=53, lose=9, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=26, lose=5, draw=0]}
// 	 Problems:{GMPBEval2300=[win=53, lose=9, draw=0]}
// AMPDE [win=25, lose=37, draw=0]
// 	 Against:{CPSO=[win=20, lose=11, draw=0], mjDE=[win=5, lose=26, draw=0]}
// 	 Problems:{GMPBEval2300=[win=25, lose=37, draw=0]}
// CPSO [win=15, lose=47, draw=0]
// 	 Against:{mjDE=[win=4, lose=27, draw=0], AMPDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval2300=[win=15, lose=47, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=22,37, Std-Dev(sigma)=1,75 RI=[18,88, 25,86]
// AMPDE - Mean(mu)=15,95, Std-Dev(sigma)=1,21 RI=[13,54, 18,36]
// CPSO - Mean(mu)=14,55, Std-Dev(sigma)=1,28 RI=[11,99, 17,12]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=31,21, Std-Dev(sigma)=1,64 RI=[27,93, 34,49]
// AMPDE - Mean(mu)=22,88, Std-Dev(sigma)=1,27 RI=[20,34, 25,41]
// CPSO - Mean(mu)=21,16, Std-Dev(sigma)=1,34 RI=[18,48, 23,85]
//
// Glicko2 rating:
// mjDE - Rating=1.904,4 RD=64,8 ro=0,06 RI=[1774,81, 2034,05]
// AMPDE - Rating=1.370,6 RD=64,8 ro=0,06 RI=[1240,96, 1500,2]
// CPSO - Rating=1.225 RD=64,8 ro=0,06 RI=[1095,37, 1354,61]
//
// Game results:
// mjDE [win=56, lose=6, draw=0]
// 	 Against:{CPSO=[win=29, lose=2, draw=0], AMPDE=[win=27, lose=4, draw=0]}
// 	 Problems:{GMPBEval2400=[win=56, lose=6, draw=0]}
// AMPDE [win=23, lose=39, draw=0]
// 	 Against:{CPSO=[win=19, lose=12, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval2400=[win=23, lose=39, draw=0]}
// CPSO [win=14, lose=48, draw=0]
// 	 Against:{mjDE=[win=2, lose=29, draw=0], AMPDE=[win=12, lose=19, draw=0]}
// 	 Problems:{GMPBEval2400=[win=14, lose=48, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=21,11, Std-Dev(sigma)=1,58 RI=[17,95, 24,27]
// AMPDE - Mean(mu)=15,33, Std-Dev(sigma)=1,2 RI=[12,94, 17,73]
// CPSO - Mean(mu)=14,29, Std-Dev(sigma)=1,24 RI=[11,81, 16,78]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=30,23, Std-Dev(sigma)=1,48 RI=[27,28, 33,19]
// AMPDE - Mean(mu)=22,91, Std-Dev(sigma)=1,25 RI=[20,42, 25,41]
// CPSO - Mean(mu)=21,86, Std-Dev(sigma)=1,31 RI=[19,25, 24,47]
//
// Glicko2 rating:
// mjDE - Rating=1.872,1 RD=64,8 ro=0,06 RI=[1742,46, 2001,69]
// AMPDE - Rating=1.386,8 RD=64,8 ro=0,06 RI=[1257,14, 1516,38]
// CPSO - Rating=1.241,2 RD=64,8 ro=0,06 RI=[1111,55, 1370,78]
//
// Game results:
// mjDE [win=54, lose=8, draw=0]
// 	 Against:{CPSO=[win=28, lose=3, draw=0], AMPDE=[win=26, lose=5, draw=0]}
// 	 Problems:{GMPBEval2500=[win=54, lose=8, draw=0]}
// AMPDE [win=24, lose=38, draw=0]
// 	 Against:{CPSO=[win=19, lose=12, draw=0], mjDE=[win=5, lose=26, draw=0]}
// 	 Problems:{GMPBEval2500=[win=24, lose=38, draw=0]}
// CPSO [win=15, lose=47, draw=0]
// 	 Against:{mjDE=[win=3, lose=28, draw=0], AMPDE=[win=12, lose=19, draw=0]}
// 	 Problems:{GMPBEval2500=[win=15, lose=47, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=19,5, Std-Dev(sigma)=1,47 RI=[16,56, 22,43]
// AMPDE - Mean(mu)=15,62, Std-Dev(sigma)=1,19 RI=[13,24, 18,01]
// CPSO - Mean(mu)=14,26, Std-Dev(sigma)=1,23 RI=[11,8, 16,71]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=28,92, Std-Dev(sigma)=1,4 RI=[26,13, 31,72]
// AMPDE - Mean(mu)=23,91, Std-Dev(sigma)=1,22 RI=[21,47, 26,35]
// CPSO - Mean(mu)=21,97, Std-Dev(sigma)=1,3 RI=[19,37, 24,57]
//
// Glicko2 rating:
// mjDE - Rating=1.823,5 RD=64,8 ro=0,06 RI=[1693,92, 1953,16]
// AMPDE - Rating=1.435,3 RD=64,8 ro=0,06 RI=[1305,67, 1564,91]
// CPSO - Rating=1.241,2 RD=64,8 ro=0,06 RI=[1111,55, 1370,78]
//
// Game results:
// mjDE [win=51, lose=11, draw=0]
// 	 Against:{CPSO=[win=28, lose=3, draw=0], AMPDE=[win=23, lose=8, draw=0]}
// 	 Problems:{GMPBEval2600=[win=51, lose=11, draw=0]}
// AMPDE [win=27, lose=35, draw=0]
// 	 Against:{CPSO=[win=19, lose=12, draw=0], mjDE=[win=8, lose=23, draw=0]}
// 	 Problems:{GMPBEval2600=[win=27, lose=35, draw=0]}
// CPSO [win=15, lose=47, draw=0]
// 	 Against:{mjDE=[win=3, lose=28, draw=0], AMPDE=[win=12, lose=19, draw=0]}
// 	 Problems:{GMPBEval2600=[win=15, lose=47, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=18,88, Std-Dev(sigma)=1,42 RI=[16,05, 21,71]
// AMPDE - Mean(mu)=15,17, Std-Dev(sigma)=1,18 RI=[12,8, 17,54]
// CPSO - Mean(mu)=13,86, Std-Dev(sigma)=1,2 RI=[11,47, 16,25]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=28,73, Std-Dev(sigma)=1,35 RI=[26,04, 31,43]
// AMPDE - Mean(mu)=24,18, Std-Dev(sigma)=1,21 RI=[21,76, 26,59]
// CPSO - Mean(mu)=22,23, Std-Dev(sigma)=1,27 RI=[19,7, 24,77]
//
// Glicko2 rating:
// mjDE - Rating=1.807,4 RD=64,8 ro=0,06 RI=[1677,75, 1936,99]
// AMPDE - Rating=1.435,3 RD=64,8 ro=0,06 RI=[1305,67, 1564,91]
// CPSO - Rating=1.257,3 RD=64,8 ro=0,06 RI=[1127,72, 1386,96]
//
// Game results:
// mjDE [win=50, lose=12, draw=0]
// 	 Against:{CPSO=[win=28, lose=3, draw=0], AMPDE=[win=22, lose=9, draw=0]}
// 	 Problems:{GMPBEval2700=[win=50, lose=12, draw=0]}
// AMPDE [win=27, lose=35, draw=0]
// 	 Against:{CPSO=[win=18, lose=13, draw=0], mjDE=[win=9, lose=22, draw=0]}
// 	 Problems:{GMPBEval2700=[win=27, lose=35, draw=0]}
// CPSO [win=16, lose=46, draw=0]
// 	 Against:{mjDE=[win=3, lose=28, draw=0], AMPDE=[win=13, lose=18, draw=0]}
// 	 Problems:{GMPBEval2700=[win=16, lose=46, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=18,81, Std-Dev(sigma)=1,44 RI=[15,94, 21,69]
// AMPDE - Mean(mu)=15,52, Std-Dev(sigma)=1,21 RI=[13,11, 17,94]
// CPSO - Mean(mu)=13,44, Std-Dev(sigma)=1,23 RI=[10,99, 15,9]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=28,88, Std-Dev(sigma)=1,36 RI=[26,15, 31,61]
// AMPDE - Mean(mu)=24,65, Std-Dev(sigma)=1,23 RI=[22,2, 27,1]
// CPSO - Mean(mu)=21,89, Std-Dev(sigma)=1,32 RI=[19,25, 24,54]
//
// Glicko2 rating:
// mjDE - Rating=1.807,4 RD=64,8 ro=0,06 RI=[1677,75, 1936,99]
// AMPDE - Rating=1.483,8 RD=64,8 ro=0,06 RI=[1354,2, 1613,44]
// CPSO - Rating=1.208,8 RD=64,8 ro=0,06 RI=[1079,19, 1338,43]
//
// Game results:
// mjDE [win=50, lose=12, draw=0]
// 	 Against:{CPSO=[win=28, lose=3, draw=0], AMPDE=[win=22, lose=9, draw=0]}
// 	 Problems:{GMPBEval2800=[win=50, lose=12, draw=0]}
// AMPDE [win=30, lose=32, draw=0]
// 	 Against:{CPSO=[win=21, lose=10, draw=0], mjDE=[win=9, lose=22, draw=0]}
// 	 Problems:{GMPBEval2800=[win=30, lose=32, draw=0]}
// CPSO [win=13, lose=49, draw=0]
// 	 Against:{mjDE=[win=3, lose=28, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval2800=[win=13, lose=49, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=18,74, Std-Dev(sigma)=1,45 RI=[15,85, 21,63]
// AMPDE - Mean(mu)=15,86, Std-Dev(sigma)=1,21 RI=[13,43, 18,28]
// CPSO - Mean(mu)=13,08, Std-Dev(sigma)=1,24 RI=[10,6, 15,56]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=28,92, Std-Dev(sigma)=1,36 RI=[26,19, 31,65]
// AMPDE - Mean(mu)=24,97, Std-Dev(sigma)=1,23 RI=[22,51, 27,43]
// CPSO - Mean(mu)=21,5, Std-Dev(sigma)=1,34 RI=[18,82, 24,18]
//
// Glicko2 rating:
// mjDE - Rating=1.807,4 RD=64,8 ro=0,06 RI=[1677,75, 1936,99]
// AMPDE - Rating=1.500 RD=64,8 ro=0,06 RI=[1370,38, 1629,62]
// CPSO - Rating=1.192,6 RD=64,8 ro=0,06 RI=[1063,01, 1322,25]
//
// Game results:
// mjDE [win=50, lose=12, draw=0]
// 	 Against:{CPSO=[win=28, lose=3, draw=0], AMPDE=[win=22, lose=9, draw=0]}
// 	 Problems:{GMPBEval2900=[win=50, lose=12, draw=0]}
// AMPDE [win=31, lose=31, draw=0]
// 	 Against:{CPSO=[win=22, lose=9, draw=0], mjDE=[win=9, lose=22, draw=0]}
// 	 Problems:{GMPBEval2900=[win=31, lose=31, draw=0]}
// CPSO [win=12, lose=50, draw=0]
// 	 Against:{mjDE=[win=3, lose=28, draw=0], AMPDE=[win=9, lose=22, draw=0]}
// 	 Problems:{GMPBEval2900=[win=12, lose=50, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=18,33, Std-Dev(sigma)=1,42 RI=[15,49, 21,17]
// AMPDE - Mean(mu)=15,79, Std-Dev(sigma)=1,25 RI=[13,29, 18,28]
// CPSO - Mean(mu)=13,14, Std-Dev(sigma)=1,24 RI=[10,65, 15,62]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=28,3, Std-Dev(sigma)=1,35 RI=[25,59, 31,01]
// AMPDE - Mean(mu)=25,25, Std-Dev(sigma)=1,25 RI=[22,75, 27,75]
// CPSO - Mean(mu)=21,54, Std-Dev(sigma)=1,35 RI=[18,84, 24,24]
//
// Glicko2 rating:
// mjDE - Rating=1.775 RD=64,8 ro=0,06 RI=[1645,39, 1904,63]
// AMPDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.176,5 RD=64,8 ro=0,06 RI=[1046,84, 1306,08]
//
// Game results:
// mjDE [win=48, lose=14, draw=0]
// 	 Against:{CPSO=[win=28, lose=3, draw=0], AMPDE=[win=20, lose=11, draw=0]}
// 	 Problems:{GMPBEval3000=[win=48, lose=14, draw=0]}
// AMPDE [win=34, lose=28, draw=0]
// 	 Against:{CPSO=[win=23, lose=8, draw=0], mjDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval3000=[win=34, lose=28, draw=0]}
// CPSO [win=11, lose=51, draw=0]
// 	 Against:{AMPDE=[win=8, lose=23, draw=0], mjDE=[win=3, lose=28, draw=0]}
// 	 Problems:{GMPBEval3000=[win=11, lose=51, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=18,04, Std-Dev(sigma)=1,38 RI=[15,28, 20,81]
// AMPDE - Mean(mu)=15,48, Std-Dev(sigma)=1,25 RI=[12,99, 17,98]
// CPSO - Mean(mu)=13,35, Std-Dev(sigma)=1,22 RI=[10,9, 15,8]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=27,93, Std-Dev(sigma)=1,33 RI=[25,27, 30,59]
// AMPDE - Mean(mu)=25,28, Std-Dev(sigma)=1,24 RI=[22,8, 27,77]
// CPSO - Mean(mu)=21,93, Std-Dev(sigma)=1,33 RI=[19,28, 24,59]
//
// Glicko2 rating:
// mjDE - Rating=1.758,8 RD=64,8 ro=0,06 RI=[1629,22, 1888,45]
// AMPDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.192,6 RD=64,8 ro=0,06 RI=[1063,01, 1322,25]
//
// Game results:
// mjDE [win=47, lose=15, draw=0]
// 	 Against:{CPSO=[win=28, lose=3, draw=0], AMPDE=[win=19, lose=12, draw=0]}
// 	 Problems:{GMPBEval3100=[win=47, lose=15, draw=0]}
// AMPDE [win=34, lose=28, draw=0]
// 	 Against:{CPSO=[win=22, lose=9, draw=0], mjDE=[win=12, lose=19, draw=0]}
// 	 Problems:{GMPBEval3100=[win=34, lose=28, draw=0]}
// CPSO [win=12, lose=50, draw=0]
// 	 Against:{AMPDE=[win=9, lose=22, draw=0], mjDE=[win=3, lose=28, draw=0]}
// 	 Problems:{GMPBEval3100=[win=12, lose=50, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=17,9, Std-Dev(sigma)=1,4 RI=[15,09, 20,7]
// AMPDE - Mean(mu)=16,25, Std-Dev(sigma)=1,27 RI=[13,72, 18,78]
// CPSO - Mean(mu)=12,79, Std-Dev(sigma)=1,26 RI=[10,28, 15,3]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=27,88, Std-Dev(sigma)=1,34 RI=[25,2, 30,57]
// AMPDE - Mean(mu)=25,92, Std-Dev(sigma)=1,25 RI=[23,41, 28,43]
// CPSO - Mean(mu)=21,2, Std-Dev(sigma)=1,37 RI=[18,45, 23,95]
//
// Glicko2 rating:
// mjDE - Rating=1.758,8 RD=64,8 ro=0,06 RI=[1629,22, 1888,45]
// AMPDE - Rating=1.580,9 RD=64,8 ro=0,06 RI=[1451,27, 1710,5]
// CPSO - Rating=1.160,3 RD=64,8 ro=0,06 RI=[1030,66, 1289,9]
//
// Game results:
// mjDE [win=47, lose=15, draw=0]
// 	 Against:{CPSO=[win=28, lose=3, draw=0], AMPDE=[win=19, lose=12, draw=0]}
// 	 Problems:{GMPBEval3200=[win=47, lose=15, draw=0]}
// AMPDE [win=36, lose=26, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], mjDE=[win=12, lose=19, draw=0]}
// 	 Problems:{GMPBEval3200=[win=36, lose=26, draw=0]}
// CPSO [win=10, lose=52, draw=0]
// 	 Against:{AMPDE=[win=7, lose=24, draw=0], mjDE=[win=3, lose=28, draw=0]}
// 	 Problems:{GMPBEval3200=[win=10, lose=52, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=18,84, Std-Dev(sigma)=1,36 RI=[16,12, 21,56]
// AMPDE - Mean(mu)=17,31, Std-Dev(sigma)=1,26 RI=[14,8, 19,83]
// CPSO - Mean(mu)=13,89, Std-Dev(sigma)=1,22 RI=[11,45, 16,33]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=27,21, Std-Dev(sigma)=1,3 RI=[24,61, 29,81]
// AMPDE - Mean(mu)=25,72, Std-Dev(sigma)=1,23 RI=[23,26, 28,18]
// CPSO - Mean(mu)=20,88, Std-Dev(sigma)=1,32 RI=[18,24, 23,52]
//
// Glicko2 rating:
// mjDE - Rating=1.742,7 RD=64,8 ro=0,06 RI=[1613,04, 1872,28]
// AMPDE - Rating=1.580,9 RD=64,8 ro=0,06 RI=[1451,27, 1710,5]
// CPSO - Rating=1.176,5 RD=64,8 ro=0,06 RI=[1046,84, 1306,08]
//
// Game results:
// mjDE [win=46, lose=16, draw=0]
// 	 Against:{CPSO=[win=28, lose=3, draw=0], AMPDE=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval3300=[win=46, lose=16, draw=0]}
// AMPDE [win=36, lose=26, draw=0]
// 	 Against:{CPSO=[win=23, lose=8, draw=0], mjDE=[win=13, lose=18, draw=0]}
// 	 Problems:{GMPBEval3300=[win=36, lose=26, draw=0]}
// CPSO [win=11, lose=51, draw=0]
// 	 Against:{AMPDE=[win=8, lose=23, draw=0], mjDE=[win=3, lose=28, draw=0]}
// 	 Problems:{GMPBEval3300=[win=11, lose=51, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=18,69, Std-Dev(sigma)=1,35 RI=[15,98, 21,39]
// AMPDE - Mean(mu)=16,95, Std-Dev(sigma)=1,25 RI=[14,46, 19,44]
// CPSO - Mean(mu)=14,31, Std-Dev(sigma)=1,22 RI=[11,88, 16,75]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=27,06, Std-Dev(sigma)=1,3 RI=[24,46, 29,66]
// AMPDE - Mean(mu)=25,3, Std-Dev(sigma)=1,23 RI=[22,84, 27,75]
// CPSO - Mean(mu)=21,54, Std-Dev(sigma)=1,3 RI=[18,94, 24,13]
//
// Glicko2 rating:
// mjDE - Rating=1.742,7 RD=64,8 ro=0,06 RI=[1613,04, 1872,28]
// AMPDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.208,8 RD=64,8 ro=0,06 RI=[1079,19, 1338,43]
//
// Game results:
// mjDE [win=46, lose=16, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=19, lose=12, draw=0]}
// 	 Problems:{GMPBEval3400=[win=46, lose=16, draw=0]}
// AMPDE [win=34, lose=28, draw=0]
// 	 Against:{CPSO=[win=22, lose=9, draw=0], mjDE=[win=12, lose=19, draw=0]}
// 	 Problems:{GMPBEval3400=[win=34, lose=28, draw=0]}
// CPSO [win=13, lose=49, draw=0]
// 	 Against:{AMPDE=[win=9, lose=22, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval3400=[win=13, lose=49, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=18,43, Std-Dev(sigma)=1,36 RI=[15,7, 21,16]
// AMPDE - Mean(mu)=16,97, Std-Dev(sigma)=1,26 RI=[14,46, 19,48]
// CPSO - Mean(mu)=13,97, Std-Dev(sigma)=1,24 RI=[11,48, 16,45]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=27,13, Std-Dev(sigma)=1,31 RI=[24,52, 29,74]
// AMPDE - Mean(mu)=25,5, Std-Dev(sigma)=1,24 RI=[23,02, 27,97]
// CPSO - Mean(mu)=21,37, Std-Dev(sigma)=1,33 RI=[18,7, 24,03]
//
// Glicko2 rating:
// mjDE - Rating=1.742,7 RD=64,8 ro=0,06 RI=[1613,04, 1872,28]
// AMPDE - Rating=1.564,7 RD=64,8 ro=0,06 RI=[1435,09, 1694,33]
// CPSO - Rating=1.192,6 RD=64,8 ro=0,06 RI=[1063,01, 1322,25]
//
// Game results:
// mjDE [win=46, lose=16, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=19, lose=12, draw=0]}
// 	 Problems:{GMPBEval3500=[win=46, lose=16, draw=0]}
// AMPDE [win=35, lose=27, draw=0]
// 	 Against:{CPSO=[win=23, lose=8, draw=0], mjDE=[win=12, lose=19, draw=0]}
// 	 Problems:{GMPBEval3500=[win=35, lose=27, draw=0]}
// CPSO [win=12, lose=50, draw=0]
// 	 Against:{AMPDE=[win=8, lose=23, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval3500=[win=12, lose=50, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=17,45, Std-Dev(sigma)=1,33 RI=[14,8, 20,11]
// AMPDE - Mean(mu)=17,23, Std-Dev(sigma)=1,25 RI=[14,73, 19,73]
// CPSO - Mean(mu)=13,09, Std-Dev(sigma)=1,23 RI=[10,62, 15,55]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26,91, Std-Dev(sigma)=1,28 RI=[24,35, 29,46]
// AMPDE - Mean(mu)=26,22, Std-Dev(sigma)=1,23 RI=[23,77, 28,67]
// CPSO - Mean(mu)=20,96, Std-Dev(sigma)=1,34 RI=[18,29, 23,64]
//
// Glicko2 rating:
// mjDE - Rating=1.710,3 RD=64,8 ro=0,06 RI=[1580,68, 1839,92]
// AMPDE - Rating=1.613,2 RD=64,8 ro=0,06 RI=[1483,62, 1742,86]
// CPSO - Rating=1.176,5 RD=64,8 ro=0,06 RI=[1046,84, 1306,08]
//
// Game results:
// mjDE [win=44, lose=18, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval3600=[win=44, lose=18, draw=0]}
// AMPDE [win=38, lose=24, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], mjDE=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval3600=[win=38, lose=24, draw=0]}
// CPSO [win=11, lose=51, draw=0]
// 	 Against:{AMPDE=[win=7, lose=24, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval3600=[win=11, lose=51, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=17,45, Std-Dev(sigma)=1,33 RI=[14,8, 20,11]
// AMPDE - Mean(mu)=17,23, Std-Dev(sigma)=1,25 RI=[14,73, 19,73]
// CPSO - Mean(mu)=13,09, Std-Dev(sigma)=1,23 RI=[10,62, 15,55]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26,91, Std-Dev(sigma)=1,28 RI=[24,35, 29,46]
// AMPDE - Mean(mu)=26,22, Std-Dev(sigma)=1,23 RI=[23,77, 28,67]
// CPSO - Mean(mu)=20,96, Std-Dev(sigma)=1,34 RI=[18,29, 23,64]
//
// Glicko2 rating:
// mjDE - Rating=1.710,3 RD=64,8 ro=0,06 RI=[1580,68, 1839,92]
// AMPDE - Rating=1.613,2 RD=64,8 ro=0,06 RI=[1483,62, 1742,86]
// CPSO - Rating=1.176,5 RD=64,8 ro=0,06 RI=[1046,84, 1306,08]
//
// Game results:
// mjDE [win=44, lose=18, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval3700=[win=44, lose=18, draw=0]}
// AMPDE [win=38, lose=24, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], mjDE=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval3700=[win=38, lose=24, draw=0]}
// CPSO [win=11, lose=51, draw=0]
// 	 Against:{AMPDE=[win=7, lose=24, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval3700=[win=11, lose=51, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,63, Std-Dev(sigma)=1,26 RI=[15,11, 20,15]
// mjDE - Mean(mu)=17,35, Std-Dev(sigma)=1,34 RI=[14,67, 20,03]
// CPSO - Mean(mu)=12,7, Std-Dev(sigma)=1,25 RI=[10,2, 15,19]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26,94, Std-Dev(sigma)=1,28 RI=[24,38, 29,5]
// AMPDE - Mean(mu)=26,55, Std-Dev(sigma)=1,23 RI=[24,08, 29,01]
// CPSO - Mean(mu)=20,53, Std-Dev(sigma)=1,36 RI=[17,81, 23,25]
//
// Glicko2 rating:
// mjDE - Rating=1.710,3 RD=64,8 ro=0,06 RI=[1580,68, 1839,92]
// AMPDE - Rating=1.629,4 RD=64,8 ro=0,06 RI=[1499,8, 1759,04]
// CPSO - Rating=1.160,3 RD=64,8 ro=0,06 RI=[1030,66, 1289,9]
//
// Game results:
// mjDE [win=44, lose=18, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval3800=[win=44, lose=18, draw=0]}
// AMPDE [win=39, lose=23, draw=0]
// 	 Against:{CPSO=[win=25, lose=6, draw=0], mjDE=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval3800=[win=39, lose=23, draw=0]}
// CPSO [win=10, lose=52, draw=0]
// 	 Against:{AMPDE=[win=6, lose=25, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval3800=[win=10, lose=52, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,23, Std-Dev(sigma)=1,27 RI=[14,69, 19,77]
// mjDE - Mean(mu)=16,98, Std-Dev(sigma)=1,32 RI=[14,35, 19,62]
// CPSO - Mean(mu)=12,43, Std-Dev(sigma)=1,25 RI=[9,93, 14,94]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26,84, Std-Dev(sigma)=1,27 RI=[24,31, 29,38]
// AMPDE - Mean(mu)=26,64, Std-Dev(sigma)=1,24 RI=[24,16, 29,11]
// CPSO - Mean(mu)=20,66, Std-Dev(sigma)=1,38 RI=[17,91, 23,41]
//
// Glicko2 rating:
// mjDE - Rating=1.694,1 RD=64,8 ro=0,06 RI=[1564,51, 1823,74]
// AMPDE - Rating=1.645,6 RD=64,8 ro=0,06 RI=[1515,98, 1775,21]
// CPSO - Rating=1.160,3 RD=64,8 ro=0,06 RI=[1030,66, 1289,9]
//
// Game results:
// mjDE [win=43, lose=19, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval3900=[win=43, lose=19, draw=0]}
// AMPDE [win=40, lose=22, draw=0]
// 	 Against:{CPSO=[win=25, lose=6, draw=0], mjDE=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval3900=[win=40, lose=22, draw=0]}
// CPSO [win=10, lose=52, draw=0]
// 	 Against:{AMPDE=[win=6, lose=25, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval3900=[win=10, lose=52, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,82, Std-Dev(sigma)=1,27 RI=[15,27, 20,37]
// mjDE - Mean(mu)=17,42, Std-Dev(sigma)=1,35 RI=[14,73, 20,12]
// CPSO - Mean(mu)=12,94, Std-Dev(sigma)=1,26 RI=[10,41, 15,46]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26,79, Std-Dev(sigma)=1,29 RI=[24,21, 29,38]
// AMPDE - Mean(mu)=26,56, Std-Dev(sigma)=1,24 RI=[24,08, 29,05]
// CPSO - Mean(mu)=20,55, Std-Dev(sigma)=1,38 RI=[17,79, 23,3]
//
// Glicko2 rating:
// mjDE - Rating=1.710,3 RD=64,8 ro=0,06 RI=[1580,68, 1839,92]
// AMPDE - Rating=1.629,4 RD=64,8 ro=0,06 RI=[1499,8, 1759,04]
// CPSO - Rating=1.160,3 RD=64,8 ro=0,06 RI=[1030,66, 1289,9]
//
// Game results:
// mjDE [win=44, lose=18, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval4000=[win=44, lose=18, draw=0]}
// AMPDE [win=39, lose=23, draw=0]
// 	 Against:{CPSO=[win=25, lose=6, draw=0], mjDE=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval4000=[win=39, lose=23, draw=0]}
// CPSO [win=10, lose=52, draw=0]
// 	 Against:{AMPDE=[win=6, lose=25, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval4000=[win=10, lose=52, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=18,02, Std-Dev(sigma)=1,29 RI=[15,43, 20,6]
// mjDE - Mean(mu)=17,07, Std-Dev(sigma)=1,34 RI=[14,4, 19,75]
// CPSO - Mean(mu)=12,28, Std-Dev(sigma)=1,27 RI=[9,73, 14,83]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,01, Std-Dev(sigma)=1,25 RI=[24,52, 29,51]
// mjDE - Mean(mu)=26,71, Std-Dev(sigma)=1,28 RI=[24,14, 29,27]
// CPSO - Mean(mu)=20,07, Std-Dev(sigma)=1,4 RI=[17,26, 22,88]
//
// Glicko2 rating:
// mjDE - Rating=1.694,1 RD=64,8 ro=0,06 RI=[1564,51, 1823,74]
// AMPDE - Rating=1.661,8 RD=64,8 ro=0,06 RI=[1532,15, 1791,39]
// CPSO - Rating=1.144,1 RD=64,8 ro=0,06 RI=[1014,48, 1273,72]
//
// Game results:
// mjDE [win=43, lose=19, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval4100=[win=43, lose=19, draw=0]}
// AMPDE [win=41, lose=21, draw=0]
// 	 Against:{CPSO=[win=26, lose=5, draw=0], mjDE=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval4100=[win=41, lose=21, draw=0]}
// CPSO [win=9, lose=53, draw=0]
// 	 Against:{AMPDE=[win=5, lose=26, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval4100=[win=9, lose=53, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=18,35, Std-Dev(sigma)=1,3 RI=[15,76, 20,94]
// mjDE - Mean(mu)=17,57, Std-Dev(sigma)=1,35 RI=[14,87, 20,27]
// CPSO - Mean(mu)=12,86, Std-Dev(sigma)=1,25 RI=[10,35, 15,36]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=26,91, Std-Dev(sigma)=1,25 RI=[24,41, 29,41]
// mjDE - Mean(mu)=26,74, Std-Dev(sigma)=1,3 RI=[24,14, 29,33]
// CPSO - Mean(mu)=20,16, Std-Dev(sigma)=1,38 RI=[17,41, 22,92]
//
// Glicko2 rating:
// mjDE - Rating=1.710,3 RD=64,8 ro=0,06 RI=[1580,68, 1839,92]
// AMPDE - Rating=1.645,6 RD=64,8 ro=0,06 RI=[1515,98, 1775,21]
// CPSO - Rating=1.144,1 RD=64,8 ro=0,06 RI=[1014,48, 1273,72]
//
// Game results:
// mjDE [win=44, lose=18, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval4200=[win=44, lose=18, draw=0]}
// AMPDE [win=40, lose=22, draw=0]
// 	 Against:{CPSO=[win=26, lose=5, draw=0], mjDE=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval4200=[win=40, lose=22, draw=0]}
// CPSO [win=9, lose=53, draw=0]
// 	 Against:{AMPDE=[win=5, lose=26, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval4200=[win=9, lose=53, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=18,7, Std-Dev(sigma)=1,31 RI=[16,08, 21,33]
// mjDE - Mean(mu)=17,4, Std-Dev(sigma)=1,36 RI=[14,67, 20,13]
// CPSO - Mean(mu)=12,48, Std-Dev(sigma)=1,28 RI=[9,92, 15,03]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=27,22, Std-Dev(sigma)=1,26 RI=[24,7, 29,74]
// mjDE - Mean(mu)=26,79, Std-Dev(sigma)=1,3 RI=[24,19, 29,39]
// CPSO - Mean(mu)=19,75, Std-Dev(sigma)=1,41 RI=[16,93, 22,57]
//
// Glicko2 rating:
// mjDE - Rating=1.710,3 RD=64,8 ro=0,06 RI=[1580,68, 1839,92]
// AMPDE - Rating=1.661,8 RD=64,8 ro=0,06 RI=[1532,15, 1791,39]
// CPSO - Rating=1.127,9 RD=64,8 ro=0,06 RI=[998,31, 1257,54]
//
// Game results:
// mjDE [win=44, lose=18, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], AMPDE=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval4300=[win=44, lose=18, draw=0]}
// AMPDE [win=41, lose=21, draw=0]
// 	 Against:{CPSO=[win=27, lose=4, draw=0], mjDE=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval4300=[win=41, lose=21, draw=0]}
// CPSO [win=8, lose=54, draw=0]
// 	 Against:{AMPDE=[win=4, lose=27, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval4300=[win=8, lose=54, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=18,35, Std-Dev(sigma)=1,3 RI=[15,76, 20,94]
// mjDE - Mean(mu)=17,57, Std-Dev(sigma)=1,35 RI=[14,87, 20,27]
// CPSO - Mean(mu)=12,86, Std-Dev(sigma)=1,25 RI=[10,35, 15,36]
//
// TrueSkill Free-For-All rating:
// ...
// CPSO - Rating=1.144,1 RD=64,8 ro=0,06 RI=[1014,48, 1273,72]
//
// Game results:
// AMPDE [win=49, lose=13, draw=0]
// 	 Against:{CPSO=[win=29, lose=2, draw=0], mjDE=[win=20, lose=11, draw=0]}
// 	 Problems:{GMPBEval7400=[win=49, lose=13, draw=0]}
// mjDE [win=35, lose=27, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval7400=[win=35, lose=27, draw=0]}
// CPSO [win=9, lose=53, draw=0]
// 	 Against:{AMPDE=[win=2, lose=29, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval7400=[win=9, lose=53, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=18,25, Std-Dev(sigma)=1,49 RI=[15,28, 21,23]
// mjDE - Mean(mu)=14,59, Std-Dev(sigma)=1,29 RI=[12,01, 17,16]
// CPSO - Mean(mu)=11,5, Std-Dev(sigma)=1,34 RI=[8,82, 14,18]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=29,41, Std-Dev(sigma)=1,36 RI=[26,68, 32,14]
// mjDE - Mean(mu)=25,78, Std-Dev(sigma)=1,27 RI=[23,24, 28,31]
// CPSO - Mean(mu)=21,48, Std-Dev(sigma)=1,47 RI=[18,55, 24,42]
//
// Glicko2 rating:
// AMPDE - Rating=1.791,2 RD=64,8 ro=0,06 RI=[1661,57, 1920,81]
// mjDE - Rating=1.564,7 RD=64,8 ro=0,06 RI=[1435,09, 1694,33]
// CPSO - Rating=1.144,1 RD=64,8 ro=0,06 RI=[1014,48, 1273,72]
//
// Game results:
// AMPDE [win=49, lose=13, draw=0]
// 	 Against:{CPSO=[win=29, lose=2, draw=0], mjDE=[win=20, lose=11, draw=0]}
// 	 Problems:{GMPBEval7500=[win=49, lose=13, draw=0]}
// mjDE [win=35, lose=27, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval7500=[win=35, lose=27, draw=0]}
// CPSO [win=9, lose=53, draw=0]
// 	 Against:{AMPDE=[win=2, lose=29, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval7500=[win=9, lose=53, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=17,3, Std-Dev(sigma)=1,52 RI=[14,26, 20,34]
// mjDE - Mean(mu)=13,74, Std-Dev(sigma)=1,32 RI=[11,1, 16,37]
// CPSO - Mean(mu)=10,49, Std-Dev(sigma)=1,4 RI=[7,69, 13,29]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=29,71, Std-Dev(sigma)=1,38 RI=[26,95, 32,48]
// mjDE - Mean(mu)=26,04, Std-Dev(sigma)=1,3 RI=[23,44, 28,64]
// CPSO - Mean(mu)=21,77, Std-Dev(sigma)=1,58 RI=[18,6, 24,93]
//
// Glicko2 rating:
// AMPDE - Rating=1.791,2 RD=64,8 ro=0,06 RI=[1661,57, 1920,81]
// mjDE - Rating=1.580,9 RD=64,8 ro=0,06 RI=[1451,27, 1710,5]
// CPSO - Rating=1.127,9 RD=64,8 ro=0,06 RI=[998,31, 1257,54]
//
// Game results:
// AMPDE [win=49, lose=13, draw=0]
// 	 Against:{CPSO=[win=29, lose=2, draw=0], mjDE=[win=20, lose=11, draw=0]}
// 	 Problems:{GMPBEval7600=[win=49, lose=13, draw=0]}
// mjDE [win=36, lose=26, draw=0]
// 	 Against:{CPSO=[win=25, lose=6, draw=0], AMPDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval7600=[win=36, lose=26, draw=0]}
// CPSO [win=8, lose=54, draw=0]
// 	 Against:{AMPDE=[win=2, lose=29, draw=0], mjDE=[win=6, lose=25, draw=0]}
// 	 Problems:{GMPBEval7600=[win=8, lose=54, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=18,25, Std-Dev(sigma)=1,49 RI=[15,28, 21,23]
// mjDE - Mean(mu)=14,59, Std-Dev(sigma)=1,29 RI=[12,01, 17,16]
// CPSO - Mean(mu)=11,5, Std-Dev(sigma)=1,34 RI=[8,82, 14,18]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=29,41, Std-Dev(sigma)=1,36 RI=[26,68, 32,14]
// mjDE - Mean(mu)=25,78, Std-Dev(sigma)=1,27 RI=[23,24, 28,31]
// CPSO - Mean(mu)=21,48, Std-Dev(sigma)=1,47 RI=[18,55, 24,42]
//
// Glicko2 rating:
// AMPDE - Rating=1.791,2 RD=64,8 ro=0,06 RI=[1661,57, 1920,81]
// mjDE - Rating=1.564,7 RD=64,8 ro=0,06 RI=[1435,09, 1694,33]
// CPSO - Rating=1.144,1 RD=64,8 ro=0,06 RI=[1014,48, 1273,72]
//
// Game results:
// AMPDE [win=49, lose=13, draw=0]
// 	 Against:{CPSO=[win=29, lose=2, draw=0], mjDE=[win=20, lose=11, draw=0]}
// 	 Problems:{GMPBEval7700=[win=49, lose=13, draw=0]}
// mjDE [win=35, lose=27, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval7700=[win=35, lose=27, draw=0]}
// CPSO [win=9, lose=53, draw=0]
// 	 Against:{AMPDE=[win=2, lose=29, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval7700=[win=9, lose=53, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=18,42, Std-Dev(sigma)=1,52 RI=[15,38, 21,47]
// mjDE - Mean(mu)=14,79, Std-Dev(sigma)=1,29 RI=[12,21, 17,37]
// CPSO - Mean(mu)=11,7, Std-Dev(sigma)=1,35 RI=[9, 14,39]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=29,31, Std-Dev(sigma)=1,41 RI=[26,5, 32,12]
// mjDE - Mean(mu)=25,47, Std-Dev(sigma)=1,28 RI=[22,9, 28,04]
// CPSO - Mean(mu)=21,23, Std-Dev(sigma)=1,48 RI=[18,26, 24,2]
//
// Glicko2 rating:
// AMPDE - Rating=1.807,4 RD=64,8 ro=0,06 RI=[1677,75, 1936,99]
// mjDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.144,1 RD=64,8 ro=0,06 RI=[1014,48, 1273,72]
//
// Game results:
// AMPDE [win=50, lose=12, draw=0]
// 	 Against:{CPSO=[win=29, lose=2, draw=0], mjDE=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval7800=[win=50, lose=12, draw=0]}
// mjDE [win=34, lose=28, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval7800=[win=34, lose=28, draw=0]}
// CPSO [win=9, lose=53, draw=0]
// 	 Against:{AMPDE=[win=2, lose=29, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval7800=[win=9, lose=53, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=18,25, Std-Dev(sigma)=1,49 RI=[15,28, 21,23]
// mjDE - Mean(mu)=14,59, Std-Dev(sigma)=1,29 RI=[12,01, 17,16]
// CPSO - Mean(mu)=11,5, Std-Dev(sigma)=1,34 RI=[8,82, 14,18]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=29,41, Std-Dev(sigma)=1,36 RI=[26,68, 32,14]
// mjDE - Mean(mu)=25,78, Std-Dev(sigma)=1,27 RI=[23,24, 28,31]
// CPSO - Mean(mu)=21,48, Std-Dev(sigma)=1,47 RI=[18,55, 24,42]
//
// Glicko2 rating:
// AMPDE - Rating=1.791,2 RD=64,8 ro=0,06 RI=[1661,57, 1920,81]
// mjDE - Rating=1.564,7 RD=64,8 ro=0,06 RI=[1435,09, 1694,33]
// CPSO - Rating=1.144,1 RD=64,8 ro=0,06 RI=[1014,48, 1273,72]
//
// Game results:
// AMPDE [win=49, lose=13, draw=0]
// 	 Against:{CPSO=[win=29, lose=2, draw=0], mjDE=[win=20, lose=11, draw=0]}
// 	 Problems:{GMPBEval7900=[win=49, lose=13, draw=0]}
// mjDE [win=35, lose=27, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval7900=[win=35, lose=27, draw=0]}
// CPSO [win=9, lose=53, draw=0]
// 	 Against:{AMPDE=[win=2, lose=29, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval7900=[win=9, lose=53, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=19,57, Std-Dev(sigma)=1,55 RI=[16,47, 22,66]
// mjDE - Mean(mu)=14,45, Std-Dev(sigma)=1,3 RI=[11,84, 17,05]
// CPSO - Mean(mu)=11,58, Std-Dev(sigma)=1,35 RI=[8,89, 14,28]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=30,1, Std-Dev(sigma)=1,4 RI=[27,31, 32,9]
// mjDE - Mean(mu)=25,43, Std-Dev(sigma)=1,28 RI=[22,87, 27,98]
// CPSO - Mean(mu)=21,08, Std-Dev(sigma)=1,48 RI=[18,11, 24,05]
//
// Glicko2 rating:
// AMPDE - Rating=1.823,5 RD=64,8 ro=0,06 RI=[1693,92, 1953,16]
// mjDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.127,9 RD=64,8 ro=0,06 RI=[998,31, 1257,54]
//
// Game results:
// AMPDE [win=51, lose=11, draw=0]
// 	 Against:{CPSO=[win=30, lose=1, draw=0], mjDE=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval8000=[win=51, lose=11, draw=0]}
// mjDE [win=34, lose=28, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval8000=[win=34, lose=28, draw=0]}
// CPSO [win=8, lose=54, draw=0]
// 	 Against:{AMPDE=[win=1, lose=30, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval8000=[win=8, lose=54, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=19,57, Std-Dev(sigma)=1,55 RI=[16,47, 22,66]
// mjDE - Mean(mu)=14,45, Std-Dev(sigma)=1,3 RI=[11,84, 17,05]
// CPSO - Mean(mu)=11,58, Std-Dev(sigma)=1,35 RI=[8,89, 14,28]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=30,1, Std-Dev(sigma)=1,4 RI=[27,31, 32,9]
// mjDE - Mean(mu)=25,43, Std-Dev(sigma)=1,28 RI=[22,87, 27,98]
// CPSO - Mean(mu)=21,08, Std-Dev(sigma)=1,48 RI=[18,11, 24,05]
//
// Glicko2 rating:
// AMPDE - Rating=1.823,5 RD=64,8 ro=0,06 RI=[1693,92, 1953,16]
// mjDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.127,9 RD=64,8 ro=0,06 RI=[998,31, 1257,54]
//
// Game results:
// AMPDE [win=51, lose=11, draw=0]
// 	 Against:{CPSO=[win=30, lose=1, draw=0], mjDE=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval8100=[win=51, lose=11, draw=0]}
// mjDE [win=34, lose=28, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval8100=[win=34, lose=28, draw=0]}
// CPSO [win=8, lose=54, draw=0]
// 	 Against:{AMPDE=[win=1, lose=30, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval8100=[win=8, lose=54, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=19,57, Std-Dev(sigma)=1,55 RI=[16,47, 22,66]
// mjDE - Mean(mu)=14,45, Std-Dev(sigma)=1,3 RI=[11,84, 17,05]
// CPSO - Mean(mu)=11,58, Std-Dev(sigma)=1,35 RI=[8,89, 14,28]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=30,1, Std-Dev(sigma)=1,4 RI=[27,31, 32,9]
// mjDE - Mean(mu)=25,43, Std-Dev(sigma)=1,28 RI=[22,87, 27,98]
// CPSO - Mean(mu)=21,08, Std-Dev(sigma)=1,48 RI=[18,11, 24,05]
//
// Glicko2 rating:
// AMPDE - Rating=1.823,5 RD=64,8 ro=0,06 RI=[1693,92, 1953,16]
// mjDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.127,9 RD=64,8 ro=0,06 RI=[998,31, 1257,54]
//
// Game results:
// AMPDE [win=51, lose=11, draw=0]
// 	 Against:{CPSO=[win=30, lose=1, draw=0], mjDE=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval8200=[win=51, lose=11, draw=0]}
// mjDE [win=34, lose=28, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval8200=[win=34, lose=28, draw=0]}
// CPSO [win=8, lose=54, draw=0]
// 	 Against:{AMPDE=[win=1, lose=30, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval8200=[win=8, lose=54, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=19,57, Std-Dev(sigma)=1,55 RI=[16,47, 22,66]
// mjDE - Mean(mu)=14,45, Std-Dev(sigma)=1,3 RI=[11,84, 17,05]
// CPSO - Mean(mu)=11,58, Std-Dev(sigma)=1,35 RI=[8,89, 14,28]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=30,1, Std-Dev(sigma)=1,4 RI=[27,31, 32,9]
// mjDE - Mean(mu)=25,43, Std-Dev(sigma)=1,28 RI=[22,87, 27,98]
// CPSO - Mean(mu)=21,08, Std-Dev(sigma)=1,48 RI=[18,11, 24,05]
//
// Glicko2 rating:
// AMPDE - Rating=1.823,5 RD=64,8 ro=0,06 RI=[1693,92, 1953,16]
// mjDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.127,9 RD=64,8 ro=0,06 RI=[998,31, 1257,54]
//
// Game results:
// AMPDE [win=51, lose=11, draw=0]
// 	 Against:{CPSO=[win=30, lose=1, draw=0], mjDE=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval8300=[win=51, lose=11, draw=0]}
// mjDE [win=34, lose=28, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval8300=[win=34, lose=28, draw=0]}
// CPSO [win=8, lose=54, draw=0]
// 	 Against:{AMPDE=[win=1, lose=30, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval8300=[win=8, lose=54, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=19,57, Std-Dev(sigma)=1,55 RI=[16,47, 22,66]
// mjDE - Mean(mu)=14,45, Std-Dev(sigma)=1,3 RI=[11,84, 17,05]
// CPSO - Mean(mu)=11,58, Std-Dev(sigma)=1,35 RI=[8,89, 14,28]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=30,1, Std-Dev(sigma)=1,4 RI=[27,31, 32,9]
// mjDE - Mean(mu)=25,43, Std-Dev(sigma)=1,28 RI=[22,87, 27,98]
// CPSO - Mean(mu)=21,08, Std-Dev(sigma)=1,48 RI=[18,11, 24,05]
//
// Glicko2 rating:
// AMPDE - Rating=1.823,5 RD=64,8 ro=0,06 RI=[1693,92, 1953,16]
// mjDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.127,9 RD=64,8 ro=0,06 RI=[998,31, 1257,54]
//
// Game results:
// AMPDE [win=51, lose=11, draw=0]
// 	 Against:{CPSO=[win=30, lose=1, draw=0], mjDE=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval8400=[win=51, lose=11, draw=0]}
// mjDE [win=34, lose=28, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval8400=[win=34, lose=28, draw=0]}
// CPSO [win=8, lose=54, draw=0]
// 	 Against:{AMPDE=[win=1, lose=30, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval8400=[win=8, lose=54, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=19,57, Std-Dev(sigma)=1,55 RI=[16,47, 22,66]
// mjDE - Mean(mu)=14,45, Std-Dev(sigma)=1,3 RI=[11,84, 17,05]
// CPSO - Mean(mu)=11,58, Std-Dev(sigma)=1,35 RI=[8,89, 14,28]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=30,1, Std-Dev(sigma)=1,4 RI=[27,31, 32,9]
// mjDE - Mean(mu)=25,43, Std-Dev(sigma)=1,28 RI=[22,87, 27,98]
// CPSO - Mean(mu)=21,08, Std-Dev(sigma)=1,48 RI=[18,11, 24,05]
//
// Glicko2 rating:
// AMPDE - Rating=1.823,5 RD=64,8 ro=0,06 RI=[1693,92, 1953,16]
// mjDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.127,9 RD=64,8 ro=0,06 RI=[998,31, 1257,54]
//
// Game results:
// AMPDE [win=51, lose=11, draw=0]
// 	 Against:{CPSO=[win=30, lose=1, draw=0], mjDE=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval8500=[win=51, lose=11, draw=0]}
// mjDE [win=34, lose=28, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval8500=[win=34, lose=28, draw=0]}
// CPSO [win=8, lose=54, draw=0]
// 	 Against:{AMPDE=[win=1, lose=30, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval8500=[win=8, lose=54, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=19,57, Std-Dev(sigma)=1,55 RI=[16,47, 22,66]
// mjDE - Mean(mu)=14,45, Std-Dev(sigma)=1,3 RI=[11,84, 17,05]
// CPSO - Mean(mu)=11,58, Std-Dev(sigma)=1,35 RI=[8,89, 14,28]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=30,1, Std-Dev(sigma)=1,4 RI=[27,31, 32,9]
// mjDE - Mean(mu)=25,43, Std-Dev(sigma)=1,28 RI=[22,87, 27,98]
// CPSO - Mean(mu)=21,08, Std-Dev(sigma)=1,48 RI=[18,11, 24,05]
//
// Glicko2 rating:
// AMPDE - Rating=1.823,5 RD=64,8 ro=0,06 RI=[1693,92, 1953,16]
// mjDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.127,9 RD=64,8 ro=0,06 RI=[998,31, 1257,54]
//
// Game results:
// AMPDE [win=51, lose=11, draw=0]
// 	 Against:{CPSO=[win=30, lose=1, draw=0], mjDE=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval8600=[win=51, lose=11, draw=0]}
// mjDE [win=34, lose=28, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval8600=[win=34, lose=28, draw=0]}
// CPSO [win=8, lose=54, draw=0]
// 	 Against:{AMPDE=[win=1, lose=30, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval8600=[win=8, lose=54, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=19,57, Std-Dev(sigma)=1,55 RI=[16,47, 22,66]
// mjDE - Mean(mu)=14,45, Std-Dev(sigma)=1,3 RI=[11,84, 17,05]
// CPSO - Mean(mu)=11,58, Std-Dev(sigma)=1,35 RI=[8,89, 14,28]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=30,1, Std-Dev(sigma)=1,4 RI=[27,31, 32,9]
// mjDE - Mean(mu)=25,43, Std-Dev(sigma)=1,28 RI=[22,87, 27,98]
// CPSO - Mean(mu)=21,08, Std-Dev(sigma)=1,48 RI=[18,11, 24,05]
//
// Glicko2 rating:
// AMPDE - Rating=1.823,5 RD=64,8 ro=0,06 RI=[1693,92, 1953,16]
// mjDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.127,9 RD=64,8 ro=0,06 RI=[998,31, 1257,54]
//
// Game results:
// AMPDE [win=51, lose=11, draw=0]
// 	 Against:{CPSO=[win=30, lose=1, draw=0], mjDE=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval8700=[win=51, lose=11, draw=0]}
// mjDE [win=34, lose=28, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval8700=[win=34, lose=28, draw=0]}
// CPSO [win=8, lose=54, draw=0]
// 	 Against:{AMPDE=[win=1, lose=30, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval8700=[win=8, lose=54, draw=0]}
// TrueSkill One-On-One rating:
// AMPDE - Mean(mu)=19,57, Std-Dev(sigma)=1,55 RI=[16,47, 22,66]
// mjDE - Mean(mu)=14,45, Std-Dev(sigma)=1,3 RI=[11,84, 17,05]
// CPSO - Mean(mu)=11,58, Std-Dev(sigma)=1,35 RI=[8,89, 14,28]
//
// TrueSkill Free-For-All rating:
// AMPDE - Mean(mu)=30,1, Std-Dev(sigma)=1,4 RI=[27,31, 32,9]
// mjDE - Mean(mu)=25,43, Std-Dev(sigma)=1,28 RI=[22,87, 27,98]
// CPSO - Mean(mu)=21,08, Std-Dev(sigma)=1,48 RI=[18,11, 24,05]
//
// Glicko2 rating:
// AMPDE - Rating=1.823,5 RD=64,8 ro=0,06 RI=[1693,92, 1953,16]
// mjDE - Rating=1.548,5 RD=64,8 ro=0,06 RI=[1418,91, 1678,15]
// CPSO - Rating=1.127,9 RD=64,8 ro=0,06 RI=[998,31, 1257,54]
//
// Game results:
// AMPDE [win=51, lose=11, draw=0]
// 	 Against:{CPSO=[win=30, lose=1, draw=0], mjDE=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval8800=[win=51, lose=11, draw=0]}
// mjDE [win=34, lose=28, draw=0]
// 	 Against:{CPSO=[win=24, lose=7, draw=0], AMPDE=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval8800=[win=34, lose=28, draw=0]}
// CPSO [win=8, lose=54, draw=0]
// 	 Against:{AMPDE=[win=1

// %% [markdown]
// #### Visualize the results of dynamic optimization algorithms comparison
//
// A function that generates a sequence of evaluation numbers, increasing by sampleInterval, and adds an extra (evaluation) number immediately after each environment change.

// %%
fun generateSequence(changeFrequency: Int, environmentNumber: Int, sampleInterval: Int = 1000): List<Int> {
    val result = mutableListOf<Int>()
    // generate numbers increasing by sampleInterval
    for (i in sampleInterval..changeFrequency * environmentNumber step sampleInterval) {
        result.add(i)
        if (i % changeFrequency == 0 && i != changeFrequency * environmentNumber) {
            result.add(i + 1)   // add the next (evaluation) number just after the change happens
        }
    }
    return result
}

// %% [markdown]
// Import necessary classes from the letsPlot library, determine the number of algorithms, generate a sequence of x-values, and create the base plot, mapping the evaluation numbers to the "eval" key.

// %%
import org.jetbrains.letsPlot.commons.values.Color

val numAlgorithms = algPerf.size
val xValues = generateSequence(changeFrequency, environmentNumber, sampleInterval)

var plot = letsPlot(mapOf("eval" to xValues))

// %% [markdown]
// For each algorithm, extract rating values and calculate the lower and upper bounds for rating deviations. Prepare data for plotting, including evaluation numbers, ratings, bounds, and algorithm labels. Add a line plot, a ribbon for rating deviations, and points to the plot for each algorithm.

// %%
for (i in 0 until numAlgorithms) {
    val yValues = algPerf[i].evalData.values.map { it.rating } // // extract the rating values for the current algorithm

    // calculate the lower and upper bounds for the rating deviations
    val lowerBounds = algPerf[i].evalData.values.map { it.rating - 2 * it.ratingDeviation }
    val upperBounds = algPerf[i].evalData.values.map { it.rating + 2 * it.ratingDeviation }

    // prepare data for the current algorithm
    val data = mapOf(
        "eval" to xValues,
        "rating" to yValues,
        "lowerBounds" to lowerBounds,
        "upperBounds" to upperBounds,
        "Algorithm" to List(yValues.size) { algPerf[i].name }  // label each algorithm
    )

    // add rating line to the plot (cycling through predefined colors)
    plot += geomLine(data = data) {
        x = "eval"
        y = "rating"
        color = "Algorithm"
    }

    // add rating deviation ribbon to the plot (using the same color with transparency)
    plot += geomRibbon(data = data, alpha = 0.2) {
        x = "eval"
        ymin = "lowerBounds"
        ymax = "upperBounds"
        color = "Algorithm"
        fill = "Algorithm"
    }

    // add points at the same locations as the line
    plot += geomPoint(data = data) {
        x = "eval"
        y = "rating"
        color = "Algorithm"
    }
}

// %% [markdown]
// Find the minimum and maximum ratings in the entire comparison if you want to zoom in on the plot.

// %%
val allRatings = algPerf.flatMap { it.evalData.values.map { it.rating } }
val minY = allRatings.minOrNull() ?: 0.0
val maxY = allRatings.maxOrNull() ?: 1.0

//plot += scaleYContinuous(limits = minY to maxY)

// %% [markdown]
// Define the range of x-values (evaluations) you want to show on the plot.

// %%
val minX = 1000
val maxX = 25000

plot += scaleXContinuous(
    breaks = xValues,
    labels = xValues.map { it.toInt().toString() }, // specify the tick marks   .take(valuesToShow)
    limits = minX to maxX
)

// %% [markdown]
// Optionally add vertical lines (at the evaluation where change happens).

// %%
val verticalLines = (changeFrequency..changeFrequency * environmentNumber step changeFrequency).toList()
verticalLines.forEach { evalPoint ->
    plot += geomVLine(xintercept = evalPoint, color = "grey", linetype = "dashed") {
        // you can customize the appearance here
    }
}

// %% [markdown]
// Define the plot's title, width, and height and show it.

// %%
val title = "Dynamic optimization algorithms ratings during optimization"
val width = 2500
val height = 750

plot += ggsize(width, height)
plot += ggtitle(title)
plot += ggtb()  // enable Zoom and Pan interactivity

plot.show()
// Out:
//    <div id="CMIgWo"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("CMIgWo");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "ggtitle":{
// "text":"Dynamic optimization algorithms ratings during optimization"
// },
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":2500.0,
// "height":750.0
// },
// "kind":"plot",
// "ggtoolbar":{
// },
// "scales":[{
// "aesthetic":"x",
// "breaks":[100.0,200.0,300.0,400.0,500.0,600.0,700.0,800.0,900.0,1000.0,1100.0,1200.0,1300.0,1400.0,1500.0,1600.0,1700.0,1800.0,1900.0,2000.0,2100.0,2200.0,2300.0,2400.0,2500.0,2600.0,2700.0,2800.0,2900.0,3000.0,3100.0,3200.0,3300.0,3400.0,3500.0,3600.0,3700.0,3800.0,3900.0,4000.0,4100.0,4200.0,4300.0,4400.0,4500.0,4600.0,4700.0,4800.0,4900.0,5000.0,5001.0,5100.0,5200.0,5300.0,5400.0,5500.0,5600.0,5700.0,5800.0,5900.0,6000.0,6100.0,6200.0,6300.0,6400.0,6500.0,6600.0,6700.0,6800.0,6900.0,7000.0,7100.0,7200.0,7300.0,7400.0,7500.0,7600.0,7700.0,7800.0,7900.0,8000.0,8100.0,8200.0,8300.0,8400.0,8500.0,8600.0,8700.0,8800.0,8900.0,9000.0,9100.0,9200.0,9300.0,9400.0,9500.0,9600.0,9700.0,9800.0,9900.0,10000.0,10001.0,10100.0,10200.0,10300.0,10400.0,10500.0,10600.0,10700.0,10800.0,10900.0,11000.0,11100.0,11200.0,11300.0,11400.0,11500.0,11600.0,11700.0,11800.0,11900.0,12000.0,12100.0,12200.0,12300.0,12400.0,12500.0,12600.0,12700.0,12800.0,12900.0,13000.0,13100.0,13200.0,13300.0,13400.0,13500.0,13600.0,13700.0,13800.0,13900.0,14000.0,14100.0,14200.0,14300.0,14400.0,14500.0,14600.0,14700.0,14800.0,14900.0,15000.0,15001.0,15100.0,15200.0,15300.0,15400.0,15500.0,15600.0,15700.0,15800.0,15900.0,16000.0,16100.0,16200.0,16300.0,16400.0,16500.0,16600.0,16700.0,16800.0,16900.0,17000.0,17100.0,17200.0,17300.0,17400.0,17500.0,17600.0,17700.0,17800.0,17900.0,18000.0,18100.0,18200.0,18300.0,18400.0,18500.0,18600.0,18700.0,18800.0,18900.0,19000.0,19100.0,19200.0,19300.0,19400.0,19500.0,19600.0,19700.0,19800.0,19900.0,20000.0,20001.0,20100.0,20200.0,20300.0,20400.0,20500.0,20600.0,20700.0,20800.0,20900.0,21000.0,21100.0,21200.0,21300.0,21400.0,21500.0,21600.0,21700.0,21800.0,21900.0,22000.0,22100.0,22200.0,22300.0,22400.0,22500.0,22600.0,22700.0,22800.0,22900.0,23000.0,23100.0,23200.0,23300.0,23400.0,23500.0,23600.0,23700.0,23800.0,23900.0,24000.0,24100.0,24200.0,24300.0,24400.0,24500.0,24600.0,24700.0,24800.0,24900.0,25000.0,25001.0,25100.0,25200.0,25300.0,25400.0,25500.0,25600.0,25700.0,25800.0,25900.0,26000.0,26100.0,26200.0,26300.0,26400.0,26500.0,26600.0,26700.0,26800.0,26900.0,27000.0,27100.0,27200.0,27300.0,27400.0,27500.0,27600.0,27700.0,27800.0,27900.0,28000.0,28100.0,28200.0,28300.0,28400.0,28500.0,28600.0,28700.0,28800.0,28900.0,29000.0,29100.0,29200.0,29300.0,29400.0,29500.0,29600.0,29700.0,29800.0,29900.0,30000.0,30001.0,30100.0,30200.0,30300.0,30400.0,30500.0,30600.0,30700.0,30800.0,30900.0,31000.0,31100.0,31200.0,31300.0,31400.0,31500.0,31600.0,31700.0,31800.0,31900.0,32000.0,32100.0,32200.0,32300.0,32400.0,32500.0,32600.0,32700.0,32800.0,32900.0,33000.0,33100.0,33200.0,33300.0,33400.0,33500.0,33600.0,33700.0,33800.0,33900.0,34000.0,34100.0,34200.0,34300.0,34400.0,34500.0,34600.0,34700.0,34800.0,34900.0,35000.0,35001.0,35100.0,35200.0,35300.0,35400.0,35500.0,35600.0,35700.0,35800.0,35900.0,36000.0,36100.0,36200.0,36300.0,36400.0,36500.0,36600.0,36700.0,36800.0,36900.0,37000.0,37100.0,37200.0,37300.0,37400.0,37500.0,37600.0,37700.0,37800.0,37900.0,38000.0,38100.0,38200.0,38300.0,38400.0,38500.0,38600.0,38700.0,38800.0,38900.0,39000.0,39100.0,39200.0,39300.0,39400.0,39500.0,39600.0,39700.0,39800.0,39900.0,40000.0,40001.0,40100.0,40200.0,40300.0,40400.0,40500.0,40600.0,40700.0,40800.0,40900.0,41000.0,41100.0,41200.0,41300.0,41400.0,41500.0,41600.0,41700.0,41800.0,41900.0,42000.0,42100.0,42200.0,42300.0,42400.0,42500.0,42600.0,42700.0,42800.0,42900.0,43000.0,43100.0,43200.0,43300.0,43400.0,43500.0,43600.0,43700.0,43800.0,43900.0,44000.0,44100.0,44200.0,44300.0,44400.0,44500.0,44600.0,44700.0,44800.0,44900.0,45000.0,45001.0,45100.0,45200.0,45300.0,45400.0,45500.0,45600.0,45700.0,45800.0,45900.0,46000.0,46100.0,46200.0,46300.0,46400.0,46500.0,46600.0,46700.0,46800.0,46900.0,47000.0,47100.0,47200.0,47300.0,47400.0,47500.0,47600.0,47700.0,47800.0,47900.0,48000.0,48100.0,48200.0,48300.0,48400.0,48500.0,48600.0,48700.0,48800.0,48900.0,49000.0,49100.0,49200.0,49300.0,49400.0,49500.0,49600.0,49700.0,49800.0,49900.0,50000.0,50001.0,50100.0,50200.0,503 ...

// %% [markdown]
// Optionally save the plot in the file.

// %%
val filename = "CEC2024_GMPB_Peaks5_ChangeFrequency5000_D5_ShiftSeverity1_Environments100.svg"

//ggsave(plot, filename)
