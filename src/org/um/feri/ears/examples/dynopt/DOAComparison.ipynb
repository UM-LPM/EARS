// %% [markdown]
// # Example of how to (visually) compare dynamic optimization algorithms
//
// Visualization of comparison results is done using Lets-Plot library using [Lets-Plot Kotlin API](https://lets-plot.org/kotlin). You can see the latest release in JetBrain's [lets-plot-kotlin](https://github.com/JetBrains/lets-plot-kotlin) repository and check some starting examples in their [Lets-Plot Usage Guide](https://nbviewer.org/github/JetBrains/lets-plot-kotlin/blob/master/docs/guide/user_guide.ipynb). Also, see [some examples](https://nbviewer.org/github/JetBrains/lets-plot-kotlin/tree/master/docs/examples/jupyter-notebooks/) by specific release.

// %% [markdown]
// #### "Line Magics"
//
// This (`%use lets-plot`) "line magic" will apply **Lets-Plot library descriptor**, which adds to your notebook all the boilerplate code necessary to create plots. `%useLatestDescriptors` is needed for function `ggtb()`, which enables zoom/pan interactivity on the plot.

// %%
%useLatestDescriptors
%use lets-plot

// %% [markdown]
// #### EARS dependency
//
// Import all EARS classes needed to perform the comparison.

// %%
import org.um.feri.ears.algorithms.DummyAlgorithm
import org.um.feri.ears.algorithms.NumberAlgorithm
import org.um.feri.ears.benchmark.Benchmark
import org.um.feri.ears.examples.dynopt.AlgorithmPerformance
import org.um.feri.ears.examples.dynopt.GMPBBenchmark
import org.um.feri.ears.statistic.rating_system.RatingType
import org.um.feri.ears.visualization.rating.RatingIntervalPlot
import java.io.File

// %% [markdown]
// #### Set the configuration for the comparison using EARS
//
// Define the directory path for storing algorithm results.

// %%
val algResultsDir =
    "D:${File.separator}" +
            "EDOLAB-MATLAB${File.separator}" +
            "Results${File.separator}" +
            "Comparison${File.separator}" +
            "DeleteAfterTest${File.separator}" +
            "GMPB_Peaks5_ChangeFrequency5000_D5_ShiftSeverity1_Environments100"

// %% [markdown]
// Configure benchmark settings and disable certain features.

// %%
Benchmark.printInfo = false
DummyAlgorithm.readFromJson = false
val displayRatingChart = false

// %% [markdown]
// Create a list of algorithms to be compared.

// %%
val players = arrayListOf<NumberAlgorithm>(
    DummyAlgorithm("ACFPSO", algResultsDir),
    DummyAlgorithm("mjDE", algResultsDir),
    DummyAlgorithm("mPSO", algResultsDir),
    DummyAlgorithm("SPSO_AP_AD", algResultsDir)
)

// %% [markdown]
// Initialize objects that will store algorithms' performance, set the number of runs, and calculate the total number of problems.

// %%
val algPerf = players.map { AlgorithmPerformance(it.id) }.toMutableList() // Prepare objects for storing the algorithms data.

val runNumber = 31

val changeFrequency = 5000
val environmentNumber = 100
val sampleInterval = 1000
val numOfProblems = (changeFrequency / sampleInterval) * environmentNumber + environmentNumber - 1

// %% [markdown]
// #### Perform the comparison using EARS
//
// * Initialize the evaluation number and iterate through all problems.
// * For each problem, create and execute benchmarks, then store and optionally display the results.
// * Update the evaluation number based on the defined interval.

// %%
var evaluationNumber = sampleInterval
for (i in 0 until numOfProblems) {
    // Create and execute benchmarks for every evaluation defined with sampleInterval.
    val gmpbBenchmark = GMPBBenchmark(evaluationNumber).apply {
        setDisplayRatingCharts(false)
        addAlgorithms(players)
        run(runNumber)
    }

    val tournamentResults = gmpbBenchmark.tournamentResults

    if (displayRatingChart) {
        RatingIntervalPlot.displayChart(
            tournamentResults.players,
            RatingType.GLICKO2,
            "Rating Interval for Eval$evaluationNumber"
        )
    }

    // Store tournament results for every player (algorithm).
    tournamentResults.players.forEach { player ->
        algPerf.firstOrNull { it.name == player.id }?.apply {
            addRating(
                "mpbeval$evaluationNumber",
                player.glicko2Rating.rating,
                player.glicko2Rating.ratingDeviation
            )
        }
    }

    if (evaluationNumber % changeFrequency == 0) {
        // first evaluation after environment/problem change
        evaluationNumber++
    } else if (evaluationNumber % sampleInterval == 0) {
        // evaluation every 'sampleInterval'
        evaluationNumber += sampleInterval
    } else {
        // next evaluation after environment/problem change
        evaluationNumber = evaluationNumber + sampleInterval - 1
    }
}
// Out:
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=10.11, Std-Dev(sigma)=1.03 RI=[8.05, 12.17]
// mjDE - Mean(mu)=9.09, Std-Dev(sigma)=1.02 RI=[7.06, 11.13]
// SPSO_AP_AD - Mean(mu)=7.99, Std-Dev(sigma)=1.01 RI=[5.97, 10.01]
// ACFPSO - Mean(mu)=6.93, Std-Dev(sigma)=0.99 RI=[4.96, 8.91]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=26.41, Std-Dev(sigma)=1.04 RI=[24.34, 28.48]
// mjDE - Mean(mu)=25.91, Std-Dev(sigma)=1.06 RI=[23.79, 28.02]
// SPSO_AP_AD - Mean(mu)=24.53, Std-Dev(sigma)=1.06 RI=[22.4, 26.66]
// ACFPSO - Mean(mu)=23.15, Std-Dev(sigma)=1.06 RI=[21.03, 25.27]
//
// Glicko2 rating:
// mPSO - Rating=1,598.2 RD=53.2 ro=0.06 RI=[1491.74, 1704.63]
// mjDE - Rating=1,592.7 RD=53.2 ro=0.06 RI=[1486.29, 1699.17]
// SPSO_AP_AD - Rating=1,418.2 RD=53.2 ro=0.06 RI=[1311.74, 1524.62]
// ACFPSO - Rating=1,390.9 RD=53.2 ro=0.06 RI=[1284.46, 1497.35]
//
// Game results:
// mPSO [win=55, lose=37, draw=1]
// 	 Against:{ACFPSO=[win=21, lose=9, draw=1], SPSO_AP_AD=[win=18, lose=13, draw=0], mjDE=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval1000=[win=55, lose=37, draw=1]}
// mjDE [win=55, lose=38, draw=0]
// 	 Against:{ACFPSO=[win=19, lose=12, draw=0], SPSO_AP_AD=[win=21, lose=10, draw=0], mPSO=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval1000=[win=55, lose=38, draw=0]}
// SPSO_AP_AD [win=39, lose=54, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], mjDE=[win=10, lose=21, draw=0], mPSO=[win=13, lose=18, draw=0]}
// 	 Problems:{GMPBEval1000=[win=39, lose=54, draw=0]}
// ACFPSO [win=36, lose=56, draw=1]
// 	 Against:{SPSO_AP_AD=[win=15, lose=16, draw=0], mjDE=[win=12, lose=19, draw=0], mPSO=[win=9, lose=21, draw=1]}
// 	 Problems:{GMPBEval1000=[win=36, lose=56, draw=1]}
// TrueSkill One-On-One rating:
// SPSO_AP_AD - Mean(mu)=7.5, Std-Dev(sigma)=1.02 RI=[5.46, 9.54]
// mjDE - Mean(mu)=7.14, Std-Dev(sigma)=1.01 RI=[5.11, 9.17]
// mPSO - Mean(mu)=6.89, Std-Dev(sigma)=0.99 RI=[4.9, 8.88]
// ACFPSO - Mean(mu)=4.41, Std-Dev(sigma)=0.99 RI=[2.43, 6.39]
//
// TrueSkill Free-For-All rating:
// SPSO_AP_AD - Mean(mu)=26.35, Std-Dev(sigma)=1.04 RI=[24.27, 28.44]
// mjDE - Mean(mu)=26.01, Std-Dev(sigma)=1.05 RI=[23.92, 28.11]
// mPSO - Mean(mu)=25.41, Std-Dev(sigma)=1.03 RI=[23.34, 27.47]
// ACFPSO - Mean(mu)=22.86, Std-Dev(sigma)=1.07 RI=[20.72, 25]
//
// Glicko2 rating:
// mjDE - Rating=1,570.9 RD=53.2 ro=0.06 RI=[1464.47, 1677.35]
// SPSO_AP_AD - Rating=1,560 RD=53.2 ro=0.06 RI=[1453.56, 1666.44]
// mPSO - Rating=1,510.9 RD=53.2 ro=0.06 RI=[1404.47, 1617.35]
// ACFPSO - Rating=1,358.2 RD=53.2 ro=0.06 RI=[1251.74, 1464.62]
//
// Game results:
// mjDE [win=53, lose=40, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], SPSO_AP_AD=[win=15, lose=16, draw=0], mPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval2000=[win=53, lose=40, draw=0]}
// SPSO_AP_AD [win=52, lose=41, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], mjDE=[win=16, lose=15, draw=0], mPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval2000=[win=52, lose=41, draw=0]}
// mPSO [win=47, lose=45, draw=1]
// 	 Against:{ACFPSO=[win=19, lose=11, draw=1], SPSO_AP_AD=[win=15, lose=16, draw=0], mjDE=[win=13, lose=18, draw=0]}
// 	 Problems:{GMPBEval2000=[win=47, lose=45, draw=1]}
// ACFPSO [win=33, lose=59, draw=1]
// 	 Against:{SPSO_AP_AD=[win=11, lose=20, draw=0], mjDE=[win=11, lose=20, draw=0], mPSO=[win=11, lose=19, draw=1]}
// 	 Problems:{GMPBEval2000=[win=33, lose=59, draw=1]}
// TrueSkill One-On-One rating:
// SPSO_AP_AD - Mean(mu)=9.92, Std-Dev(sigma)=1.03 RI=[7.85, 11.99]
// mPSO - Mean(mu)=9.14, Std-Dev(sigma)=1 RI=[7.13, 11.14]
// mjDE - Mean(mu)=8.88, Std-Dev(sigma)=1.05 RI=[6.78, 10.97]
// ACFPSO - Mean(mu)=5.66, Std-Dev(sigma)=0.99 RI=[3.67, 7.64]
//
// TrueSkill Free-For-All rating:
// SPSO_AP_AD - Mean(mu)=26.36, Std-Dev(sigma)=1.04 RI=[24.28, 28.45]
// mjDE - Mean(mu)=25.99, Std-Dev(sigma)=1.07 RI=[23.84, 28.14]
// mPSO - Mean(mu)=25.26, Std-Dev(sigma)=1.04 RI=[23.18, 27.34]
// ACFPSO - Mean(mu)=21.25, Std-Dev(sigma)=1.09 RI=[19.06, 23.43]
//
// Glicko2 rating:
// mjDE - Rating=1,614.5 RD=53.2 ro=0.06 RI=[1508.11, 1720.99]
// SPSO_AP_AD - Rating=1,592.7 RD=53.2 ro=0.06 RI=[1486.29, 1699.17]
// mPSO - Rating=1,510.9 RD=53.2 ro=0.06 RI=[1404.47, 1617.35]
// ACFPSO - Rating=1,281.8 RD=53.2 ro=0.06 RI=[1175.37, 1388.26]
//
// Game results:
// mjDE [win=57, lose=36, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], SPSO_AP_AD=[win=17, lose=14, draw=0], mPSO=[win=19, lose=12, draw=0]}
// 	 Problems:{GMPBEval3000=[win=57, lose=36, draw=0]}
// SPSO_AP_AD [win=55, lose=38, draw=0]
// 	 Against:{ACFPSO=[win=23, lose=8, draw=0], mjDE=[win=14, lose=17, draw=0], mPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval3000=[win=55, lose=38, draw=0]}
// mPSO [win=47, lose=45, draw=1]
// 	 Against:{ACFPSO=[win=22, lose=8, draw=1], SPSO_AP_AD=[win=13, lose=18, draw=0], mjDE=[win=12, lose=19, draw=0]}
// 	 Problems:{GMPBEval3000=[win=47, lose=45, draw=1]}
// ACFPSO [win=26, lose=66, draw=1]
// 	 Against:{SPSO_AP_AD=[win=8, lose=23, draw=0], mjDE=[win=10, lose=21, draw=0], mPSO=[win=8, lose=22, draw=1]}
// 	 Problems:{GMPBEval3000=[win=26, lose=66, draw=1]}
// TrueSkill One-On-One rating:
// SPSO_AP_AD - Mean(mu)=8.56, Std-Dev(sigma)=1.03 RI=[6.49, 10.62]
// mjDE - Mean(mu)=8.28, Std-Dev(sigma)=1.08 RI=[6.13, 10.44]
// mPSO - Mean(mu)=7.82, Std-Dev(sigma)=1 RI=[5.82, 9.82]
// ACFPSO - Mean(mu)=4.42, Std-Dev(sigma)=1.01 RI=[2.39, 6.45]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=27, Std-Dev(sigma)=1.09 RI=[24.83, 29.18]
// SPSO_AP_AD - Mean(mu)=26.61, Std-Dev(sigma)=1.04 RI=[24.52, 28.7]
// mPSO - Mean(mu)=25.32, Std-Dev(sigma)=1.04 RI=[23.25, 27.39]
// ACFPSO - Mean(mu)=21.46, Std-Dev(sigma)=1.11 RI=[19.23, 23.68]
//
// Glicko2 rating:
// mjDE - Rating=1,647.3 RD=53.2 ro=0.06 RI=[1540.83, 1753.72]
// SPSO_AP_AD - Rating=1,570.9 RD=53.2 ro=0.06 RI=[1464.47, 1677.35]
// mPSO - Rating=1,521.8 RD=53.2 ro=0.06 RI=[1415.38, 1628.26]
// ACFPSO - Rating=1,260 RD=53.2 ro=0.06 RI=[1153.55, 1366.44]
//
// Game results:
// mjDE [win=60, lose=33, draw=0]
// 	 Against:{ACFPSO=[win=24, lose=7, draw=0], SPSO_AP_AD=[win=17, lose=14, draw=0], mPSO=[win=19, lose=12, draw=0]}
// 	 Problems:{GMPBEval4000=[win=60, lose=33, draw=0]}
// SPSO_AP_AD [win=53, lose=40, draw=0]
// 	 Against:{ACFPSO=[win=22, lose=9, draw=0], mPSO=[win=17, lose=14, draw=0], mjDE=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval4000=[win=53, lose=40, draw=0]}
// mPSO [win=48, lose=44, draw=1]
// 	 Against:{ACFPSO=[win=22, lose=8, draw=1], SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=12, lose=19, draw=0]}
// 	 Problems:{GMPBEval4000=[win=48, lose=44, draw=1]}
// ACFPSO [win=24, lose=68, draw=1]
// 	 Against:{SPSO_AP_AD=[win=9, lose=22, draw=0], mPSO=[win=8, lose=22, draw=1], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval4000=[win=24, lose=68, draw=1]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=11.25, Std-Dev(sigma)=1.12 RI=[9.01, 13.49]
// SPSO_AP_AD - Mean(mu)=10.29, Std-Dev(sigma)=1.04 RI=[8.22, 12.36]
// mPSO - Mean(mu)=9.84, Std-Dev(sigma)=0.99 RI=[7.85, 11.82]
// ACFPSO - Mean(mu)=6.86, Std-Dev(sigma)=1.01 RI=[4.83, 8.88]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26.99, Std-Dev(sigma)=1.11 RI=[24.77, 29.21]
// SPSO_AP_AD - Mean(mu)=25.17, Std-Dev(sigma)=1.05 RI=[23.07, 27.27]
// mPSO - Mean(mu)=24.22, Std-Dev(sigma)=1.04 RI=[22.15, 26.29]
// ACFPSO - Mean(mu)=20.84, Std-Dev(sigma)=1.11 RI=[18.62, 23.06]
//
// Glicko2 rating:
// mjDE - Rating=1,701.8 RD=53.2 ro=0.06 RI=[1595.38, 1808.27]
// SPSO_AP_AD - Rating=1,516.4 RD=53.2 ro=0.06 RI=[1409.92, 1622.81]
// mPSO - Rating=1,489.1 RD=53.2 ro=0.06 RI=[1382.65, 1595.53]
// ACFPSO - Rating=1,292.7 RD=53.2 ro=0.06 RI=[1186.28, 1399.16]
//
// Game results:
// mjDE [win=65, lose=28, draw=0]
// 	 Against:{ACFPSO=[win=24, lose=7, draw=0], SPSO_AP_AD=[win=21, lose=10, draw=0], mPSO=[win=20, lose=11, draw=0]}
// 	 Problems:{GMPBEval5000=[win=65, lose=28, draw=0]}
// SPSO_AP_AD [win=48, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], mjDE=[win=10, lose=21, draw=0], mPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval5000=[win=48, lose=45, draw=0]}
// mPSO [win=45, lose=47, draw=1]
// 	 Against:{ACFPSO=[win=20, lose=10, draw=1], SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval5000=[win=45, lose=47, draw=1]}
// ACFPSO [win=27, lose=65, draw=1]
// 	 Against:{SPSO_AP_AD=[win=10, lose=21, draw=0], mjDE=[win=7, lose=24, draw=0], mPSO=[win=10, lose=20, draw=1]}
// 	 Problems:{GMPBEval5000=[win=27, lose=65, draw=1]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=11.3, Std-Dev(sigma)=1.19 RI=[8.91, 13.68]
// ACFPSO - Mean(mu)=8.02, Std-Dev(sigma)=1.02 RI=[5.99, 10.05]
// mPSO - Mean(mu)=7.25, Std-Dev(sigma)=1.01 RI=[5.22, 9.27]
// SPSO_AP_AD - Mean(mu)=6.6, Std-Dev(sigma)=0.98 RI=[4.63, 8.57]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=29.07, Std-Dev(sigma)=1.15 RI=[26.76, 31.38]
// ACFPSO - Mean(mu)=24.82, Std-Dev(sigma)=1.05 RI=[22.71, 26.93]
// mPSO - Mean(mu)=23.64, Std-Dev(sigma)=1.08 RI=[21.48, 25.79]
// SPSO_AP_AD - Mean(mu)=23.03, Std-Dev(sigma)=1.06 RI=[20.91, 25.15]
//
// Glicko2 rating:
// mjDE - Rating=1,789.1 RD=53.2 ro=0.06 RI=[1682.66, 1895.54]
// ACFPSO - Rating=1,461.8 RD=53.2 ro=0.06 RI=[1355.37, 1568.26]
// mPSO - Rating=1,374.5 RD=53.2 ro=0.06 RI=[1268.1, 1480.99]
// SPSO_AP_AD - Rating=1,374.5 RD=53.2 ro=0.06 RI=[1268.1, 1480.99]
//
// Game results:
// mjDE [win=73, lose=20, draw=0]
// 	 Against:{ACFPSO=[win=22, lose=9, draw=0], SPSO_AP_AD=[win=24, lose=7, draw=0], mPSO=[win=27, lose=4, draw=0]}
// 	 Problems:{GMPBEval5001=[win=73, lose=20, draw=0]}
// ACFPSO [win=43, lose=50, draw=0]
// 	 Against:{SPSO_AP_AD=[win=20, lose=11, draw=0], mjDE=[win=9, lose=22, draw=0], mPSO=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval5001=[win=43, lose=50, draw=0]}
// mPSO [win=35, lose=58, draw=0]
// 	 Against:{ACFPSO=[win=17, lose=14, draw=0], SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=4, lose=27, draw=0]}
// 	 Problems:{GMPBEval5001=[win=35, lose=58, draw=0]}
// SPSO_AP_AD [win=35, lose=58, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], mjDE=[win=7, lose=24, draw=0], mPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval5001=[win=35, lose=58, draw=0]}
// TrueSkill One-On-One rating:
// SPSO_AP_AD - Mean(mu)=8.28, Std-Dev(sigma)=1.03 RI=[6.21, 10.35]
// mjDE - Mean(mu)=7.95, Std-Dev(sigma)=1.07 RI=[5.8, 10.09]
// mPSO - Mean(mu)=7.39, Std-Dev(sigma)=0.98 RI=[5.42, 9.35]
// ACFPSO - Mean(mu)=6.87, Std-Dev(sigma)=1.02 RI=[4.84, 8.9]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26.59, Std-Dev(sigma)=1.1 RI=[24.4, 28.78]
// SPSO_AP_AD - Mean(mu)=25.75, Std-Dev(sigma)=1.07 RI=[23.61, 27.9]
// ACFPSO - Mean(mu)=24.47, Std-Dev(sigma)=1.08 RI=[22.31, 26.62]
// mPSO - Mean(mu)=24.32, Std-Dev(sigma)=1.05 RI=[22.23, 26.41]
//
// Glicko2 rating:
// mjDE - Rating=1,647.3 RD=53.2 ro=0.06 RI=[1540.83, 1753.72]
// SPSO_AP_AD - Rating=1,461.8 RD=53.2 ro=0.06 RI=[1355.37, 1568.26]
// mPSO - Rating=1,450.9 RD=53.2 ro=0.06 RI=[1344.47, 1557.35]
// ACFPSO - Rating=1,440 RD=53.2 ro=0.06 RI=[1333.56, 1546.44]
//
// Game results:
// mjDE [win=60, lose=33, draw=0]
// 	 Against:{ACFPSO=[win=19, lose=12, draw=0], SPSO_AP_AD=[win=21, lose=10, draw=0], mPSO=[win=20, lose=11, draw=0]}
// 	 Problems:{GMPBEval6000=[win=60, lose=33, draw=0]}
// SPSO_AP_AD [win=43, lose=50, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], mjDE=[win=10, lose=21, draw=0], mPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval6000=[win=43, lose=50, draw=0]}
// mPSO [win=42, lose=51, draw=0]
// 	 Against:{ACFPSO=[win=17, lose=14, draw=0], SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval6000=[win=42, lose=51, draw=0]}
// ACFPSO [win=41, lose=52, draw=0]
// 	 Against:{SPSO_AP_AD=[win=15, lose=16, draw=0], mjDE=[win=12, lose=19, draw=0], mPSO=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval6000=[win=41, lose=52, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=7.51, Std-Dev(sigma)=1.08 RI=[5.36, 9.67]
// SPSO_AP_AD - Mean(mu)=7.29, Std-Dev(sigma)=1.05 RI=[5.19, 9.38]
// mPSO - Mean(mu)=6.4, Std-Dev(sigma)=0.99 RI=[4.42, 8.38]
// ACFPSO - Mean(mu)=5.71, Std-Dev(sigma)=1.03 RI=[3.66, 7.77]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26.95, Std-Dev(sigma)=1.1 RI=[24.75, 29.14]
// SPSO_AP_AD - Mean(mu)=25.9, Std-Dev(sigma)=1.08 RI=[23.74, 28.06]
// mPSO - Mean(mu)=24.47, Std-Dev(sigma)=1.04 RI=[22.38, 26.56]
// ACFPSO - Mean(mu)=24.45, Std-Dev(sigma)=1.09 RI=[22.28, 26.62]
//
// Glicko2 rating:
// mjDE - Rating=1,669.1 RD=53.2 ro=0.06 RI=[1562.65, 1775.54]
// SPSO_AP_AD - Rating=1,461.8 RD=53.2 ro=0.06 RI=[1355.37, 1568.26]
// mPSO - Rating=1,450.9 RD=53.2 ro=0.06 RI=[1344.47, 1557.35]
// ACFPSO - Rating=1,418.2 RD=53.2 ro=0.06 RI=[1311.74, 1524.62]
//
// Game results:
// mjDE [win=62, lose=31, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], SPSO_AP_AD=[win=21, lose=10, draw=0], mPSO=[win=20, lose=11, draw=0]}
// 	 Problems:{GMPBEval7000=[win=62, lose=31, draw=0]}
// SPSO_AP_AD [win=43, lose=50, draw=0]
// 	 Against:{ACFPSO=[win=17, lose=14, draw=0], mjDE=[win=10, lose=21, draw=0], mPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval7000=[win=43, lose=50, draw=0]}
// mPSO [win=42, lose=51, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], SPSO_AP_AD=[win=15, lose=16, draw=0], mjDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval7000=[win=42, lose=51, draw=0]}
// ACFPSO [win=39, lose=54, draw=0]
// 	 Against:{SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=10, lose=21, draw=0], mPSO=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval7000=[win=39, lose=54, draw=0]}
// TrueSkill One-On-One rating:
// SPSO_AP_AD - Mean(mu)=7.78, Std-Dev(sigma)=1.06 RI=[5.65, 9.9]
// mjDE - Mean(mu)=7.47, Std-Dev(sigma)=1.09 RI=[5.29, 9.64]
// mPSO - Mean(mu)=6.67, Std-Dev(sigma)=0.99 RI=[4.69, 8.65]
// ACFPSO - Mean(mu)=6.1, Std-Dev(sigma)=1.02 RI=[4.07, 8.14]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26.87, Std-Dev(sigma)=1.12 RI=[24.62, 29.12]
// SPSO_AP_AD - Mean(mu)=26.16, Std-Dev(sigma)=1.08 RI=[23.99, 28.33]
// mPSO - Mean(mu)=24.42, Std-Dev(sigma)=1.05 RI=[22.32, 26.51]
// ACFPSO - Mean(mu)=24.09, Std-Dev(sigma)=1.08 RI=[21.93, 26.25]
//
// Glicko2 rating:
// mjDE - Rating=1,669.1 RD=53.2 ro=0.06 RI=[1562.65, 1775.54]
// SPSO_AP_AD - Rating=1,483.6 RD=53.2 ro=0.06 RI=[1377.19, 1590.08]
// mPSO - Rating=1,450.9 RD=53.2 ro=0.06 RI=[1344.47, 1557.35]
// ACFPSO - Rating=1,396.4 RD=53.2 ro=0.06 RI=[1289.92, 1502.8]
//
// Game results:
// mjDE [win=62, lose=31, draw=0]
// 	 Against:{ACFPSO=[win=22, lose=9, draw=0], SPSO_AP_AD=[win=20, lose=11, draw=0], mPSO=[win=20, lose=11, draw=0]}
// 	 Problems:{GMPBEval8000=[win=62, lose=31, draw=0]}
// SPSO_AP_AD [win=45, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=18, lose=13, draw=0], mjDE=[win=11, lose=20, draw=0], mPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval8000=[win=45, lose=48, draw=0]}
// mPSO [win=42, lose=51, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], SPSO_AP_AD=[win=15, lose=16, draw=0], mjDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval8000=[win=42, lose=51, draw=0]}
// ACFPSO [win=37, lose=56, draw=0]
// 	 Against:{SPSO_AP_AD=[win=13, lose=18, draw=0], mjDE=[win=9, lose=22, draw=0], mPSO=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval8000=[win=37, lose=56, draw=0]}
// TrueSkill One-On-One rating:
// SPSO_AP_AD - Mean(mu)=7.21, Std-Dev(sigma)=1.06 RI=[5.08, 9.33]
// mjDE - Mean(mu)=7.11, Std-Dev(sigma)=1.1 RI=[4.91, 9.31]
// mPSO - Mean(mu)=6.38, Std-Dev(sigma)=1 RI=[4.38, 8.37]
// ACFPSO - Mean(mu)=5.84, Std-Dev(sigma)=1.02 RI=[3.8, 7.87]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=27.22, Std-Dev(sigma)=1.13 RI=[24.96, 29.48]
// SPSO_AP_AD - Mean(mu)=26.12, Std-Dev(sigma)=1.1 RI=[23.91, 28.33]
// mPSO - Mean(mu)=24.81, Std-Dev(sigma)=1.05 RI=[22.71, 26.91]
// ACFPSO - Mean(mu)=24.34, Std-Dev(sigma)=1.08 RI=[22.18, 26.51]
//
// Glicko2 rating:
// mjDE - Rating=1,680 RD=53.2 ro=0.06 RI=[1573.56, 1786.45]
// mPSO - Rating=1,461.8 RD=53.2 ro=0.06 RI=[1355.37, 1568.26]
// SPSO_AP_AD - Rating=1,450.9 RD=53.2 ro=0.06 RI=[1344.47, 1557.35]
// ACFPSO - Rating=1,407.3 RD=53.2 ro=0.06 RI=[1300.83, 1513.71]
//
// Game results:
// mjDE [win=63, lose=30, draw=0]
// 	 Against:{ACFPSO=[win=22, lose=9, draw=0], SPSO_AP_AD=[win=21, lose=10, draw=0], mPSO=[win=20, lose=11, draw=0]}
// 	 Problems:{GMPBEval9000=[win=63, lose=30, draw=0]}
// mPSO [win=43, lose=50, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], SPSO_AP_AD=[win=16, lose=15, draw=0], mjDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval9000=[win=43, lose=50, draw=0]}
// SPSO_AP_AD [win=42, lose=51, draw=0]
// 	 Against:{ACFPSO=[win=17, lose=14, draw=0], mjDE=[win=10, lose=21, draw=0], mPSO=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval9000=[win=42, lose=51, draw=0]}
// ACFPSO [win=38, lose=55, draw=0]
// 	 Against:{SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=9, lose=22, draw=0], mPSO=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval9000=[win=38, lose=55, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=7.67, Std-Dev(sigma)=1.13 RI=[5.42, 9.92]
// SPSO_AP_AD - Mean(mu)=7.04, Std-Dev(sigma)=1.06 RI=[4.92, 9.16]
// ACFPSO - Mean(mu)=5.95, Std-Dev(sigma)=1.01 RI=[3.93, 7.98]
// mPSO - Mean(mu)=5.95, Std-Dev(sigma)=1.01 RI=[3.94, 7.97]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=27.83, Std-Dev(sigma)=1.14 RI=[25.55, 30.11]
// SPSO_AP_AD - Mean(mu)=25.93, Std-Dev(sigma)=1.11 RI=[23.72, 28.15]
// ACFPSO - Mean(mu)=24.43, Std-Dev(sigma)=1.08 RI=[22.27, 26.58]
// mPSO - Mean(mu)=24.37, Std-Dev(sigma)=1.06 RI=[22.24, 26.49]
//
// Glicko2 rating:
// mjDE - Rating=1,712.7 RD=53.2 ro=0.06 RI=[1606.29, 1819.18]
// SPSO_AP_AD - Rating=1,440 RD=53.2 ro=0.06 RI=[1333.56, 1546.44]
// mPSO - Rating=1,440 RD=53.2 ro=0.06 RI=[1333.56, 1546.44]
// ACFPSO - Rating=1,407.3 RD=53.2 ro=0.06 RI=[1300.83, 1513.71]
//
// Game results:
// mjDE [win=66, lose=27, draw=0]
// 	 Against:{ACFPSO=[win=22, lose=9, draw=0], SPSO_AP_AD=[win=22, lose=9, draw=0], mPSO=[win=22, lose=9, draw=0]}
// 	 Problems:{GMPBEval10000=[win=66, lose=27, draw=0]}
// SPSO_AP_AD [win=41, lose=52, draw=0]
// 	 Against:{ACFPSO=[win=17, lose=14, draw=0], mjDE=[win=9, lose=22, draw=0], mPSO=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval10000=[win=41, lose=52, draw=0]}
// mPSO [win=41, lose=52, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], SPSO_AP_AD=[win=16, lose=15, draw=0], mjDE=[win=9, lose=22, draw=0]}
// 	 Problems:{GMPBEval10000=[win=41, lose=52, draw=0]}
// ACFPSO [win=38, lose=55, draw=0]
// 	 Against:{SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=9, lose=22, draw=0], mPSO=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval10000=[win=38, lose=55, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=15.76, Std-Dev(sigma)=1.42 RI=[12.92, 18.61]
// ACFPSO - Mean(mu)=10.44, Std-Dev(sigma)=1.05 RI=[8.34, 12.55]
// SPSO_AP_AD - Mean(mu)=9.37, Std-Dev(sigma)=1.01 RI=[7.34, 11.39]
// mPSO - Mean(mu)=8.93, Std-Dev(sigma)=1.05 RI=[6.83, 11.03]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=30.68, Std-Dev(sigma)=1.28 RI=[28.11, 33.25]
// ACFPSO - Mean(mu)=23.98, Std-Dev(sigma)=1.09 RI=[21.81, 26.15]
// SPSO_AP_AD - Mean(mu)=22.44, Std-Dev(sigma)=1.08 RI=[20.29, 24.6]
// mPSO - Mean(mu)=22.06, Std-Dev(sigma)=1.12 RI=[19.82, 24.29]
//
// Glicko2 rating:
// mjDE - Rating=1,876.4 RD=53.2 ro=0.06 RI=[1769.93, 1982.82]
// ACFPSO - Rating=1,483.6 RD=53.2 ro=0.06 RI=[1377.19, 1590.08]
// SPSO_AP_AD - Rating=1,330.9 RD=53.2 ro=0.06 RI=[1224.46, 1437.35]
// mPSO - Rating=1,309.1 RD=53.2 ro=0.06 RI=[1202.64, 1415.53]
//
// Game results:
// mjDE [win=81, lose=12, draw=0]
// 	 Against:{ACFPSO=[win=25, lose=6, draw=0], SPSO_AP_AD=[win=28, lose=3, draw=0], mPSO=[win=28, lose=3, draw=0]}
// 	 Problems:{GMPBEval10001=[win=81, lose=12, draw=0]}
// ACFPSO [win=45, lose=48, draw=0]
// 	 Against:{SPSO_AP_AD=[win=18, lose=13, draw=0], mjDE=[win=6, lose=25, draw=0], mPSO=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval10001=[win=45, lose=48, draw=0]}
// SPSO_AP_AD [win=31, lose=62, draw=0]
// 	 Against:{ACFPSO=[win=13, lose=18, draw=0], mjDE=[win=3, lose=28, draw=0], mPSO=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval10001=[win=31, lose=62, draw=0]}
// mPSO [win=29, lose=64, draw=0]
// 	 Against:{ACFPSO=[win=10, lose=21, draw=0], SPSO_AP_AD=[win=16, lose=15, draw=0], mjDE=[win=3, lose=28, draw=0]}
// 	 Problems:{GMPBEval10001=[win=29, lose=64, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=7.63, Std-Dev(sigma)=1.05 RI=[5.52, 9.74]
// SPSO_AP_AD - Mean(mu)=6.97, Std-Dev(sigma)=1.04 RI=[4.88, 9.06]
// ACFPSO - Mean(mu)=6.42, Std-Dev(sigma)=1.04 RI=[4.35, 8.49]
// mPSO - Mean(mu)=5.97, Std-Dev(sigma)=0.97 RI=[4.04, 7.9]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26.97, Std-Dev(sigma)=1.06 RI=[24.85, 29.1]
// SPSO_AP_AD - Mean(mu)=25.9, Std-Dev(sigma)=1.09 RI=[23.72, 28.09]
// ACFPSO - Mean(mu)=25.9, Std-Dev(sigma)=1.07 RI=[23.75, 28.05]
// mPSO - Mean(mu)=23.9, Std-Dev(sigma)=1.05 RI=[21.8, 26]
//
// Glicko2 rating:
// mjDE - Rating=1,636.4 RD=53.2 ro=0.06 RI=[1529.92, 1742.81]
// ACFPSO - Rating=1,538.2 RD=53.2 ro=0.06 RI=[1431.74, 1644.63]
// SPSO_AP_AD - Rating=1,450.9 RD=53.2 ro=0.06 RI=[1344.47, 1557.35]
// mPSO - Rating=1,374.5 RD=53.2 ro=0.06 RI=[1268.1, 1480.99]
//
// Game results:
// mjDE [win=59, lose=34, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], SPSO_AP_AD=[win=19, lose=12, draw=0], mPSO=[win=24, lose=7, draw=0]}
// 	 Problems:{GMPBEval11000=[win=59, lose=34, draw=0]}
// ACFPSO [win=50, lose=43, draw=0]
// 	 Against:{SPSO_AP_AD=[win=17, lose=14, draw=0], mjDE=[win=15, lose=16, draw=0], mPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval11000=[win=50, lose=43, draw=0]}
// SPSO_AP_AD [win=42, lose=51, draw=0]
// 	 Against:{ACFPSO=[win=14, lose=17, draw=0], mjDE=[win=12, lose=19, draw=0], mPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval11000=[win=42, lose=51, draw=0]}
// mPSO [win=35, lose=58, draw=0]
// 	 Against:{ACFPSO=[win=13, lose=18, draw=0], SPSO_AP_AD=[win=15, lose=16, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval11000=[win=35, lose=58, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=6.57, Std-Dev(sigma)=1.02 RI=[4.53, 8.61]
// SPSO_AP_AD - Mean(mu)=6.47, Std-Dev(sigma)=1.05 RI=[4.37, 8.57]
// mPSO - Mean(mu)=5.81, Std-Dev(sigma)=0.99 RI=[3.84, 7.78]
// ACFPSO - Mean(mu)=5.59, Std-Dev(sigma)=1.01 RI=[3.57, 7.6]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26.57, Std-Dev(sigma)=1.06 RI=[24.46, 28.69]
// SPSO_AP_AD - Mean(mu)=26.49, Std-Dev(sigma)=1.09 RI=[24.31, 28.66]
// ACFPSO - Mean(mu)=25.44, Std-Dev(sigma)=1.06 RI=[23.32, 27.55]
// mPSO - Mean(mu)=25.08, Std-Dev(sigma)=1.05 RI=[22.99, 27.18]
//
// Glicko2 rating:
// mjDE - Rating=1,592.7 RD=53.2 ro=0.06 RI=[1486.29, 1699.17]
// ACFPSO - Rating=1,483.6 RD=53.2 ro=0.06 RI=[1377.19, 1590.08]
// SPSO_AP_AD - Rating=1,472.7 RD=53.2 ro=0.06 RI=[1366.28, 1579.17]
// mPSO - Rating=1,450.9 RD=53.2 ro=0.06 RI=[1344.47, 1557.35]
//
// Game results:
// mjDE [win=55, lose=38, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], SPSO_AP_AD=[win=18, lose=13, draw=0], mPSO=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval12000=[win=55, lose=38, draw=0]}
// ACFPSO [win=45, lose=48, draw=0]
// 	 Against:{SPSO_AP_AD=[win=16, lose=15, draw=0], mjDE=[win=15, lose=16, draw=0], mPSO=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval12000=[win=45, lose=48, draw=0]}
// SPSO_AP_AD [win=44, lose=49, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], mjDE=[win=13, lose=18, draw=0], mPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval12000=[win=44, lose=49, draw=0]}
// mPSO [win=42, lose=51, draw=0]
// 	 Against:{ACFPSO=[win=17, lose=14, draw=0], SPSO_AP_AD=[win=15, lose=16, draw=0], mjDE=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval12000=[win=42, lose=51, draw=0]}
// TrueSkill One-On-One rating:
// SPSO_AP_AD - Mean(mu)=7.11, Std-Dev(sigma)=1.04 RI=[5.04, 9.18]
// mjDE - Mean(mu)=6.83, Std-Dev(sigma)=1.03 RI=[4.76, 8.89]
// mPSO - Mean(mu)=6.52, Std-Dev(sigma)=0.98 RI=[4.56, 8.48]
// ACFPSO - Mean(mu)=6.4, Std-Dev(sigma)=0.99 RI=[4.42, 8.38]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26.31, Std-Dev(sigma)=1.07 RI=[24.16, 28.45]
// SPSO_AP_AD - Mean(mu)=26.19, Std-Dev(sigma)=1.07 RI=[24.05, 28.33]
// ACFPSO - Mean(mu)=25.04, Std-Dev(sigma)=1.05 RI=[22.94, 27.13]
// mPSO - Mean(mu)=25.02, Std-Dev(sigma)=1.04 RI=[22.95, 27.09]
//
// Glicko2 rating:
// mjDE - Rating=1,581.8 RD=53.2 ro=0.06 RI=[1475.38, 1688.26]
// SPSO_AP_AD - Rating=1,483.6 RD=53.2 ro=0.06 RI=[1377.19, 1590.08]
// mPSO - Rating=1,472.7 RD=53.2 ro=0.06 RI=[1366.28, 1579.17]
// ACFPSO - Rating=1,461.8 RD=53.2 ro=0.06 RI=[1355.37, 1568.26]
//
// Game results:
// mjDE [win=54, lose=39, draw=0]
// 	 Against:{ACFPSO=[win=17, lose=14, draw=0], SPSO_AP_AD=[win=18, lose=13, draw=0], mPSO=[win=19, lose=12, draw=0]}
// 	 Problems:{GMPBEval13000=[win=54, lose=39, draw=0]}
// SPSO_AP_AD [win=45, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], mjDE=[win=13, lose=18, draw=0], mPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval13000=[win=45, lose=48, draw=0]}
// mPSO [win=44, lose=49, draw=0]
// 	 Against:{ACFPSO=[win=18, lose=13, draw=0], SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=12, lose=19, draw=0]}
// 	 Problems:{GMPBEval13000=[win=44, lose=49, draw=0]}
// ACFPSO [win=43, lose=50, draw=0]
// 	 Against:{SPSO_AP_AD=[win=16, lose=15, draw=0], mjDE=[win=14, lose=17, draw=0], mPSO=[win=13, lose=18, draw=0]}
// 	 Problems:{GMPBEval13000=[win=43, lose=50, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=7.73, Std-Dev(sigma)=1.06 RI=[5.62, 9.85]
// SPSO_AP_AD - Mean(mu)=7.02, Std-Dev(sigma)=1.04 RI=[4.94, 9.09]
// mPSO - Mean(mu)=6.95, Std-Dev(sigma)=0.98 RI=[4.99, 8.92]
// ACFPSO - Mean(mu)=6.3, Std-Dev(sigma)=0.99 RI=[4.31, 8.29]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26.89, Std-Dev(sigma)=1.07 RI=[24.74, 29.04]
// SPSO_AP_AD - Mean(mu)=25.74, Std-Dev(sigma)=1.08 RI=[23.59, 27.89]
// mPSO - Mean(mu)=24.97, Std-Dev(sigma)=1.04 RI=[22.9, 27.05]
// ACFPSO - Mean(mu)=24.42, Std-Dev(sigma)=1.06 RI=[22.3, 26.55]
//
// Glicko2 rating:
// mjDE - Rating=1,636.4 RD=53.2 ro=0.06 RI=[1529.92, 1742.81]
// mPSO - Rating=1,483.6 RD=53.2 ro=0.06 RI=[1377.19, 1590.08]
// SPSO_AP_AD - Rating=1,461.8 RD=53.2 ro=0.06 RI=[1355.37, 1568.26]
// ACFPSO - Rating=1,418.2 RD=53.2 ro=0.06 RI=[1311.74, 1524.62]
//
// Game results:
// mjDE [win=59, lose=34, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], SPSO_AP_AD=[win=18, lose=13, draw=0], mPSO=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval14000=[win=59, lose=34, draw=0]}
// mPSO [win=45, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=19, lose=12, draw=0], SPSO_AP_AD=[win=16, lose=15, draw=0], mjDE=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval14000=[win=45, lose=48, draw=0]}
// SPSO_AP_AD [win=43, lose=50, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], mjDE=[win=13, lose=18, draw=0], mPSO=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval14000=[win=43, lose=50, draw=0]}
// ACFPSO [win=39, lose=54, draw=0]
// 	 Against:{SPSO_AP_AD=[win=16, lose=15, draw=0], mjDE=[win=11, lose=20, draw=0], mPSO=[win=12, lose=19, draw=0]}
// 	 Problems:{GMPBEval14000=[win=39, lose=54, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=7.93, Std-Dev(sigma)=1.06 RI=[5.81, 10.05]
// mPSO - Mean(mu)=7.18, Std-Dev(sigma)=0.99 RI=[5.2, 9.16]
// SPSO_AP_AD - Mean(mu)=6.41, Std-Dev(sigma)=1.03 RI=[4.35, 8.47]
// ACFPSO - Mean(mu)=6.12, Std-Dev(sigma)=1 RI=[4.11, 8.13]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=27.1, Std-Dev(sigma)=1.07 RI=[24.96, 29.24]
// mPSO - Mean(mu)=25.35, Std-Dev(sigma)=1.04 RI=[23.28, 27.43]
// SPSO_AP_AD - Mean(mu)=25.14, Std-Dev(sigma)=1.08 RI=[22.99, 27.3]
// ACFPSO - Mean(mu)=24.44, Std-Dev(sigma)=1.07 RI=[22.3, 26.58]
//
// Glicko2 rating:
// mjDE - Rating=1,647.3 RD=53.2 ro=0.06 RI=[1540.83, 1753.72]
// mPSO - Rating=1,505.5 RD=53.2 ro=0.06 RI=[1399.01, 1611.9]
// SPSO_AP_AD - Rating=1,429.1 RD=53.2 ro=0.06 RI=[1322.65, 1535.53]
// ACFPSO - Rating=1,418.2 RD=53.2 ro=0.06 RI=[1311.74, 1524.62]
//
// Game results:
// mjDE [win=60, lose=33, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], SPSO_AP_AD=[win=19, lose=12, draw=0], mPSO=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval15000=[win=60, lose=33, draw=0]}
// mPSO [win=47, lose=46, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], SPSO_AP_AD=[win=17, lose=14, draw=0], mjDE=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval15000=[win=47, lose=46, draw=0]}
// SPSO_AP_AD [win=40, lose=53, draw=0]
// 	 Against:{ACFPSO=[win=14, lose=17, draw=0], mjDE=[win=12, lose=19, draw=0], mPSO=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval15000=[win=40, lose=53, draw=0]}
// ACFPSO [win=39, lose=54, draw=0]
// 	 Against:{SPSO_AP_AD=[win=17, lose=14, draw=0], mjDE=[win=11, lose=20, draw=0], mPSO=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval15000=[win=39, lose=54, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=12.94, Std-Dev(sigma)=1.23 RI=[10.49, 15.39]
// SPSO_AP_AD - Mean(mu)=9.72, Std-Dev(sigma)=1 RI=[7.72, 11.72]
// ACFPSO - Mean(mu)=9.06, Std-Dev(sigma)=1.02 RI=[7.02, 11.1]
// mPSO - Mean(mu)=8.92, Std-Dev(sigma)=1.01 RI=[6.9, 10.94]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=28.89, Std-Dev(sigma)=1.18 RI=[26.54, 31.24]
// SPSO_AP_AD - Mean(mu)=23.78, Std-Dev(sigma)=1.07 RI=[21.64, 25.91]
// ACFPSO - Mean(mu)=23.74, Std-Dev(sigma)=1.07 RI=[21.6, 25.89]
// mPSO - Mean(mu)=23.03, Std-Dev(sigma)=1.07 RI=[20.88, 25.18]
//
// Glicko2 rating:
// mjDE - Rating=1,800 RD=53.2 ro=0.06 RI=[1693.56, 1906.45]
// ACFPSO - Rating=1,450.9 RD=53.2 ro=0.06 RI=[1344.47, 1557.35]
// SPSO_AP_AD - Rating=1,396.4 RD=53.2 ro=0.06 RI=[1289.92, 1502.8]
// mPSO - Rating=1,352.7 RD=53.2 ro=0.06 RI=[1246.28, 1459.17]
//
// Game results:
// mjDE [win=74, lose=19, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], SPSO_AP_AD=[win=27, lose=4, draw=0], mPSO=[win=26, lose=5, draw=0]}
// 	 Problems:{GMPBEval15001=[win=74, lose=19, draw=0]}
// ACFPSO [win=42, lose=51, draw=0]
// 	 Against:{SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=10, lose=21, draw=0], mPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval15001=[win=42, lose=51, draw=0]}
// SPSO_AP_AD [win=37, lose=56, draw=0]
// 	 Against:{ACFPSO=[win=17, lose=14, draw=0], mjDE=[win=4, lose=27, draw=0], mPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval15001=[win=37, lose=56, draw=0]}
// mPSO [win=33, lose=60, draw=0]
// 	 Against:{ACFPSO=[win=13, lose=18, draw=0], SPSO_AP_AD=[win=15, lose=16, draw=0], mjDE=[win=5, lose=26, draw=0]}
// 	 Problems:{GMPBEval15001=[win=33, lose=60, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=8.33, Std-Dev(sigma)=1.01 RI=[6.31, 10.35]
// SPSO_AP_AD - Mean(mu)=8.31, Std-Dev(sigma)=1.03 RI=[6.25, 10.37]
// ACFPSO - Mean(mu)=7.19, Std-Dev(sigma)=0.98 RI=[5.23, 9.15]
// mPSO - Mean(mu)=7.16, Std-Dev(sigma)=0.97 RI=[5.21, 9.1]
//
// TrueSkill Free-For-All rating:
// SPSO_AP_AD - Mean(mu)=26.07, Std-Dev(sigma)=1.06 RI=[23.96, 28.19]
// mjDE - Mean(mu)=25.7, Std-Dev(sigma)=1.04 RI=[23.61, 27.78]
// ACFPSO - Mean(mu)=24.26, Std-Dev(sigma)=1.05 RI=[22.16, 26.36]
// mPSO - Mean(mu)=23.84, Std-Dev(sigma)=1.03 RI=[21.77, 25.91]
//
// Glicko2 rating:
// SPSO_AP_AD - Rating=1,592.7 RD=53.2 ro=0.06 RI=[1486.29, 1699.17]
// mjDE - Rating=1,560 RD=53.2 ro=0.06 RI=[1453.56, 1666.44]
// ACFPSO - Rating=1,440 RD=53.2 ro=0.06 RI=[1333.56, 1546.44]
// mPSO - Rating=1,407.3 RD=53.2 ro=0.06 RI=[1300.83, 1513.71]
//
// Game results:
// SPSO_AP_AD [win=55, lose=38, draw=0]
// 	 Against:{ACFPSO=[win=18, lose=13, draw=0], mjDE=[win=15, lose=16, draw=0], mPSO=[win=22, lose=9, draw=0]}
// 	 Problems:{GMPBEval16000=[win=55, lose=38, draw=0]}
// mjDE [win=52, lose=41, draw=0]
// 	 Against:{ACFPSO=[win=18, lose=13, draw=0], SPSO_AP_AD=[win=16, lose=15, draw=0], mPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval16000=[win=52, lose=41, draw=0]}
// ACFPSO [win=41, lose=52, draw=0]
// 	 Against:{SPSO_AP_AD=[win=13, lose=18, draw=0], mjDE=[win=13, lose=18, draw=0], mPSO=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval16000=[win=41, lose=52, draw=0]}
// mPSO [win=38, lose=55, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], SPSO_AP_AD=[win=9, lose=22, draw=0], mjDE=[win=13, lose=18, draw=0]}
// 	 Problems:{GMPBEval16000=[win=38, lose=55, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=7.17, Std-Dev(sigma)=1.02 RI=[5.12, 9.22]
// mPSO - Mean(mu)=6.39, Std-Dev(sigma)=0.99 RI=[4.42, 8.37]
// SPSO_AP_AD - Mean(mu)=5.67, Std-Dev(sigma)=1.01 RI=[3.66, 7.69]
// ACFPSO - Mean(mu)=4.76, Std-Dev(sigma)=1.01 RI=[2.73, 6.79]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26.5, Std-Dev(sigma)=1.04 RI=[24.41, 28.58]
// SPSO_AP_AD - Mean(mu)=25.23, Std-Dev(sigma)=1.04 RI=[23.14, 27.31]
// mPSO - Mean(mu)=25.18, Std-Dev(sigma)=1.03 RI=[23.12, 27.25]
// ACFPSO - Mean(mu)=23.89, Std-Dev(sigma)=1.08 RI=[21.72, 26.06]
//
// Glicko2 rating:
// mjDE - Rating=1,614.5 RD=53.2 ro=0.06 RI=[1508.11, 1720.99]
// SPSO_AP_AD - Rating=1,516.4 RD=53.2 ro=0.06 RI=[1409.92, 1622.81]
// mPSO - Rating=1,483.6 RD=53.2 ro=0.06 RI=[1377.19, 1590.08]
// ACFPSO - Rating=1,385.5 RD=53.2 ro=0.06 RI=[1279.01, 1491.89]
//
// Game results:
// mjDE [win=57, lose=36, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], SPSO_AP_AD=[win=17, lose=14, draw=0], mPSO=[win=20, lose=11, draw=0]}
// 	 Problems:{GMPBEval17000=[win=57, lose=36, draw=0]}
// SPSO_AP_AD [win=48, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=17, lose=14, draw=0], mjDE=[win=14, lose=17, draw=0], mPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval17000=[win=48, lose=45, draw=0]}
// mPSO [win=45, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval17000=[win=45, lose=48, draw=0]}
// ACFPSO [win=36, lose=57, draw=0]
// 	 Against:{SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=11, lose=20, draw=0], mPSO=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval17000=[win=36, lose=57, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=8.37, Std-Dev(sigma)=1.07 RI=[6.23, 10.52]
// mPSO - Mean(mu)=6.51, Std-Dev(sigma)=0.99 RI=[4.53, 8.49]
// SPSO_AP_AD - Mean(mu)=6.05, Std-Dev(sigma)=1 RI=[4.04, 8.06]
// ACFPSO - Mean(mu)=4.9, Std-Dev(sigma)=1.01 RI=[2.88, 6.91]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=27.51, Std-Dev(sigma)=1.06 RI=[25.39, 29.62]
// SPSO_AP_AD - Mean(mu)=24.99, Std-Dev(sigma)=1.05 RI=[22.9, 27.09]
// mPSO - Mean(mu)=24.87, Std-Dev(sigma)=1.04 RI=[22.79, 26.96]
// ACFPSO - Mean(mu)=23.31, Std-Dev(sigma)=1.09 RI=[21.13, 25.49]
//
// Glicko2 rating:
// mjDE - Rating=1,680 RD=53.2 ro=0.06 RI=[1573.56, 1786.45]
// SPSO_AP_AD - Rating=1,516.4 RD=53.2 ro=0.06 RI=[1409.92, 1622.81]
// mPSO - Rating=1,461.8 RD=53.2 ro=0.06 RI=[1355.37, 1568.26]
// ACFPSO - Rating=1,341.8 RD=53.2 ro=0.06 RI=[1235.37, 1448.26]
//
// Game results:
// mjDE [win=63, lose=30, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], SPSO_AP_AD=[win=21, lose=10, draw=0], mPSO=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval18000=[win=63, lose=30, draw=0]}
// SPSO_AP_AD [win=48, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], mjDE=[win=10, lose=21, draw=0], mPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval18000=[win=48, lose=45, draw=0]}
// mPSO [win=43, lose=50, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], SPSO_AP_AD=[win=13, lose=18, draw=0], mjDE=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval18000=[win=43, lose=50, draw=0]}
// ACFPSO [win=32, lose=61, draw=0]
// 	 Against:{SPSO_AP_AD=[win=11, lose=20, draw=0], mjDE=[win=10, lose=21, draw=0], mPSO=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval18000=[win=32, lose=61, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=8.43, Std-Dev(sigma)=1.07 RI=[6.29, 10.56]
// mPSO - Mean(mu)=7.18, Std-Dev(sigma)=0.99 RI=[5.21, 9.16]
// SPSO_AP_AD - Mean(mu)=6.52, Std-Dev(sigma)=1 RI=[4.51, 8.53]
// ACFPSO - Mean(mu)=5.27, Std-Dev(sigma)=0.99 RI=[3.28, 7.25]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=27.24, Std-Dev(sigma)=1.06 RI=[25.12, 29.36]
// mPSO - Mean(mu)=25.15, Std-Dev(sigma)=1.04 RI=[23.07, 27.22]
// SPSO_AP_AD - Mean(mu)=24.99, Std-Dev(sigma)=1.05 RI=[22.89, 27.09]
// ACFPSO - Mean(mu)=23.12, Std-Dev(sigma)=1.07 RI=[20.97, 25.26]
//
// Glicko2 rating:
// mjDE - Rating=1,669.1 RD=53.2 ro=0.06 RI=[1562.65, 1775.54]
// SPSO_AP_AD - Rating=1,505.5 RD=53.2 ro=0.06 RI=[1399.01, 1611.9]
// mPSO - Rating=1,483.6 RD=53.2 ro=0.06 RI=[1377.19, 1590.08]
// ACFPSO - Rating=1,341.8 RD=53.2 ro=0.06 RI=[1235.37, 1448.26]
//
// Game results:
// mjDE [win=62, lose=31, draw=0]
// 	 Against:{ACFPSO=[win=22, lose=9, draw=0], SPSO_AP_AD=[win=21, lose=10, draw=0], mPSO=[win=19, lose=12, draw=0]}
// 	 Problems:{GMPBEval19000=[win=62, lose=31, draw=0]}
// SPSO_AP_AD [win=47, lose=46, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], mjDE=[win=10, lose=21, draw=0], mPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval19000=[win=47, lose=46, draw=0]}
// mPSO [win=45, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=19, lose=12, draw=0], SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=12, lose=19, draw=0]}
// 	 Problems:{GMPBEval19000=[win=45, lose=48, draw=0]}
// ACFPSO [win=32, lose=61, draw=0]
// 	 Against:{SPSO_AP_AD=[win=11, lose=20, draw=0], mjDE=[win=9, lose=22, draw=0], mPSO=[win=12, lose=19, draw=0]}
// 	 Problems:{GMPBEval19000=[win=32, lose=61, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=8.39, Std-Dev(sigma)=1.08 RI=[6.23, 10.55]
// mPSO - Mean(mu)=7.64, Std-Dev(sigma)=1 RI=[5.65, 9.63]
// SPSO_AP_AD - Mean(mu)=6.06, Std-Dev(sigma)=1 RI=[4.06, 8.06]
// ACFPSO - Mean(mu)=4.96, Std-Dev(sigma)=1 RI=[2.96, 6.96]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=27.39, Std-Dev(sigma)=1.07 RI=[25.26, 29.52]
// mPSO - Mean(mu)=25.61, Std-Dev(sigma)=1.03 RI=[23.54, 27.67]
// SPSO_AP_AD - Mean(mu)=24.54, Std-Dev(sigma)=1.05 RI=[22.44, 26.64]
// ACFPSO - Mean(mu)=22.9, Std-Dev(sigma)=1.08 RI=[20.74, 25.07]
//
// Glicko2 rating:
// mjDE - Rating=1,680 RD=53.2 ro=0.06 RI=[1573.56, 1786.45]
// mPSO - Rating=1,516.4 RD=53.2 ro=0.06 RI=[1409.92, 1622.81]
// SPSO_AP_AD - Rating=1,472.7 RD=53.2 ro=0.06 RI=[1366.28, 1579.17]
// ACFPSO - Rating=1,330.9 RD=53.2 ro=0.06 RI=[1224.46, 1437.35]
//
// Game results:
// mjDE [win=63, lose=30, draw=0]
// 	 Against:{ACFPSO=[win=22, lose=9, draw=0], SPSO_AP_AD=[win=22, lose=9, draw=0], mPSO=[win=19, lose=12, draw=0]}
// 	 Problems:{GMPBEval20000=[win=63, lose=30, draw=0]}
// mPSO [win=48, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=21, lose=10, draw=0], SPSO_AP_AD=[win=15, lose=16, draw=0], mjDE=[win=12, lose=19, draw=0]}
// 	 Problems:{GMPBEval20000=[win=48, lose=45, draw=0]}
// SPSO_AP_AD [win=44, lose=49, draw=0]
// 	 Against:{ACFPSO=[win=19, lose=12, draw=0], mjDE=[win=9, lose=22, draw=0], mPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval20000=[win=44, lose=49, draw=0]}
// ACFPSO [win=31, lose=62, draw=0]
// 	 Against:{SPSO_AP_AD=[win=12, lose=19, draw=0], mjDE=[win=9, lose=22, draw=0], mPSO=[win=10, lose=21, draw=0]}
// 	 Problems:{GMPBEval20000=[win=31, lose=62, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=12.59, Std-Dev(sigma)=1.26 RI=[10.07, 15.12]
// ACFPSO - Mean(mu)=7.54, Std-Dev(sigma)=1.01 RI=[5.51, 9.56]
// SPSO_AP_AD - Mean(mu)=7.3, Std-Dev(sigma)=0.99 RI=[5.32, 9.29]
// mPSO - Mean(mu)=7.17, Std-Dev(sigma)=1.01 RI=[5.15, 9.2]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=30.32, Std-Dev(sigma)=1.18 RI=[27.96, 32.69]
// ACFPSO - Mean(mu)=24.07, Std-Dev(sigma)=1.07 RI=[21.93, 26.22]
// mPSO - Mean(mu)=23.73, Std-Dev(sigma)=1.08 RI=[21.57, 25.88]
// SPSO_AP_AD - Mean(mu)=23.44, Std-Dev(sigma)=1.07 RI=[21.3, 25.58]
//
// Glicko2 rating:
// mjDE - Rating=1,832.7 RD=53.2 ro=0.06 RI=[1726.29, 1939.18]
// ACFPSO - Rating=1,429.1 RD=53.2 ro=0.06 RI=[1322.65, 1535.53]
// mPSO - Rating=1,385.5 RD=53.2 ro=0.06 RI=[1279.01, 1491.89]
// SPSO_AP_AD - Rating=1,352.7 RD=53.2 ro=0.06 RI=[1246.28, 1459.17]
//
// Game results:
// mjDE [win=77, lose=16, draw=0]
// 	 Against:{ACFPSO=[win=25, lose=6, draw=0], SPSO_AP_AD=[win=28, lose=3, draw=0], mPSO=[win=24, lose=7, draw=0]}
// 	 Problems:{GMPBEval20001=[win=77, lose=16, draw=0]}
// ACFPSO [win=40, lose=53, draw=0]
// 	 Against:{SPSO_AP_AD=[win=17, lose=14, draw=0], mjDE=[win=6, lose=25, draw=0], mPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval20001=[win=40, lose=53, draw=0]}
// mPSO [win=36, lose=57, draw=0]
// 	 Against:{ACFPSO=[win=14, lose=17, draw=0], SPSO_AP_AD=[win=15, lose=16, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{GMPBEval20001=[win=36, lose=57, draw=0]}
// SPSO_AP_AD [win=33, lose=60, draw=0]
// 	 Against:{ACFPSO=[win=14, lose=17, draw=0], mjDE=[win=3, lose=28, draw=0], mPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval20001=[win=33, lose=60, draw=0]}
// TrueSkill One-On-One rating:
// SPSO_AP_AD - Mean(mu)=6.71, Std-Dev(sigma)=1 RI=[4.71, 8.72]
// ACFPSO - Mean(mu)=6.18, Std-Dev(sigma)=1 RI=[4.17, 8.19]
// mjDE - Mean(mu)=6.15, Std-Dev(sigma)=1 RI=[4.15, 8.15]
// mPSO - Mean(mu)=5.48, Std-Dev(sigma)=0.99 RI=[3.5, 7.46]
//
// TrueSkill Free-For-All rating:
// SPSO_AP_AD - Mean(mu)=26.29, Std-Dev(sigma)=1.04 RI=[24.21, 28.37]
// mjDE - Mean(mu)=25.76, Std-Dev(sigma)=1.04 RI=[23.68, 27.85]
// ACFPSO - Mean(mu)=25.74, Std-Dev(sigma)=1.05 RI=[23.65, 27.83]
// mPSO - Mean(mu)=24.59, Std-Dev(sigma)=1.06 RI=[22.47, 26.72]
//
// Glicko2 rating:
// SPSO_AP_AD - Rating=1,549.1 RD=53.2 ro=0.06 RI=[1442.65, 1655.53]
// mjDE - Rating=1,527.3 RD=53.2 ro=0.06 RI=[1420.83, 1633.72]
// ACFPSO - Rating=1,516.4 RD=53.2 ro=0.06 RI=[1409.92, 1622.81]
// mPSO - Rating=1,407.3 RD=53.2 ro=0.06 RI=[1300.83, 1513.71]
//
// Game results:
// SPSO_AP_AD [win=51, lose=42, draw=0]
// 	 Against:{ACFPSO=[win=19, lose=12, draw=0], mjDE=[win=14, lose=17, draw=0], mPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval21000=[win=51, lose=42, draw=0]}
// mjDE [win=49, lose=44, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], SPSO_AP_AD=[win=17, lose=14, draw=0], mPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval21000=[win=49, lose=44, draw=0]}
// ACFPSO [win=48, lose=45, draw=0]
// 	 Against:{SPSO_AP_AD=[win=12, lose=19, draw=0], mjDE=[win=16, lose=15, draw=0], mPSO=[win=20, lose=11, draw=0]}
// 	 Problems:{GMPBEval21000=[win=48, lose=45, draw=0]}
// mPSO [win=38, lose=55, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], SPSO_AP_AD=[win=13, lose=18, draw=0], mjDE=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval21000=[win=38, lose=55, draw=0]}
// TrueSkill One-On-One rating:
// SPSO_AP_AD - Mean(mu)=7.58, Std-Dev(sigma)=1.01 RI=[5.56, 9.6]
// mPSO - Mean(mu)=6.93, Std-Dev(sigma)=0.99 RI=[4.96, 8.91]
// mjDE - Mean(mu)=6.89, Std-Dev(sigma)=0.99 RI=[4.9, 8.87]
// ACFPSO - Mean(mu)=6.59, Std-Dev(sigma)=1 RI=[4.59, 8.58]
//
// TrueSkill Free-For-All rating:
// SPSO_AP_AD - Mean(mu)=25.54, Std-Dev(sigma)=1.03 RI=[23.47, 27.61]
// mPSO - Mean(mu)=24.75, Std-Dev(sigma)=1.05 RI=[22.66, 26.84]
// mjDE - Mean(mu)=24.7, Std-Dev(sigma)=1.04 RI=[22.62, 26.78]
// ACFPSO - Mean(mu)=24.52, Std-Dev(sigma)=1.05 RI=[22.41, 26.62]
//
// Glicko2 rating:
// SPSO_AP_AD - Rating=1,549.1 RD=53.2 ro=0.06 RI=[1442.65, 1655.53]
// mPSO - Rating=1,494.5 RD=53.2 ro=0.06 RI=[1388.1, 1600.99]
// mjDE - Rating=1,483.6 RD=53.2 ro=0.06 RI=[1377.19, 1590.08]
// ACFPSO - Rating=1,472.7 RD=53.2 ro=0.06 RI=[1366.28, 1579.17]
//
// Game results:
// SPSO_AP_AD [win=51, lose=42, draw=0]
// 	 Against:{ACFPSO=[win=18, lose=13, draw=0], mPSO=[win=17, lose=14, draw=0], mjDE=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval22000=[win=51, lose=42, draw=0]}
// mPSO [win=46, lose=47, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval22000=[win=46, lose=47, draw=0]}
// mjDE [win=45, lose=48, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], SPSO_AP_AD=[win=15, lose=16, draw=0], mPSO=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval22000=[win=45, lose=48, draw=0]}
// ACFPSO [win=44, lose=49, draw=0]
// 	 Against:{SPSO_AP_AD=[win=13, lose=18, draw=0], mPSO=[win=15, lose=16, draw=0], mjDE=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval22000=[win=44, lose=49, draw=0]}
// TrueSkill One-On-One rating:
// SPSO_AP_AD - Mean(mu)=7.46, Std-Dev(sigma)=1.03 RI=[5.41, 9.52]
// mPSO - Mean(mu)=6.77, Std-Dev(sigma)=0.98 RI=[4.81, 8.74]
// mjDE - Mean(mu)=6.58, Std-Dev(sigma)=1 RI=[4.59, 8.58]
// ACFPSO - Mean(mu)=6.45, Std-Dev(sigma)=0.99 RI=[4.46, 8.43]
//
// TrueSkill Free-For-All rating:
// SPSO_AP_AD - Mean(mu)=25.9, Std-Dev(sigma)=1.05 RI=[23.79, 28.01]
// mjDE - Mean(mu)=24.75, Std-Dev(sigma)=1.04 RI=[22.67, 26.83]
// mPSO - Mean(mu)=24.75, Std-Dev(sigma)=1.04 RI=[22.68, 26.82]
// ACFPSO - Mean(mu)=24.39, Std-Dev(sigma)=1.05 RI=[22.29, 26.49]
//
// Glicko2 rating:
// SPSO_AP_AD - Rating=1,570.9 RD=53.2 ro=0.06 RI=[1464.47, 1677.35]
// mjDE - Rating=1,494.5 RD=53.2 ro=0.06 RI=[1388.1, 1600.99]
// mPSO - Rating=1,494.5 RD=53.2 ro=0.06 RI=[1388.1, 1600.99]
// ACFPSO - Rating=1,440 RD=53.2 ro=0.06 RI=[1333.56, 1546.44]
//
// Game results:
// SPSO_AP_AD [win=53, lose=40, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], mPSO=[win=18, lose=13, draw=0], mjDE=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval23000=[win=53, lose=40, draw=0]}
// mjDE [win=46, lose=47, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], SPSO_AP_AD=[win=16, lose=15, draw=0], mPSO=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval23000=[win=46, lose=47, draw=0]}
// mPSO [win=46, lose=47, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], SPSO_AP_AD=[win=13, lose=18, draw=0], mjDE=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval23000=[win=46, lose=47, draw=0]}
// ACFPSO [win=41, lose=52, draw=0]
// 	 Against:{SPSO_AP_AD=[win=11, lose=20, draw=0], mPSO=[win=15, lose=16, draw=0], mjDE=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval23000=[win=41, lose=52, draw=0]}
// TrueSkill One-On-One rating:
// SPSO_AP_AD - Mean(mu)=7.23, Std-Dev(sigma)=1.02 RI=[5.2, 9.27]
// mjDE - Mean(mu)=6.96, Std-Dev(sigma)=0.99 RI=[4.98, 8.95]
// mPSO - Mean(mu)=6.88, Std-Dev(sigma)=1 RI=[4.89, 8.88]
// ACFPSO - Mean(mu)=5.92, Std-Dev(sigma)=0.98 RI=[3.95, 7.89]
//
// TrueSkill Free-For-All rating:
// SPSO_AP_AD - Mean(mu)=25.61, Std-Dev(sigma)=1.05 RI=[23.51, 27.7]
// mPSO - Mean(mu)=25.08, Std-Dev(sigma)=1.04 RI=[22.99, 27.17]
// mjDE - Mean(mu)=25.05, Std-Dev(sigma)=1.03 RI=[22.99, 27.1]
// ACFPSO - Mean(mu)=23.88, Std-Dev(sigma)=1.06 RI=[21.76, 25.99]
//
// Glicko2 rating:
// SPSO_AP_AD - Rating=1,549.1 RD=53.2 ro=0.06 RI=[1442.65, 1655.53]
// mPSO - Rating=1,516.4 RD=53.2 ro=0.06 RI=[1409.92, 1622.81]
// mjDE - Rating=1,516.4 RD=53.2 ro=0.06 RI=[1409.92, 1622.81]
// ACFPSO - Rating=1,418.2 RD=53.2 ro=0.06 RI=[1311.74, 1524.62]
//
// Game results:
// SPSO_AP_AD [win=51, lose=42, draw=0]
// 	 Against:{ACFPSO=[win=19, lose=12, draw=0], mPSO=[win=18, lose=13, draw=0], mjDE=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval24000=[win=51, lose=42, draw=0]}
// mPSO [win=48, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=18, lose=13, draw=0], SPSO_AP_AD=[win=13, lose=18, draw=0], mjDE=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval24000=[win=48, lose=45, draw=0]}
// mjDE [win=48, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=17, lose=14, draw=0], SPSO_AP_AD=[win=17, lose=14, draw=0], mPSO=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval24000=[win=48, lose=45, draw=0]}
// ACFPSO [win=39, lose=54, draw=0]
// 	 Against:{SPSO_AP_AD=[win=12, lose=19, draw=0], mPSO=[win=13, lose=18, draw=0], mjDE=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval24000=[win=39, lose=54, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=7.17, Std-Dev(sigma)=1.01 RI=[5.15, 9.18]
// SPSO_AP_AD - Mean(mu)=7.06, Std-Dev(sigma)=1.01 RI=[5.05, 9.07]
// mPSO - Mean(mu)=6.86, Std-Dev(sigma)=1 RI=[4.85, 8.87]
// ACFPSO - Mean(mu)=6.07, Std-Dev(sigma)=0.99 RI=[4.09, 8.06]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=25.8, Std-Dev(sigma)=1.04 RI=[23.73, 27.88]
// SPSO_AP_AD - Mean(mu)=25.56, Std-Dev(sigma)=1.04 RI=[23.47, 27.65]
// mPSO - Mean(mu)=25.38, Std-Dev(sigma)=1.05 RI=[23.28, 27.49]
// ACFPSO - Mean(mu)=24.39, Std-Dev(sigma)=1.06 RI=[22.27, 26.51]
//
// Glicko2 rating:
// mjDE - Rating=1,570.9 RD=53.2 ro=0.06 RI=[1464.47, 1677.35]
// SPSO_AP_AD - Rating=1,516.4 RD=53.2 ro=0.06 RI=[1409.92, 1622.81]
// mPSO - Rating=1,494.5 RD=53.2 ro=0.06 RI=[1388.1, 1600.99]
// ACFPSO - Rating=1,418.2 RD=53.2 ro=0.06 RI=[1311.74, 1524.62]
//
// Game results:
// mjDE [win=53, lose=40, draw=0]
// 	 Against:{ACFPSO=[win=18, lose=13, draw=0], SPSO_AP_AD=[win=18, lose=13, draw=0], mPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval25000=[win=53, lose=40, draw=0]}
// SPSO_AP_AD [win=48, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=19, lose=12, draw=0], mjDE=[win=13, lose=18, draw=0], mPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval25000=[win=48, lose=45, draw=0]}
// mPSO [win=46, lose=47, draw=0]
// 	 Against:{ACFPSO=[win=17, lose=14, draw=0], SPSO_AP_AD=[win=15, lose=16, draw=0], mjDE=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval25000=[win=46, lose=47, draw=0]}
// ACFPSO [win=39, lose=54, draw=0]
// 	 Against:{SPSO_AP_AD=[win=12, lose=19, draw=0], mjDE=[win=13, lose=18, draw=0], mPSO=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval25000=[win=39, lose=54, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=13.47, Std-Dev(sigma)=1.3 RI=[10.86, 16.08]
// mPSO - Mean(mu)=9.15, Std-Dev(sigma)=1.03 RI=[7.09, 11.21]
// ACFPSO - Mean(mu)=8.1, Std-Dev(sigma)=1.01 RI=[6.08, 10.11]
// SPSO_AP_AD - Mean(mu)=6.98, Std-Dev(sigma)=1.03 RI=[4.93, 9.04]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=29.64, Std-Dev(sigma)=1.22 RI=[27.2, 32.09]
// mPSO - Mean(mu)=24.21, Std-Dev(sigma)=1.07 RI=[22.08, 26.35]
// ACFPSO - Mean(mu)=22.65, Std-Dev(sigma)=1.08 RI=[20.49, 24.81]
// SPSO_AP_AD - Mean(mu)=22.07, Std-Dev(sigma)=1.11 RI=[19.85, 24.29]
//
// Glicko2 rating:
// mjDE - Rating=1,854.6 RD=53.2 ro=0.06 RI=[1748.11, 1961]
// mPSO - Rating=1,461.8 RD=53.2 ro=0.06 RI=[1355.37, 1568.26]
// ACFPSO - Rating=1,363.6 RD=53.2 ro=0.06 RI=[1257.19, 1470.08]
// SPSO_AP_AD - Rating=1,320 RD=53.2 ro=0.06 RI=[1213.55, 1426.44]
//
// Game results:
// mjDE [win=79, lose=14, draw=0]
// ...
// SPSO_AP_AD - Mean(mu)=7.49, Std-Dev(sigma)=1.04 RI=[5.42, 9.56]
// mPSO - Mean(mu)=6.46, Std-Dev(sigma)=0.98 RI=[4.5, 8.42]
// mjDE - Mean(mu)=5.9, Std-Dev(sigma)=0.99 RI=[3.93, 7.87]
//
// TrueSkill Free-For-All rating:
// SPSO_AP_AD - Mean(mu)=26.43, Std-Dev(sigma)=1.06 RI=[24.31, 28.55]
// ACFPSO - Mean(mu)=25.84, Std-Dev(sigma)=1.05 RI=[23.75, 27.94]
// mPSO - Mean(mu)=24.51, Std-Dev(sigma)=1.04 RI=[22.42, 26.6]
// mjDE - Mean(mu)=24.02, Std-Dev(sigma)=1.06 RI=[21.9, 26.13]
//
// Glicko2 rating:
// SPSO_AP_AD - Rating=1,614.5 RD=53.2 ro=0.06 RI=[1508.11, 1720.99]
// ACFPSO - Rating=1,516.4 RD=53.2 ro=0.06 RI=[1409.92, 1622.81]
// mPSO - Rating=1,472.7 RD=53.2 ro=0.06 RI=[1366.28, 1579.17]
// mjDE - Rating=1,396.4 RD=53.2 ro=0.06 RI=[1289.92, 1502.8]
//
// Game results:
// SPSO_AP_AD [win=57, lose=36, draw=0]
// 	 Against:{ACFPSO=[win=18, lose=13, draw=0], mPSO=[win=21, lose=10, draw=0], mjDE=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval44000=[win=57, lose=36, draw=0]}
// ACFPSO [win=48, lose=45, draw=0]
// 	 Against:{SPSO_AP_AD=[win=13, lose=18, draw=0], mPSO=[win=17, lose=14, draw=0], mjDE=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval44000=[win=48, lose=45, draw=0]}
// mPSO [win=44, lose=49, draw=0]
// 	 Against:{ACFPSO=[win=14, lose=17, draw=0], SPSO_AP_AD=[win=10, lose=21, draw=0], mjDE=[win=20, lose=11, draw=0]}
// 	 Problems:{GMPBEval44000=[win=44, lose=49, draw=0]}
// mjDE [win=37, lose=56, draw=0]
// 	 Against:{ACFPSO=[win=13, lose=18, draw=0], SPSO_AP_AD=[win=13, lose=18, draw=0], mPSO=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval44000=[win=37, lose=56, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=7.62, Std-Dev(sigma)=1.01 RI=[5.59, 9.64]
// SPSO_AP_AD - Mean(mu)=7.46, Std-Dev(sigma)=1.04 RI=[5.39, 9.54]
// mjDE - Mean(mu)=6.28, Std-Dev(sigma)=0.99 RI=[4.31, 8.26]
// mPSO - Mean(mu)=5.99, Std-Dev(sigma)=0.98 RI=[4.03, 7.95]
//
// TrueSkill Free-For-All rating:
// SPSO_AP_AD - Mean(mu)=26.47, Std-Dev(sigma)=1.06 RI=[24.35, 28.59]
// ACFPSO - Mean(mu)=25.87, Std-Dev(sigma)=1.05 RI=[23.78, 27.96]
// mjDE - Mean(mu)=24.51, Std-Dev(sigma)=1.05 RI=[22.41, 26.62]
// mPSO - Mean(mu)=24.07, Std-Dev(sigma)=1.05 RI=[21.97, 26.17]
//
// Glicko2 rating:
// SPSO_AP_AD - Rating=1,614.5 RD=53.2 ro=0.06 RI=[1508.11, 1720.99]
// ACFPSO - Rating=1,516.4 RD=53.2 ro=0.06 RI=[1409.92, 1622.81]
// mPSO - Rating=1,440 RD=53.2 ro=0.06 RI=[1333.56, 1546.44]
// mjDE - Rating=1,429.1 RD=53.2 ro=0.06 RI=[1322.65, 1535.53]
//
// Game results:
// SPSO_AP_AD [win=57, lose=36, draw=0]
// 	 Against:{ACFPSO=[win=18, lose=13, draw=0], mPSO=[win=21, lose=10, draw=0], mjDE=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval45000=[win=57, lose=36, draw=0]}
// ACFPSO [win=48, lose=45, draw=0]
// 	 Against:{SPSO_AP_AD=[win=13, lose=18, draw=0], mPSO=[win=17, lose=14, draw=0], mjDE=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval45000=[win=48, lose=45, draw=0]}
// mPSO [win=41, lose=52, draw=0]
// 	 Against:{ACFPSO=[win=14, lose=17, draw=0], SPSO_AP_AD=[win=10, lose=21, draw=0], mjDE=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval45000=[win=41, lose=52, draw=0]}
// mjDE [win=40, lose=53, draw=0]
// 	 Against:{ACFPSO=[win=13, lose=18, draw=0], SPSO_AP_AD=[win=13, lose=18, draw=0], mPSO=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval45000=[win=40, lose=53, draw=0]}
// TrueSkill One-On-One rating:
// SPSO_AP_AD - Mean(mu)=8.6, Std-Dev(sigma)=1.03 RI=[6.55, 10.66]
// mjDE - Mean(mu)=8.26, Std-Dev(sigma)=1.02 RI=[6.21, 10.3]
// mPSO - Mean(mu)=6.52, Std-Dev(sigma)=0.99 RI=[4.54, 8.5]
// ACFPSO - Mean(mu)=6.11, Std-Dev(sigma)=0.99 RI=[4.13, 8.1]
//
// TrueSkill Free-For-All rating:
// SPSO_AP_AD - Mean(mu)=26.55, Std-Dev(sigma)=1.06 RI=[24.44, 28.67]
// mjDE - Mean(mu)=26.16, Std-Dev(sigma)=1.04 RI=[24.07, 28.25]
// mPSO - Mean(mu)=24.15, Std-Dev(sigma)=1.04 RI=[22.06, 26.24]
// ACFPSO - Mean(mu)=23.73, Std-Dev(sigma)=1.07 RI=[21.59, 25.86]
//
// Glicko2 rating:
// mjDE - Rating=1,603.6 RD=53.2 ro=0.06 RI=[1497.2, 1710.08]
// SPSO_AP_AD - Rating=1,560 RD=53.2 ro=0.06 RI=[1453.56, 1666.44]
// mPSO - Rating=1,429.1 RD=53.2 ro=0.06 RI=[1322.65, 1535.53]
// ACFPSO - Rating=1,407.3 RD=53.2 ro=0.06 RI=[1300.83, 1513.71]
//
// Game results:
// mjDE [win=56, lose=37, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], SPSO_AP_AD=[win=16, lose=15, draw=0], mPSO=[win=20, lose=11, draw=0]}
// 	 Problems:{GMPBEval45001=[win=56, lose=37, draw=0]}
// SPSO_AP_AD [win=52, lose=41, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], mjDE=[win=15, lose=16, draw=0], mPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval45001=[win=52, lose=41, draw=0]}
// mPSO [win=40, lose=53, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval45001=[win=40, lose=53, draw=0]}
// ACFPSO [win=38, lose=55, draw=0]
// 	 Against:{SPSO_AP_AD=[win=11, lose=20, draw=0], mjDE=[win=11, lose=20, draw=0], mPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval45001=[win=38, lose=55, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=9.18, Std-Dev(sigma)=1.08 RI=[7.02, 11.35]
// SPSO_AP_AD - Mean(mu)=7.16, Std-Dev(sigma)=1.02 RI=[5.11, 9.21]
// mjDE - Mean(mu)=6.54, Std-Dev(sigma)=1.01 RI=[4.53, 8.56]
// mPSO - Mean(mu)=5.64, Std-Dev(sigma)=0.97 RI=[3.69, 7.59]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=27.58, Std-Dev(sigma)=1.07 RI=[25.45, 29.72]
// SPSO_AP_AD - Mean(mu)=25.57, Std-Dev(sigma)=1.06 RI=[23.45, 27.7]
// mjDE - Mean(mu)=24.49, Std-Dev(sigma)=1.06 RI=[22.38, 26.61]
// mPSO - Mean(mu)=23.24, Std-Dev(sigma)=1.06 RI=[21.12, 25.35]
//
// Glicko2 rating:
// ACFPSO - Rating=1,636.4 RD=53.2 ro=0.06 RI=[1529.92, 1742.81]
// SPSO_AP_AD - Rating=1,560 RD=53.2 ro=0.06 RI=[1453.56, 1666.44]
// mjDE - Rating=1,440 RD=53.2 ro=0.06 RI=[1333.56, 1546.44]
// mPSO - Rating=1,363.6 RD=53.2 ro=0.06 RI=[1257.19, 1470.08]
//
// Game results:
// ACFPSO [win=59, lose=34, draw=0]
// 	 Against:{SPSO_AP_AD=[win=18, lose=13, draw=0], mjDE=[win=22, lose=9, draw=0], mPSO=[win=19, lose=12, draw=0]}
// 	 Problems:{GMPBEval46000=[win=59, lose=34, draw=0]}
// SPSO_AP_AD [win=52, lose=41, draw=0]
// 	 Against:{ACFPSO=[win=13, lose=18, draw=0], mjDE=[win=17, lose=14, draw=0], mPSO=[win=22, lose=9, draw=0]}
// 	 Problems:{GMPBEval46000=[win=52, lose=41, draw=0]}
// mjDE [win=41, lose=52, draw=0]
// 	 Against:{ACFPSO=[win=9, lose=22, draw=0], SPSO_AP_AD=[win=14, lose=17, draw=0], mPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval46000=[win=41, lose=52, draw=0]}
// mPSO [win=34, lose=59, draw=0]
// 	 Against:{ACFPSO=[win=12, lose=19, draw=0], SPSO_AP_AD=[win=9, lose=22, draw=0], mjDE=[win=13, lose=18, draw=0]}
// 	 Problems:{GMPBEval46000=[win=34, lose=59, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=8.75, Std-Dev(sigma)=1.05 RI=[6.65, 10.85]
// SPSO_AP_AD - Mean(mu)=7.13, Std-Dev(sigma)=1.07 RI=[4.99, 9.26]
// mjDE - Mean(mu)=6.21, Std-Dev(sigma)=0.99 RI=[4.22, 8.2]
// mPSO - Mean(mu)=5.93, Std-Dev(sigma)=0.98 RI=[3.98, 7.89]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=27.1, Std-Dev(sigma)=1.06 RI=[24.97, 29.23]
// SPSO_AP_AD - Mean(mu)=26.19, Std-Dev(sigma)=1.09 RI=[24.02, 28.36]
// mjDE - Mean(mu)=23.85, Std-Dev(sigma)=1.06 RI=[21.74, 25.96]
// mPSO - Mean(mu)=23.57, Std-Dev(sigma)=1.05 RI=[21.48, 25.66]
//
// Glicko2 rating:
// ACFPSO - Rating=1,603.6 RD=53.2 ro=0.06 RI=[1497.2, 1710.08]
// SPSO_AP_AD - Rating=1,603.6 RD=53.2 ro=0.06 RI=[1497.2, 1710.08]
// mjDE - Rating=1,396.4 RD=53.2 ro=0.06 RI=[1289.92, 1502.8]
// mPSO - Rating=1,396.4 RD=53.2 ro=0.06 RI=[1289.92, 1502.8]
//
// Game results:
// ACFPSO [win=56, lose=37, draw=0]
// 	 Against:{SPSO_AP_AD=[win=17, lose=14, draw=0], mjDE=[win=21, lose=10, draw=0], mPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval47000=[win=56, lose=37, draw=0]}
// SPSO_AP_AD [win=56, lose=37, draw=0]
// 	 Against:{ACFPSO=[win=14, lose=17, draw=0], mjDE=[win=21, lose=10, draw=0], mPSO=[win=21, lose=10, draw=0]}
// 	 Problems:{GMPBEval47000=[win=56, lose=37, draw=0]}
// mjDE [win=37, lose=56, draw=0]
// 	 Against:{ACFPSO=[win=10, lose=21, draw=0], SPSO_AP_AD=[win=10, lose=21, draw=0], mPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval47000=[win=37, lose=56, draw=0]}
// mPSO [win=37, lose=56, draw=0]
// 	 Against:{ACFPSO=[win=13, lose=18, draw=0], SPSO_AP_AD=[win=10, lose=21, draw=0], mjDE=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval47000=[win=37, lose=56, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=8.36, Std-Dev(sigma)=1.03 RI=[6.29, 10.43]
// SPSO_AP_AD - Mean(mu)=6.76, Std-Dev(sigma)=1.06 RI=[4.64, 8.89]
// mjDE - Mean(mu)=6.46, Std-Dev(sigma)=0.99 RI=[4.48, 8.43]
// mPSO - Mean(mu)=6.39, Std-Dev(sigma)=0.99 RI=[4.42, 8.37]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=26.63, Std-Dev(sigma)=1.05 RI=[24.52, 28.74]
// SPSO_AP_AD - Mean(mu)=26.02, Std-Dev(sigma)=1.1 RI=[23.82, 28.22]
// mPSO - Mean(mu)=24.37, Std-Dev(sigma)=1.04 RI=[22.29, 26.46]
// mjDE - Mean(mu)=24.21, Std-Dev(sigma)=1.05 RI=[22.11, 26.31]
//
// Glicko2 rating:
// SPSO_AP_AD - Rating=1,581.8 RD=53.2 ro=0.06 RI=[1475.38, 1688.26]
// ACFPSO - Rating=1,560 RD=53.2 ro=0.06 RI=[1453.56, 1666.44]
// mPSO - Rating=1,450.9 RD=53.2 ro=0.06 RI=[1344.47, 1557.35]
// mjDE - Rating=1,407.3 RD=53.2 ro=0.06 RI=[1300.83, 1513.71]
//
// Game results:
// SPSO_AP_AD [win=54, lose=39, draw=0]
// 	 Against:{ACFPSO=[win=16, lose=15, draw=0], mjDE=[win=20, lose=11, draw=0], mPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval48000=[win=54, lose=39, draw=0]}
// ACFPSO [win=52, lose=41, draw=0]
// 	 Against:{SPSO_AP_AD=[win=15, lose=16, draw=0], mjDE=[win=20, lose=11, draw=0], mPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval48000=[win=52, lose=41, draw=0]}
// mPSO [win=42, lose=51, draw=0]
// 	 Against:{ACFPSO=[win=14, lose=17, draw=0], SPSO_AP_AD=[win=13, lose=18, draw=0], mjDE=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval48000=[win=42, lose=51, draw=0]}
// mjDE [win=38, lose=55, draw=0]
// 	 Against:{ACFPSO=[win=11, lose=20, draw=0], SPSO_AP_AD=[win=11, lose=20, draw=0], mPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval48000=[win=38, lose=55, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=8.33, Std-Dev(sigma)=1.05 RI=[6.23, 10.43]
// mPSO - Mean(mu)=6.62, Std-Dev(sigma)=0.98 RI=[4.66, 8.57]
// mjDE - Mean(mu)=6.49, Std-Dev(sigma)=1 RI=[4.5, 8.48]
// SPSO_AP_AD - Mean(mu)=6.12, Std-Dev(sigma)=1.05 RI=[4.03, 8.22]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=26.85, Std-Dev(sigma)=1.06 RI=[24.73, 28.97]
// SPSO_AP_AD - Mean(mu)=25.33, Std-Dev(sigma)=1.1 RI=[23.14, 27.52]
// mPSO - Mean(mu)=24.54, Std-Dev(sigma)=1.04 RI=[22.47, 26.61]
// mjDE - Mean(mu)=24.48, Std-Dev(sigma)=1.05 RI=[22.39, 26.58]
//
// Glicko2 rating:
// ACFPSO - Rating=1,570.9 RD=53.2 ro=0.06 RI=[1464.47, 1677.35]
// SPSO_AP_AD - Rating=1,549.1 RD=53.2 ro=0.06 RI=[1442.65, 1655.53]
// mPSO - Rating=1,450.9 RD=53.2 ro=0.06 RI=[1344.47, 1557.35]
// mjDE - Rating=1,429.1 RD=53.2 ro=0.06 RI=[1322.65, 1535.53]
//
// Game results:
// ACFPSO [win=53, lose=40, draw=0]
// 	 Against:{SPSO_AP_AD=[win=16, lose=15, draw=0], mjDE=[win=21, lose=10, draw=0], mPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval49000=[win=53, lose=40, draw=0]}
// SPSO_AP_AD [win=51, lose=42, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], mjDE=[win=18, lose=13, draw=0], mPSO=[win=18, lose=13, draw=0]}
// 	 Problems:{GMPBEval49000=[win=51, lose=42, draw=0]}
// mPSO [win=42, lose=51, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], SPSO_AP_AD=[win=13, lose=18, draw=0], mjDE=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval49000=[win=42, lose=51, draw=0]}
// mjDE [win=40, lose=53, draw=0]
// 	 Against:{ACFPSO=[win=10, lose=21, draw=0], SPSO_AP_AD=[win=13, lose=18, draw=0], mPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval49000=[win=40, lose=53, draw=0]}
// TrueSkill One-On-One rating:
// ACFPSO - Mean(mu)=8.32, Std-Dev(sigma)=1.03 RI=[6.26, 10.38]
// mjDE - Mean(mu)=6.9, Std-Dev(sigma)=1 RI=[4.9, 8.89]
// mPSO - Mean(mu)=6.85, Std-Dev(sigma)=0.98 RI=[4.89, 8.81]
// SPSO_AP_AD - Mean(mu)=6.7, Std-Dev(sigma)=1.04 RI=[4.63, 8.78]
//
// TrueSkill Free-For-All rating:
// ACFPSO - Mean(mu)=26.3, Std-Dev(sigma)=1.05 RI=[24.19, 28.41]
// SPSO_AP_AD - Mean(mu)=25.28, Std-Dev(sigma)=1.08 RI=[23.12, 27.44]
// mjDE - Mean(mu)=24.5, Std-Dev(sigma)=1.05 RI=[22.4, 26.59]
// mPSO - Mean(mu)=24.3, Std-Dev(sigma)=1.04 RI=[22.23, 26.38]
//
// Glicko2 rating:
// ACFPSO - Rating=1,549.1 RD=53.2 ro=0.06 RI=[1442.65, 1655.53]
// SPSO_AP_AD - Rating=1,549.1 RD=53.2 ro=0.06 RI=[1442.65, 1655.53]
// mjDE - Rating=1,450.9 RD=53.2 ro=0.06 RI=[1344.47, 1557.35]
// mPSO - Rating=1,450.9 RD=53.2 ro=0.06 RI=[1344.47, 1557.35]
//
// Game results:
// ACFPSO [win=51, lose=42, draw=0]
// 	 Against:{SPSO_AP_AD=[win=16, lose=15, draw=0], mjDE=[win=19, lose=12, draw=0], mPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval50000=[win=51, lose=42, draw=0]}
// SPSO_AP_AD [win=51, lose=42, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], mjDE=[win=17, lose=14, draw=0], mPSO=[win=19, lose=12, draw=0]}
// 	 Problems:{GMPBEval50000=[win=51, lose=42, draw=0]}
// mjDE [win=42, lose=51, draw=0]
// 	 Against:{ACFPSO=[win=12, lose=19, draw=0], SPSO_AP_AD=[win=14, lose=17, draw=0], mPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval50000=[win=42, lose=51, draw=0]}
// mPSO [win=42, lose=51, draw=0]
// 	 Against:{ACFPSO=[win=15, lose=16, draw=0], SPSO_AP_AD=[win=12, lose=19, draw=0], mjDE=[win=15, lose=16, draw=0]}
// 	 Problems:{GMPBEval50000=[win=42, lose=51, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=7.49, Std-Dev(sigma)=1.02 RI=[5.44, 9.53]
// SPSO_AP_AD - Mean(mu)=6.82, Std-Dev(sigma)=1.02 RI=[4.78, 8.86]
// mPSO - Mean(mu)=6.71, Std-Dev(sigma)=1.01 RI=[4.69, 8.72]
// ACFPSO - Mean(mu)=4.7, Std-Dev(sigma)=0.99 RI=[2.71, 6.69]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=26.63, Std-Dev(sigma)=1.05 RI=[24.53, 28.73]
// SPSO_AP_AD - Mean(mu)=26.12, Std-Dev(sigma)=1.05 RI=[24.01, 28.22]
// mPSO - Mean(mu)=25.75, Std-Dev(sigma)=1.04 RI=[23.67, 27.84]
// ACFPSO - Mean(mu)=23.45, Std-Dev(sigma)=1.07 RI=[21.31, 25.59]
//
// Glicko2 rating:
// mjDE - Rating=1,603.6 RD=53.2 ro=0.06 RI=[1497.2, 1710.08]
// SPSO_AP_AD - Rating=1,527.3 RD=53.2 ro=0.06 RI=[1420.83, 1633.72]
// mPSO - Rating=1,516.4 RD=53.2 ro=0.06 RI=[1409.92, 1622.81]
// ACFPSO - Rating=1,352.7 RD=53.2 ro=0.06 RI=[1246.28, 1459.17]
//
// Game results:
// mjDE [win=56, lose=37, draw=0]
// 	 Against:{ACFPSO=[win=22, lose=9, draw=0], SPSO_AP_AD=[win=17, lose=14, draw=0], mPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval50001=[win=56, lose=37, draw=0]}
// SPSO_AP_AD [win=49, lose=44, draw=0]
// 	 Against:{ACFPSO=[win=18, lose=13, draw=0], mjDE=[win=14, lose=17, draw=0], mPSO=[win=17, lose=14, draw=0]}
// 	 Problems:{GMPBEval50001=[win=49, lose=44, draw=0]}
// mPSO [win=48, lose=45, draw=0]
// 	 Against:{ACFPSO=[win=20, lose=11, draw=0], SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=14, lose=17, draw=0]}
// 	 Problems:{GMPBEval50001=[win=48, lose=45, draw=0]}
// ACFPSO [win=33, lose=60, draw=0]
// 	 Against:{SPSO_AP_AD=[win=13, lose=18, draw=0], mjDE=[win=9, lose=22, draw=0], mPSO=[win=11, lose=20, draw=0]}
// 	 Problems:{GMPBEval50001=[win=33, lose=60, draw=0]}
// TrueSkill One-On-One rating:
// SPSO_AP_AD - Mean(mu)=11.48, Std-Dev(sigma)=1.12 RI=[9.24, 13.71]
// ACFPSO - Mean(mu)=10.75, Std-Dev(sigma)=1.08 RI=[8.6, 12.91]
// mjDE - Mean(mu)=7.33, Std-Dev(sigma)=0.99 RI=[5.35, 9.31]
// mPSO - Mean(mu)=7.17, Std-Dev(sigma)=0.98 RI=[5.22, 9.12]
//
// TrueSkill Free-For-All rating:
// SPSO_AP_AD - Mean(mu)=27.75, Std-Dev(sigma)=1.08 RI=[25.58, 29.91]
// ACFPSO - Mean(mu)=26.91, Std-Dev(sigma)=1.07 RI=[24.76, 29.06]
// mjDE - Mean(mu)=21.89, Std-Dev(sigma)=1.08 RI=[19.72, 24.06]
// mPSO - Mean(mu)=21.75, Std-Dev(sigma)=1.07 RI=[19.62, 23.89]
//
// Glicko2 rating:
// SPSO_AP_AD - Rating=1,701.8 RD=53.2 ro=0.06 RI=[1595.38, 1808.27]
// ACFPSO - Rating=1,636.4 RD=53.2 ro=0.06 RI=[1529.92, 1742.81]
// mjDE - Rating=1,330.9 RD=53.2 ro=0.06 RI=[1224.46, 1437.35]
// mPSO - Rating=1,330.9 RD=53.2 ro=0.06 RI=[1224.46, 1437.35]
//
// Game results:
// SPSO_AP_AD [win=65, lose=28, draw=0]
// 	 Against:{ACFPSO=[win=17, lose=14, draw=0], mjDE=[win=24, lose=7, draw=0], mPSO=[win=24, lose=7, draw=0]}
// 	 Problems:{GMPBEval51000=[win=65, lose=28, draw=0]}
// ACFPSO [win=59, lose=34, draw=0]
// 	 Against:{SPSO_AP_AD=[win=14, lose=17, draw=0], mjDE=[win=23, lose=8, draw=0], mPSO=[win=22, lose=9, draw=0]}
// 	 Problems:{GMPBEval51000=[win=59, lose=34, draw=0]}
// mjDE [win=31, lose=62, draw=0]
// 	 Against:{ACFPSO=[win=8, lose=23, draw=0], SPSO_AP_AD=[win=7, lose=24, draw=0], mPSO=[win=16, lose=15, draw=0]}
// 	 Problems:{GMPBEval51000=[win=31, lose=62,

// %% [markdown]
// #### Visualize the results of dynamic optimization algorithms comparison
//
// A function that generates a sequence of evaluation numbers, increasing by sampleInterval, and adds an extra (evaluation) number immediately after each environment change.

// %%
fun generateSequence(changeFrequency: Int, environmentNumber: Int, sampleInterval: Int = 1000): List<Int> {
    val result = mutableListOf<Int>()
    // generate numbers increasing by sampleInterval
    for (i in sampleInterval..changeFrequency * environmentNumber step sampleInterval) {
        result.add(i)
        if (i % changeFrequency == 0 && i != changeFrequency * environmentNumber) {
            result.add(i + 1)   // add the next (evaluation) number just after the change happens
        }
    }
    return result
}

// %% [markdown]
// Import necessary classes from the letsPlot library, determine the number of algorithms, generate a sequence of x-values, and create the base plot, mapping the evaluation numbers to the "eval" key.

// %%
import org.jetbrains.letsPlot.commons.values.Color

val numAlgorithms = algPerf.size
val xValues = generateSequence(changeFrequency, environmentNumber)

var plot = letsPlot(mapOf("eval" to xValues))

// %% [markdown]
// For each algorithm, extract rating values and calculate the lower and upper bounds for rating deviations. Prepare data for plotting, including evaluation numbers, ratings, bounds, and algorithm labels. Add a line plot, a ribbon for rating deviations, and points to the plot for each algorithm.

// %%
for (i in 0 until numAlgorithms) {
    val yValues = algPerf[i].evalData.values.map { it.rating } // // extract the rating values for the current algorithm

    // calculate the lower and upper bounds for the rating deviations
    val lowerBounds = algPerf[i].evalData.values.map { it.rating - it.ratingDeviation }
    val upperBounds = algPerf[i].evalData.values.map { it.rating + it.ratingDeviation }

    // prepare data for the current algorithm
    val data = mapOf(
        "eval" to xValues,
        "rating" to yValues,
        "lowerBounds" to lowerBounds,
        "upperBounds" to upperBounds,
        "Algorithm" to List(yValues.size) { algPerf[i].name }  // label each algorithm
    )

    // add rating line to the plot (cycling through predefined colors)
    plot += geomLine(data = data) {
        x = "eval"
        y = "rating"
        color = "Algorithm"
    }

    // add rating deviation ribbon to the plot (using the same color with transparency)
    plot += geomRibbon(data = data, alpha = 0.2) {
        x = "eval"
        ymin = "lowerBounds"
        ymax = "upperBounds"
        color = "Algorithm"
        fill = "Algorithm"
    }

    // add points at the same locations as the line
    plot += geomPoint(data = data) {
        x = "eval"
        y = "rating"
        color = "Algorithm"
    }
}

// %% [markdown]
// Find the minimum and maximum ratings in the entire comparison if you want to zoom in on the plot.

// %%
val allRatings = algPerf.flatMap { it.evalData.values.map { it.rating } }
val minY = allRatings.minOrNull() ?: 0.0
val maxY = allRatings.maxOrNull() ?: 1.0

//plot += scaleYContinuous(limits = minY to maxY)

// %% [markdown]
// Define the range of x-values (evaluations) you want to show on the plot.

// %%
val minX = 1000
val maxX = 25000

plot += scaleXContinuous(
    breaks = xValues,
    //labels = xValues.take(valuesToShow).map { it.toInt().toString() }, // specify the tick marks
    limits = minX to maxX
)

// %% [markdown]
// Optionally add vertical lines (at the evaluation where change happens).

// %%
val verticalLines = (changeFrequency..changeFrequency * environmentNumber step changeFrequency).toList()
verticalLines.forEach { evalPoint ->
    plot += geomVLine(xintercept = evalPoint, color = "grey", linetype = "dashed") {
        // you can customize the appearance here
    }
}

// %% [markdown]
// Define the plot's title, width, and height and show it.

// %%
val title = "Dynamic optimization algorithms ratings during optimization"
val width = 1500
val height = 750

plot += ggsize(width, height)
plot += ggtitle(title)
plot += ggtb()  // enable Zoom and Pan interactivity

plot.show()
// Out:
//    <div id="KwSkex"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"Dynamic optimization algorithms ratings during optimization"
// },
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":1500.0,
// "height":750.0
// },
// "kind":"plot",
// "ggtoolbar":{
// },
// "scales":[{
// "aesthetic":"x",
// "breaks":[1000.0,2000.0,3000.0,4000.0,5000.0,5001.0,6000.0,7000.0,8000.0,9000.0,10000.0,10001.0,11000.0,12000.0,13000.0,14000.0,15000.0,15001.0,16000.0,17000.0,18000.0,19000.0,20000.0,20001.0,21000.0,22000.0,23000.0,24000.0,25000.0,25001.0,26000.0,27000.0,28000.0,29000.0,30000.0,30001.0,31000.0,32000.0,33000.0,34000.0,35000.0,35001.0,36000.0,37000.0,38000.0,39000.0,40000.0,40001.0,41000.0,42000.0,43000.0,44000.0,45000.0,45001.0,46000.0,47000.0,48000.0,49000.0,50000.0,50001.0,51000.0,52000.0,53000.0,54000.0,55000.0,55001.0,56000.0,57000.0,58000.0,59000.0,60000.0,60001.0,61000.0,62000.0,63000.0,64000.0,65000.0,65001.0,66000.0,67000.0,68000.0,69000.0,70000.0,70001.0,71000.0,72000.0,73000.0,74000.0,75000.0,75001.0,76000.0,77000.0,78000.0,79000.0,80000.0,80001.0,81000.0,82000.0,83000.0,84000.0,85000.0,85001.0,86000.0,87000.0,88000.0,89000.0,90000.0,90001.0,91000.0,92000.0,93000.0,94000.0,95000.0,95001.0,96000.0,97000.0,98000.0,99000.0,100000.0,100001.0,101000.0,102000.0,103000.0,104000.0,105000.0,105001.0,106000.0,107000.0,108000.0,109000.0,110000.0,110001.0,111000.0,112000.0,113000.0,114000.0,115000.0,115001.0,116000.0,117000.0,118000.0,119000.0,120000.0,120001.0,121000.0,122000.0,123000.0,124000.0,125000.0,125001.0,126000.0,127000.0,128000.0,129000.0,130000.0,130001.0,131000.0,132000.0,133000.0,134000.0,135000.0,135001.0,136000.0,137000.0,138000.0,139000.0,140000.0,140001.0,141000.0,142000.0,143000.0,144000.0,145000.0,145001.0,146000.0,147000.0,148000.0,149000.0,150000.0,150001.0,151000.0,152000.0,153000.0,154000.0,155000.0,155001.0,156000.0,157000.0,158000.0,159000.0,160000.0,160001.0,161000.0,162000.0,163000.0,164000.0,165000.0,165001.0,166000.0,167000.0,168000.0,169000.0,170000.0,170001.0,171000.0,172000.0,173000.0,174000.0,175000.0,175001.0,176000.0,177000.0,178000.0,179000.0,180000.0,180001.0,181000.0,182000.0,183000.0,184000.0,185000.0,185001.0,186000.0,187000.0,188000.0,189000.0,190000.0,190001.0,191000.0,192000.0,193000.0,194000.0,195000.0,195001.0,196000.0,197000.0,198000.0,199000.0,200000.0,200001.0,201000.0,202000.0,203000.0,204000.0,205000.0,205001.0,206000.0,207000.0,208000.0,209000.0,210000.0,210001.0,211000.0,212000.0,213000.0,214000.0,215000.0,215001.0,216000.0,217000.0,218000.0,219000.0,220000.0,220001.0,221000.0,222000.0,223000.0,224000.0,225000.0,225001.0,226000.0,227000.0,228000.0,229000.0,230000.0,230001.0,231000.0,232000.0,233000.0,234000.0,235000.0,235001.0,236000.0,237000.0,238000.0,239000.0,240000.0,240001.0,241000.0,242000.0,243000.0,244000.0,245000.0,245001.0,246000.0,247000.0,248000.0,249000.0,250000.0,250001.0,251000.0,252000.0,253000.0,254000.0,255000.0,255001.0,256000.0,257000.0,258000.0,259000.0,260000.0,260001.0,261000.0,262000.0,263000.0,264000.0,265000.0,265001.0,266000.0,267000.0,268000.0,269000.0,270000.0,270001.0,271000.0,272000.0,273000.0,274000.0,275000.0,275001.0,276000.0,277000.0,278000.0,279000.0,280000.0,280001.0,281000.0,282000.0,283000.0,284000.0,285000.0,285001.0,286000.0,287000.0,288000.0,289000.0,290000.0,290001.0,291000.0,292000.0,293000.0,294000.0,295000.0,295001.0,296000.0,297000.0,298000.0,299000.0,300000.0,300001.0,301000.0,302000.0,303000.0,304000.0,305000.0,305001.0,306000.0,307000.0,308000.0,309000.0,310000.0,310001.0,311000.0,312000.0,313000.0,314000.0,315000.0,315001.0,316000.0,317000.0,318000.0,319000.0,320000.0,320001.0,321000.0,322000.0,323000.0,324000.0,325000.0,325001.0,326000.0,327000.0,328000.0,329000.0,330000.0,330001.0,331000.0,332000.0,333000.0,334000.0,335000.0,335001.0,336000.0,337000.0,338000.0,339000.0,340000.0,340001.0,341000.0,342000.0,343000.0,344000.0,345000.0,345001.0,346000.0,347000.0,348000.0,349000.0,350000.0,350001.0,351000.0,352000.0,353000.0,354000.0,355000.0,355001.0,356000.0,357000.0,358000.0,359000.0,360000.0,360001.0,361000.0,362000.0,363000.0,364000.0,365000.0,365001.0,366000.0,367000.0,368000.0,369000.0,370000.0,370001.0,371000.0,372000.0,373000.0,374000.0,375000.0,375001.0,376000.0,377000.0,378000.0,379000.0,380000.0,380001.0,381000.0,38200 ...
// "limits":[1000.0,25000.0]
// }],
// "layers":[{
// "mapping":{
// "x":"eval",
// "y":"rating",
// "color":"Algorithm"
// },
// "stat":"identity",
// "data":{
// "eval":[1000.0,2000.0,3000.0,4000.0,5000.0,5001.0,6000.0,7000.0,8000.0,9000.0,10000.0,10001.0,11000.0,12000.0,13000.0,14000.0,15000.0,15001.0,16000.0,17000.0,18000.0,19000.0,20000.0,20001.0,21000.0,22000.0,23000.0,24000.0,25000.0,25001.0,26000.0,27000.0,28000.0,29000.0,30000.0,30001.0,31000.0,32000.0,33000.0,34000.0,35000.0,35001.0,36000.0,37000.0,38000.0,39000.0,40000.0,40001.0,41000.0,42000.0,43000.0,44000.0,45000.0,45001.0,46000.0,47000.0,48000.0,49000.0,50000.0,50001.0,51000.0,52000.0,53000.0,54000.0,55000.0,55001.0,56000.0,57000.0,58000.0,59000.0,60000.0,60001.0,61000.0,62000.0,63000.0,64000.0,65000.0,65001.0,66000.0,67000.0,68000.0,69000.0,70000.0,70001.0,71000.0,72000.0,73000.0,74000.0,75000.0,75001.0,76000.0,77000.0,78000.0,79000.0,80000.0,80001.0,81000.0,82000.0,83000.0,84000.0,85000.0,85001.0,86000.0,87000.0,88000.0,89000.0,90000.0,90001.0,91000.0,92000.0,93000.0,94000.0,95000.0,95001.0,96000.0,97000.0,98000.0,99000.0,100000.0,100001.0,101000.0,102000.0,103000.0,104000.0,105000.0,105001.0,106000.0,107000.0,108000.0,109000.0,110000.0,110001.0,111000.0,112000.0,113000.0,114000.0,115000.0,115001.0,116000.0,117000.0,118000.0,119000.0,120000.0,120001.0,121000.0,122000.0,123000.0,124000.0,125000.0,125001.0,126000.0,127000.0,128000.0,129000.0,130000.0,130001.0,131000.0,132000.0,133000.0,134000.0,135000.0,135001.0,136000.0,137000.0,138000.0,139000.0,140000.0,140001.0,141000.0,142000.0,143000.0,144000.0,145000.0,145001.0,146000.0,147000.0,148000.0,149000.0,150000.0,150001.0,151000.0,152000.0,153000.0,154000.0,155000.0,155001.0,156000.0,157000.0,158000.0,159000.0,160000.0,160001.0,161000.0,162000.0,163000.0,164000.0,165000.0,165001.0,166000.0,167000.0,168000.0,169000.0,170000.0,170001.0,171000.0,172000.0,173000.0,174000.0,175000.0,175001.0,176000.0,177000.0,178000.0,179000.0,180000.0,180001.0,181000.0,182000.0,183000.0,184000.0,185000.0,185001.0,186000.0,187000.0,188000.0,189000.0,190000.0,190001.0,191000.0,192000.0,193000.0,194000.0,195000.0,195001.0,196000.0,197000.0,198000.0,199000.0,200000.0,200001.0,201000.0,202000.0,203000.0,204000.0,205000.0,205001.0,206000.0,207000.0,208000.0,209000.0,210000.0,210001.0,211000.0,212000.0,213000.0,214000.0,215000.0,215001.0,216000.0,217000.0,218000.0,219000.0,2

// %% [markdown]
// Optionally save the plot in the file.

// %%
val filename = "plot.svg"

ggsave(plot, filename)
// Out:
// D:\EARS\src\org\um\feri\ears\examples\dynopt\lets-plot-images\plot.svg
