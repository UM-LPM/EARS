// %% [markdown]
// ### Resources:
//
// * [Lets-Plot Usage Guide](https://nbviewer.org/github/JetBrains/lets-plot-kotlin/blob/master/docs/guide/user_guide.ipynb)
// * [GitHub Repository](https://github.com/JetBrains/lets-plot-kotlin)

// %%
%use lets-plot
// Out:
//    <div id="SaXUJd"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("SaXUJd").appendChild(div);
//            };
//            var e = document.getElementById("SaXUJd");
//            e.appendChild(script);
//        })();
//    </script>

// %%
data class EvaluationMetrics(
    val evalNumber: String,
    val rating: Double,
    val ratingDeviation: Double,
    var avgFitness: Double = 0.0, // average over all runs
    var fitnessDeviation: Double = 0.0
)

class AlgorithmPerformance(val name: String) {
    val ratings: LinkedHashMap<String, EvaluationMetrics> = LinkedHashMap()

    fun addRating(evalNumber: String, rating: Double, ratingDeviation: Double) {
        ratings[evalNumber] = EvaluationMetrics(evalNumber, rating, ratingDeviation)
    }

    fun setAvgFitness(evalNumber: String, avgFitness: Double) {
        ratings[evalNumber]?.avgFitness = avgFitness
    }

    fun setFitnessDeviation(evalNumber: String, stdDeviation: Double) {
        ratings[evalNumber]?.fitnessDeviation = stdDeviation
    }
}

// %%
import org.um.feri.ears.algorithms.DummyAlgorithm
import org.um.feri.ears.algorithms.NumberAlgorithm
import org.um.feri.ears.benchmark.Benchmark
import org.um.feri.ears.examples.MovingPeaksBenchmark
import org.um.feri.ears.statistic.rating_system.RatingType
import org.um.feri.ears.visualization.rating.RatingIntervalPlot
import java.io.File

Benchmark.printInfo = false
DummyAlgorithm.readFromJson = false
val displayRatingChart = false

val algResultDir =
    "D:${File.separator}EDOLAB-MATLAB${File.separator}Results${File.separator}Comparison${File.separator}DeleteAfterTest"

val benchmark = "$algResultDir${File.separator}MPB_Peaks10_ChangeFrequency5000_D5_ShiftSeverity1_Environments3"

val players = arrayListOf<NumberAlgorithm>(
    DummyAlgorithm("DSPSO", benchmark),
    DummyAlgorithm("mQSO", benchmark),
    DummyAlgorithm("RPSO", benchmark),
    DummyAlgorithm("mjDE", benchmark),
    DummyAlgorithm("mPSO", benchmark)
)

// prepare objects for storing the algorithms data
val algPerf = players.map { AlgorithmPerformance(it.id) }.toMutableList()

val runNumber = 31 // number of runs

// calculate the number of different problems
val changeFrequency = 5000
val environmentNumber = 3
val sampleInterval = 1000
val numOfProblems = (changeFrequency / sampleInterval) * environmentNumber + environmentNumber - 1

var evaluationNumber = sampleInterval
for (i in 0 until numOfProblems) {
    // create and execute benchmarks for every evaluation defined with sampleInterval
    val movingPeaksBenchmark = MovingPeaksBenchmark(evaluationNumber).apply {
        setDisplayRatingCharts(false)
        addAlgorithms(players)
        run(runNumber)
    }

    val tournamentResults = movingPeaksBenchmark.tournamentResults

    if (displayRatingChart) {
        RatingIntervalPlot.displayChart(
            tournamentResults.players,
            RatingType.GLICKO2,
            "Rating Interval for Eval$evaluationNumber"
        )
    }

    // store tournament results for every player (algorithm)
    tournamentResults.players.forEach { player ->
        algPerf.firstOrNull { it.name == player.id }?.apply {
            addRating(
                "mpbeval$evaluationNumber",
                player.glicko2Rating.rating,
                player.glicko2Rating.ratingDeviation
            )
        }
    }

    if (evaluationNumber % changeFrequency == 0) {
        evaluationNumber++
    } else if (evaluationNumber % sampleInterval == 0) {
        evaluationNumber += sampleInterval
    } else {
        evaluationNumber = evaluationNumber + sampleInterval - 1
    }
}
// Out:
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=4,03, Std-Dev(sigma)=1,09 RI=[1,86, 6,2]
// mjDE - Mean(mu)=3,51, Std-Dev(sigma)=1,03 RI=[1,46, 5,56]
// RPSO - Mean(mu)=2,62, Std-Dev(sigma)=1,04 RI=[0,54, 4,69]
// mQSO - Mean(mu)=0,51, Std-Dev(sigma)=0,91 RI=[−1,31, 2,33]
// DSPSO - Mean(mu)=−2,28, Std-Dev(sigma)=0,96 RI=[−4,19, −0,37]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=29,33, Std-Dev(sigma)=1,04 RI=[27,25, 31,41]
// RPSO - Mean(mu)=28,11, Std-Dev(sigma)=1,03 RI=[26,06, 30,17]
// mjDE - Mean(mu)=27,94, Std-Dev(sigma)=1,02 RI=[25,89, 29,99]
// mQSO - Mean(mu)=22,36, Std-Dev(sigma)=1,03 RI=[20,29, 24,42]
// DSPSO - Mean(mu)=19,06, Std-Dev(sigma)=1,15 RI=[16,76, 21,35]
//
// Glicko2 rating:
// mPSO - Rating=1.730,4 RD=50 ro=0,06 RI=[1630,43, 1830,43]
// mjDE - Rating=1.672,8 RD=50 ro=0,06 RI=[1572,82, 1772,82]
// RPSO - Rating=1.648,1 RD=50 ro=0,06 RI=[1548,13, 1748,13]
// mQSO - Rating=1.310,7 RD=50 ro=0,06 RI=[1210,72, 1410,72]
// DSPSO - Rating=1.137,9 RD=50 ro=0,06 RI=[1037,9, 1237,9]
//
// Game results:
// mPSO [win=90, lose=34, draw=0]
// 	 Against:{mQSO=[win=27, lose=4, draw=0], DSPSO=[win=29, lose=2, draw=0], RPSO=[win=13, lose=18, draw=0], mjDE=[win=21, lose=10, draw=0]}
// 	 Problems:{MPBEval1000=[win=90, lose=34, draw=0]}
// mjDE [win=83, lose=41, draw=0]
// 	 Against:{mQSO=[win=28, lose=3, draw=0], DSPSO=[win=30, lose=1, draw=0], RPSO=[win=15, lose=16, draw=0], mPSO=[win=10, lose=21, draw=0]}
// 	 Problems:{MPBEval1000=[win=83, lose=41, draw=0]}
// RPSO [win=80, lose=44, draw=0]
// 	 Against:{mQSO=[win=22, lose=9, draw=0], DSPSO=[win=24, lose=7, draw=0], mPSO=[win=18, lose=13, draw=0], mjDE=[win=16, lose=15, draw=0]}
// 	 Problems:{MPBEval1000=[win=80, lose=44, draw=0]}
// mQSO [win=39, lose=85, draw=0]
// 	 Against:{DSPSO=[win=23, lose=8, draw=0], RPSO=[win=9, lose=22, draw=0], mPSO=[win=4, lose=27, draw=0], mjDE=[win=3, lose=28, draw=0]}
// 	 Problems:{MPBEval1000=[win=39, lose=85, draw=0]}
// DSPSO [win=18, lose=106, draw=0]
// 	 Against:{mQSO=[win=8, lose=23, draw=0], RPSO=[win=7, lose=24, draw=0], mPSO=[win=2, lose=29, draw=0], mjDE=[win=1, lose=30, draw=0]}
// 	 Problems:{MPBEval1000=[win=18, lose=106, draw=0]}
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=7,15, Std-Dev(sigma)=1,19 RI=[4,77, 9,53]
// mQSO - Mean(mu)=4,87, Std-Dev(sigma)=0,99 RI=[2,88, 6,85]
// mjDE - Mean(mu)=2,9, Std-Dev(sigma)=0,97 RI=[0,97, 4,83]
// RPSO - Mean(mu)=1,53, Std-Dev(sigma)=0,96 RI=[−0,4, 3,45]
// DSPSO - Mean(mu)=−1,07, Std-Dev(sigma)=0,96 RI=[−2,99, 0,85]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=30,68, Std-Dev(sigma)=1,07 RI=[28,54, 32,83]
// mQSO - Mean(mu)=26,7, Std-Dev(sigma)=1,01 RI=[24,68, 28,72]
// mjDE - Mean(mu)=25,3, Std-Dev(sigma)=1,01 RI=[23,28, 27,32]
// RPSO - Mean(mu)=23,81, Std-Dev(sigma)=1,02 RI=[21,78, 25,85]
// DSPSO - Mean(mu)=18,62, Std-Dev(sigma)=1,15 RI=[16,33, 20,92]
//
// Glicko2 rating:
// mPSO - Rating=1.808,6 RD=50 ro=0,06 RI=[1708,61, 1908,61]
// mQSO - Rating=1.590,5 RD=50 ro=0,06 RI=[1490,53, 1690,53]
// mjDE - Rating=1.565,8 RD=50 ro=0,06 RI=[1465,84, 1665,84]
// RPSO - Rating=1.405,4 RD=50 ro=0,06 RI=[1305,36, 1505,36]
// DSPSO - Rating=1.129,7 RD=50 ro=0,06 RI=[1029,67, 1229,67]
//
// Game results:
// mPSO [win=99, lose=24, draw=1]
// 	 Against:{mQSO=[win=23, lose=8, draw=0], DSPSO=[win=29, lose=2, draw=0], RPSO=[win=23, lose=7, draw=1], mjDE=[win=24, lose=7, draw=0]}
// 	 Problems:{MPBEval2000=[win=99, lose=24, draw=1]}
// mQSO [win=73, lose=51, draw=0]
// 	 Against:{DSPSO=[win=29, lose=2, draw=0], RPSO=[win=22, lose=9, draw=0], mjDE=[win=14, lose=17, draw=0], mPSO=[win=8, lose=23, draw=0]}
// 	 Problems:{MPBEval2000=[win=73, lose=51, draw=0]}
// mjDE [win=70, lose=54, draw=0]
// 	 Against:{mQSO=[win=17, lose=14, draw=0], DSPSO=[win=29, lose=2, draw=0], RPSO=[win=17, lose=14, draw=0], mPSO=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval2000=[win=70, lose=54, draw=0]}
// RPSO [win=50, lose=73, draw=1]
// 	 Against:{mQSO=[win=9, lose=22, draw=0], DSPSO=[win=20, lose=11, draw=0], mjDE=[win=14, lose=17, draw=0], mPSO=[win=7, lose=23, draw=1]}
// 	 Problems:{MPBEval2000=[win=50, lose=73, draw=1]}
// DSPSO [win=17, lose=107, draw=0]
// 	 Against:{mQSO=[win=2, lose=29, draw=0], RPSO=[win=11, lose=20, draw=0], mjDE=[win=2, lose=29, draw=0], mPSO=[win=2, lose=29, draw=0]}
// 	 Problems:{MPBEval2000=[win=17, lose=107, draw=0]}
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=6,06, Std-Dev(sigma)=1,15 RI=[3,76, 8,37]
// mQSO - Mean(mu)=3,64, Std-Dev(sigma)=1 RI=[1,64, 5,64]
// mjDE - Mean(mu)=1,05, Std-Dev(sigma)=0,95 RI=[−0,84, 2,95]
// RPSO - Mean(mu)=0,1, Std-Dev(sigma)=0,94 RI=[−1,79, 1,98]
// DSPSO - Mean(mu)=−1,23, Std-Dev(sigma)=0,93 RI=[−3,09, 0,62]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=31,23, Std-Dev(sigma)=1,07 RI=[29,09, 33,37]
// mQSO - Mean(mu)=27,8, Std-Dev(sigma)=1,01 RI=[25,78, 29,83]
// mjDE - Mean(mu)=25,48, Std-Dev(sigma)=1 RI=[23,48, 27,49]
// RPSO - Mean(mu)=23,54, Std-Dev(sigma)=1,03 RI=[21,48, 25,6]
// DSPSO - Mean(mu)=20,41, Std-Dev(sigma)=1,1 RI=[18,21, 22,61]
//
// Glicko2 rating:
// mPSO - Rating=1.804,5 RD=50 ro=0,06 RI=[1704,49, 1904,49]
// mQSO - Rating=1.648,1 RD=50 ro=0,06 RI=[1548,13, 1748,13]
// mjDE - Rating=1.524,7 RD=50 ro=0,06 RI=[1424,69, 1624,69]
// RPSO - Rating=1.343,6 RD=50 ro=0,06 RI=[1243,64, 1443,64]
// DSPSO - Rating=1.179 RD=50 ro=0,06 RI=[1079,05, 1279,05]
//
// Game results:
// mPSO [win=98, lose=24, draw=2]
// 	 Against:{mQSO=[win=21, lose=10, draw=0], DSPSO=[win=28, lose=3, draw=0], RPSO=[win=24, lose=5, draw=2], mjDE=[win=25, lose=6, draw=0]}
// 	 Problems:{MPBEval3000=[win=98, lose=24, draw=2]}
// mQSO [win=80, lose=44, draw=0]
// 	 Against:{DSPSO=[win=31, lose=0, draw=0], RPSO=[win=24, lose=7, draw=0], mjDE=[win=15, lose=16, draw=0], mPSO=[win=10, lose=21, draw=0]}
// 	 Problems:{MPBEval3000=[win=80, lose=44, draw=0]}
// mjDE [win=65, lose=59, draw=0]
// 	 Against:{mQSO=[win=16, lose=15, draw=0], DSPSO=[win=26, lose=5, draw=0], RPSO=[win=17, lose=14, draw=0], mPSO=[win=6, lose=25, draw=0]}
// 	 Problems:{MPBEval3000=[win=65, lose=59, draw=0]}
// RPSO [win=42, lose=80, draw=2]
// 	 Against:{mQSO=[win=7, lose=24, draw=0], DSPSO=[win=16, lose=15, draw=0], mjDE=[win=14, lose=17, draw=0], mPSO=[win=5, lose=24, draw=2]}
// 	 Problems:{MPBEval3000=[win=42, lose=80, draw=2]}
// DSPSO [win=23, lose=101, draw=0]
// 	 Against:{mQSO=[win=0, lose=31, draw=0], RPSO=[win=15, lose=16, draw=0], mjDE=[win=5, lose=26, draw=0], mPSO=[win=3, lose=28, draw=0]}
// 	 Problems:{MPBEval3000=[win=23, lose=101, draw=0]}
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=6,49, Std-Dev(sigma)=1,14 RI=[4,21, 8,78]
// mQSO - Mean(mu)=4,32, Std-Dev(sigma)=1 RI=[2,33, 6,32]
// mjDE - Mean(mu)=1,87, Std-Dev(sigma)=0,95 RI=[−0,03, 3,76]
// DSPSO - Mean(mu)=0,07, Std-Dev(sigma)=0,92 RI=[−1,77, 1,9]
// RPSO - Mean(mu)=−0,09, Std-Dev(sigma)=0,94 RI=[−1,96, 1,78]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=30,45, Std-Dev(sigma)=1,06 RI=[28,32, 32,57]
// mQSO - Mean(mu)=27,35, Std-Dev(sigma)=1,01 RI=[25,33, 29,37]
// mjDE - Mean(mu)=25,1, Std-Dev(sigma)=1 RI=[23,1, 27,11]
// RPSO - Mean(mu)=21,84, Std-Dev(sigma)=1,05 RI=[19,75, 23,93]
// DSPSO - Mean(mu)=21,09, Std-Dev(sigma)=1,05 RI=[18,99, 23,19]
//
// Glicko2 rating:
// mPSO - Rating=1.804,5 RD=50 ro=0,06 RI=[1704,49, 1904,49]
// mQSO - Rating=1.639,9 RD=50 ro=0,06 RI=[1539,9, 1739,9]
// mjDE - Rating=1.532,9 RD=50 ro=0,06 RI=[1432,92, 1632,92]
// RPSO - Rating=1.286 RD=50 ro=0,06 RI=[1186,03, 1386,03]
// DSPSO - Rating=1.236,7 RD=50 ro=0,06 RI=[1136,65, 1336,65]
//
// Game results:
// mPSO [win=98, lose=24, draw=2]
// 	 Against:{mQSO=[win=21, lose=10, draw=0], DSPSO=[win=27, lose=4, draw=0], RPSO=[win=25, lose=4, draw=2], mjDE=[win=25, lose=6, draw=0]}
// 	 Problems:{MPBEval4000=[win=98, lose=24, draw=2]}
// mQSO [win=79, lose=45, draw=0]
// 	 Against:{DSPSO=[win=29, lose=2, draw=0], RPSO=[win=25, lose=6, draw=0], mjDE=[win=15, lose=16, draw=0], mPSO=[win=10, lose=21, draw=0]}
// 	 Problems:{MPBEval4000=[win=79, lose=45, draw=0]}
// mjDE [win=66, lose=58, draw=0]
// 	 Against:{mQSO=[win=16, lose=15, draw=0], DSPSO=[win=25, lose=6, draw=0], RPSO=[win=19, lose=12, draw=0], mPSO=[win=6, lose=25, draw=0]}
// 	 Problems:{MPBEval4000=[win=66, lose=58, draw=0]}
// RPSO [win=35, lose=87, draw=2]
// 	 Against:{mQSO=[win=6, lose=25, draw=0], DSPSO=[win=13, lose=18, draw=0], mjDE=[win=12, lose=19, draw=0], mPSO=[win=4, lose=25, draw=2]}
// 	 Problems:{MPBEval4000=[win=35, lose=87, draw=2]}
// DSPSO [win=30, lose=94, draw=0]
// 	 Against:{mQSO=[win=2, lose=29, draw=0], RPSO=[win=18, lose=13, draw=0], mjDE=[win=6, lose=25, draw=0], mPSO=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval4000=[win=30, lose=94, draw=0]}
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=6,27, Std-Dev(sigma)=1,17 RI=[3,94, 8,6]
// mQSO - Mean(mu)=3,6, Std-Dev(sigma)=0,99 RI=[1,61, 5,58]
// mjDE - Mean(mu)=2,18, Std-Dev(sigma)=0,95 RI=[0,29, 4,07]
// DSPSO - Mean(mu)=0,16, Std-Dev(sigma)=0,92 RI=[−1,68, 2]
// RPSO - Mean(mu)=−0,71, Std-Dev(sigma)=0,95 RI=[−2,61, 1,19]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=30,98, Std-Dev(sigma)=1,08 RI=[28,82, 33,13]
// mQSO - Mean(mu)=27,19, Std-Dev(sigma)=1,01 RI=[25,18, 29,21]
// mjDE - Mean(mu)=25,61, Std-Dev(sigma)=1 RI=[23,61, 27,6]
// DSPSO - Mean(mu)=22,06, Std-Dev(sigma)=1,05 RI=[19,97, 24,15]
// RPSO - Mean(mu)=21,78, Std-Dev(sigma)=1,07 RI=[19,64, 23,91]
//
// Glicko2 rating:
// mPSO - Rating=1.816,8 RD=50 ro=0,06 RI=[1716,84, 1916,84]
// mQSO - Rating=1.615,2 RD=50 ro=0,06 RI=[1515,21, 1715,21]
// mjDE - Rating=1.532,9 RD=50 ro=0,06 RI=[1432,92, 1632,92]
// DSPSO - Rating=1.269,6 RD=50 ro=0,06 RI=[1169,57, 1369,57]
// RPSO - Rating=1.265,5 RD=50 ro=0,06 RI=[1165,46, 1365,46]
//
// Game results:
// mPSO [win=100, lose=23, draw=1]
// 	 Against:{mQSO=[win=22, lose=9, draw=0], DSPSO=[win=26, lose=5, draw=0], RPSO=[win=26, lose=4, draw=1], mjDE=[win=26, lose=5, draw=0]}
// 	 Problems:{MPBEval5000=[win=100, lose=23, draw=1]}
// mQSO [win=76, lose=48, draw=0]
// 	 Against:{DSPSO=[win=27, lose=4, draw=0], RPSO=[win=25, lose=6, draw=0], mjDE=[win=15, lose=16, draw=0], mPSO=[win=9, lose=22, draw=0]}
// 	 Problems:{MPBEval5000=[win=76, lose=48, draw=0]}
// mjDE [win=66, lose=58, draw=0]
// 	 Against:{mQSO=[win=16, lose=15, draw=0], DSPSO=[win=24, lose=7, draw=0], RPSO=[win=21, lose=10, draw=0], mPSO=[win=5, lose=26, draw=0]}
// 	 Problems:{MPBEval5000=[win=66, lose=58, draw=0]}
// DSPSO [win=34, lose=90, draw=0]
// 	 Against:{mQSO=[win=4, lose=27, draw=0], RPSO=[win=18, lose=13, draw=0], mjDE=[win=7, lose=24, draw=0], mPSO=[win=5, lose=26, draw=0]}
// 	 Problems:{MPBEval5000=[win=34, lose=90, draw=0]}
// RPSO [win=33, lose=90, draw=1]
// 	 Against:{mQSO=[win=6, lose=25, draw=0], DSPSO=[win=13, lose=18, draw=0], mjDE=[win=10, lose=21, draw=0], mPSO=[win=4, lose=26, draw=1]}
// 	 Problems:{MPBEval5000=[win=33, lose=90, draw=1]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=12,97, Std-Dev(sigma)=1,61 RI=[9,76, 16,18]
// mPSO - Mean(mu)=9,75, Std-Dev(sigma)=1,24 RI=[7,27, 12,22]
// DSPSO - Mean(mu)=5,27, Std-Dev(sigma)=1 RI=[3,27, 7,26]
// mQSO - Mean(mu)=5,09, Std-Dev(sigma)=0,99 RI=[3,12, 7,07]
// RPSO - Mean(mu)=0,46, Std-Dev(sigma)=1,05 RI=[−1,63, 2,56]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=34,14, Std-Dev(sigma)=1,23 RI=[31,68, 36,61]
// mPSO - Mean(mu)=30,04, Std-Dev(sigma)=1,12 RI=[27,8, 32,29]
// DSPSO - Mean(mu)=22,65, Std-Dev(sigma)=1,08 RI=[20,49, 24,81]
// mQSO - Mean(mu)=22,04, Std-Dev(sigma)=1,07 RI=[19,89, 24,18]
// RPSO - Mean(mu)=14,74, Std-Dev(sigma)=1,29 RI=[12,15, 17,32]
//
// Glicko2 rating:
// mjDE - Rating=1.911,5 RD=50 ro=0,06 RI=[1811,48, 2011,48]
// mPSO - Rating=1.755,1 RD=50 ro=0,06 RI=[1655,12, 1855,12]
// mQSO - Rating=1.401,2 RD=50 ro=0,06 RI=[1301,25, 1501,25]
// DSPSO - Rating=1.360,1 RD=50 ro=0,06 RI=[1260,1, 1460,1]
// RPSO - Rating=1.072,1 RD=50 ro=0,06 RI=[972,06, 1172,06]
//
// Game results:
// mjDE [win=112, lose=12, draw=0]
// 	 Against:{mQSO=[win=27, lose=4, draw=0], DSPSO=[win=30, lose=1, draw=0], RPSO=[win=31, lose=0, draw=0], mPSO=[win=24, lose=7, draw=0]}
// 	 Problems:{MPBEval5001=[win=112, lose=12, draw=0]}
// mPSO [win=93, lose=31, draw=0]
// 	 Against:{mQSO=[win=27, lose=4, draw=0], DSPSO=[win=28, lose=3, draw=0], RPSO=[win=31, lose=0, draw=0], mjDE=[win=7, lose=24, draw=0]}
// 	 Problems:{MPBEval5001=[win=93, lose=31, draw=0]}
// mQSO [win=50, lose=74, draw=0]
// 	 Against:{DSPSO=[win=15, lose=16, draw=0], RPSO=[win=27, lose=4, draw=0], mjDE=[win=4, lose=27, draw=0], mPSO=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval5001=[win=50, lose=74, draw=0]}
// DSPSO [win=45, lose=79, draw=0]
// 	 Against:{mQSO=[win=16, lose=15, draw=0], RPSO=[win=25, lose=6, draw=0], mjDE=[win=1, lose=30, draw=0], mPSO=[win=3, lose=28, draw=0]}
// 	 Problems:{MPBEval5001=[win=45, lose=79, draw=0]}
// RPSO [win=10, lose=114, draw=0]
// 	 Against:{mQSO=[win=4, lose=27, draw=0], DSPSO=[win=6, lose=25, draw=0], mjDE=[win=0, lose=31, draw=0], mPSO=[win=0, lose=31, draw=0]}
// 	 Problems:{MPBEval5001=[win=10, lose=114, draw=0]}
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=6,93, Std-Dev(sigma)=1,15 RI=[4,62, 9,23]
// mQSO - Mean(mu)=5,77, Std-Dev(sigma)=1,01 RI=[3,75, 7,8]
// mjDE - Mean(mu)=3,29, Std-Dev(sigma)=0,93 RI=[1,42, 5,15]
// DSPSO - Mean(mu)=2,41, Std-Dev(sigma)=0,92 RI=[0,57, 4,25]
// RPSO - Mean(mu)=1,37, Std-Dev(sigma)=0,93 RI=[−0,5, 3,24]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=29,58, Std-Dev(sigma)=1,11 RI=[27,36, 31,8]
// mQSO - Mean(mu)=26,98, Std-Dev(sigma)=1,01 RI=[24,95, 29,01]
// mjDE - Mean(mu)=23,86, Std-Dev(sigma)=1 RI=[21,86, 25,86]
// DSPSO - Mean(mu)=22,39, Std-Dev(sigma)=1,01 RI=[20,36, 24,41]
// RPSO - Mean(mu)=21,28, Std-Dev(sigma)=1,05 RI=[19,17, 23,38]
//
// Glicko2 rating:
// mPSO - Rating=1.812,7 RD=50 ro=0,06 RI=[1712,72, 1912,72]
// mQSO - Rating=1.631,7 RD=50 ro=0,06 RI=[1531,67, 1731,67]
// mjDE - Rating=1.458,9 RD=50 ro=0,06 RI=[1358,85, 1558,85]
// DSPSO - Rating=1.335,4 RD=50 ro=0,06 RI=[1235,41, 1435,41]
// RPSO - Rating=1.261,3 RD=50 ro=0,06 RI=[1161,34, 1361,34]
//
// Game results:
// mPSO [win=100, lose=24, draw=0]
// 	 Against:{mQSO=[win=21, lose=10, draw=0], DSPSO=[win=26, lose=5, draw=0], RPSO=[win=26, lose=5, draw=0], mjDE=[win=27, lose=4, draw=0]}
// 	 Problems:{MPBEval6000=[win=100, lose=24, draw=0]}
// mQSO [win=78, lose=46, draw=0]
// 	 Against:{DSPSO=[win=23, lose=8, draw=0], RPSO=[win=26, lose=5, draw=0], mjDE=[win=19, lose=12, draw=0], mPSO=[win=10, lose=21, draw=0]}
// 	 Problems:{MPBEval6000=[win=78, lose=46, draw=0]}
// mjDE [win=57, lose=67, draw=0]
// 	 Against:{mQSO=[win=12, lose=19, draw=0], DSPSO=[win=21, lose=10, draw=0], RPSO=[win=20, lose=11, draw=0], mPSO=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval6000=[win=57, lose=67, draw=0]}
// DSPSO [win=42, lose=82, draw=0]
// 	 Against:{mQSO=[win=8, lose=23, draw=0], RPSO=[win=19, lose=12, draw=0], mjDE=[win=10, lose=21, draw=0], mPSO=[win=5, lose=26, draw=0]}
// 	 Problems:{MPBEval6000=[win=42, lose=82, draw=0]}
// RPSO [win=33, lose=91, draw=0]
// 	 Against:{mQSO=[win=5, lose=26, draw=0], DSPSO=[win=12, lose=19, draw=0], mjDE=[win=11, lose=20, draw=0], mPSO=[win=5, lose=26, draw=0]}
// 	 Problems:{MPBEval6000=[win=33, lose=91, draw=0]}
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=6,06, Std-Dev(sigma)=1,16 RI=[3,75, 8,37]
// mQSO - Mean(mu)=3,91, Std-Dev(sigma)=1,01 RI=[1,89, 5,93]
// mjDE - Mean(mu)=2,41, Std-Dev(sigma)=0,94 RI=[0,53, 4,28]
// DSPSO - Mean(mu)=1,66, Std-Dev(sigma)=0,92 RI=[−0,18, 3,51]
// RPSO - Mean(mu)=−0,81, Std-Dev(sigma)=0,95 RI=[−2,72, 1,09]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=30,04, Std-Dev(sigma)=1,08 RI=[27,89, 32,19]
// mQSO - Mean(mu)=27,02, Std-Dev(sigma)=1,01 RI=[25, 29,04]
// mjDE - Mean(mu)=24,61, Std-Dev(sigma)=0,99 RI=[22,62, 26,6]
// DSPSO - Mean(mu)=23,45, Std-Dev(sigma)=1 RI=[21,46, 25,45]
// RPSO - Mean(mu)=20,43, Std-Dev(sigma)=1,1 RI=[18,24, 22,62]
//
// Glicko2 rating:
// mPSO - Rating=1.812,7 RD=50 ro=0,06 RI=[1712,72, 1912,72]
// mQSO - Rating=1.615,2 RD=50 ro=0,06 RI=[1515,21, 1715,21]
// mjDE - Rating=1.483,5 RD=50 ro=0,06 RI=[1383,54, 1583,54]
// DSPSO - Rating=1.376,6 RD=50 ro=0,06 RI=[1276,56, 1476,56]
// RPSO - Rating=1.212 RD=50 ro=0,06 RI=[1111,97, 1311,97]
//
// Game results:
// mPSO [win=100, lose=24, draw=0]
// 	 Against:{mQSO=[win=21, lose=10, draw=0], DSPSO=[win=26, lose=5, draw=0], RPSO=[win=27, lose=4, draw=0], mjDE=[win=26, lose=5, draw=0]}
// 	 Problems:{MPBEval7000=[win=100, lose=24, draw=0]}
// mQSO [win=76, lose=48, draw=0]
// 	 Against:{DSPSO=[win=21, lose=10, draw=0], RPSO=[win=26, lose=5, draw=0], mjDE=[win=19, lose=12, draw=0], mPSO=[win=10, lose=21, draw=0]}
// 	 Problems:{MPBEval7000=[win=76, lose=48, draw=0]}
// mjDE [win=60, lose=64, draw=0]
// 	 Against:{mQSO=[win=12, lose=19, draw=0], DSPSO=[win=20, lose=11, draw=0], RPSO=[win=23, lose=8, draw=0], mPSO=[win=5, lose=26, draw=0]}
// 	 Problems:{MPBEval7000=[win=60, lose=64, draw=0]}
// DSPSO [win=47, lose=77, draw=0]
// 	 Against:{mQSO=[win=10, lose=21, draw=0], RPSO=[win=21, lose=10, draw=0], mjDE=[win=11, lose=20, draw=0], mPSO=[win=5, lose=26, draw=0]}
// 	 Problems:{MPBEval7000=[win=47, lose=77, draw=0]}
// RPSO [win=27, lose=97, draw=0]
// 	 Against:{mQSO=[win=5, lose=26, draw=0], DSPSO=[win=10, lose=21, draw=0], mjDE=[win=8, lose=23, draw=0], mPSO=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval7000=[win=27, lose=97, draw=0]}
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=6,16, Std-Dev(sigma)=1,16 RI=[3,83, 8,48]
// mQSO - Mean(mu)=4,36, Std-Dev(sigma)=1,02 RI=[2,31, 6,41]
// mjDE - Mean(mu)=2,43, Std-Dev(sigma)=0,95 RI=[0,54, 4,33]
// DSPSO - Mean(mu)=2,05, Std-Dev(sigma)=0,93 RI=[0,19, 3,9]
// RPSO - Mean(mu)=−1,04, Std-Dev(sigma)=0,95 RI=[−2,95, 0,87]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=29,98, Std-Dev(sigma)=1,08 RI=[27,83, 32,13]
// mQSO - Mean(mu)=27,3, Std-Dev(sigma)=1,01 RI=[25,28, 29,33]
// mjDE - Mean(mu)=24,4, Std-Dev(sigma)=1 RI=[22,4, 26,4]
// DSPSO - Mean(mu)=23,5, Std-Dev(sigma)=1 RI=[21,51, 25,5]
// RPSO - Mean(mu)=19,48, Std-Dev(sigma)=1,12 RI=[17,25, 21,71]
//
// Glicko2 rating:
// mPSO - Rating=1.812,7 RD=50 ro=0,06 RI=[1712,72, 1912,72]
// mQSO - Rating=1.639,9 RD=50 ro=0,06 RI=[1539,9, 1739,9]
// mjDE - Rating=1.475,3 RD=50 ro=0,06 RI=[1375,31, 1575,31]
// DSPSO - Rating=1.393 RD=50 ro=0,06 RI=[1293,02, 1493,02]
// RPSO - Rating=1.179 RD=50 ro=0,06 RI=[1079,05, 1279,05]
//
// Game results:
// mPSO [win=100, lose=24, draw=0]
// 	 Against:{mQSO=[win=21, lose=10, draw=0], DSPSO=[win=26, lose=5, draw=0], RPSO=[win=27, lose=4, draw=0], mjDE=[win=26, lose=5, draw=0]}
// 	 Problems:{MPBEval8000=[win=100, lose=24, draw=0]}
// mQSO [win=79, lose=45, draw=0]
// 	 Against:{DSPSO=[win=22, lose=9, draw=0], RPSO=[win=27, lose=4, draw=0], mjDE=[win=20, lose=11, draw=0], mPSO=[win=10, lose=21, draw=0]}
// 	 Problems:{MPBEval8000=[win=79, lose=45, draw=0]}
// mjDE [win=59, lose=65, draw=0]
// 	 Against:{mQSO=[win=11, lose=20, draw=0], DSPSO=[win=19, lose=12, draw=0], RPSO=[win=24, lose=7, draw=0], mPSO=[win=5, lose=26, draw=0]}
// 	 Problems:{MPBEval8000=[win=59, lose=65, draw=0]}
// DSPSO [win=49, lose=75, draw=0]
// 	 Against:{mQSO=[win=9, lose=22, draw=0], RPSO=[win=23, lose=8, draw=0], mjDE=[win=12, lose=19, draw=0], mPSO=[win=5, lose=26, draw=0]}
// 	 Problems:{MPBEval8000=[win=49, lose=75, draw=0]}
// RPSO [win=23, lose=101, draw=0]
// 	 Against:{mQSO=[win=4, lose=27, draw=0], DSPSO=[win=8, lose=23, draw=0], mjDE=[win=7, lose=24, draw=0], mPSO=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval8000=[win=23, lose=101, draw=0]}
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=6,3, Std-Dev(sigma)=1,19 RI=[3,93, 8,67]
// mQSO - Mean(mu)=4,3, Std-Dev(sigma)=1,04 RI=[2,22, 6,38]
// mjDE - Mean(mu)=2,56, Std-Dev(sigma)=0,95 RI=[0,65, 4,46]
// DSPSO - Mean(mu)=2,37, Std-Dev(sigma)=0,94 RI=[0,48, 4,26]
// RPSO - Mean(mu)=−1,09, Std-Dev(sigma)=0,97 RI=[−3,04, 0,85]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=30,32, Std-Dev(sigma)=1,09 RI=[28,14, 32,5]
// mQSO - Mean(mu)=27,59, Std-Dev(sigma)=1,03 RI=[25,53, 29,65]
// mjDE - Mean(mu)=24,2, Std-Dev(sigma)=1,01 RI=[22,19, 26,22]
// DSPSO - Mean(mu)=23,95, Std-Dev(sigma)=1,01 RI=[21,92, 25,97]
// RPSO - Mean(mu)=19,22, Std-Dev(sigma)=1,15 RI=[16,92, 21,52]
//
// Glicko2 rating:
// mPSO - Rating=1.812,7 RD=50 ro=0,06 RI=[1712,72, 1912,72]
// mQSO - Rating=1.664,6 RD=50 ro=0,06 RI=[1564,59, 1764,59]
// mjDE - Rating=1.450,6 RD=50 ro=0,06 RI=[1350,62, 1550,62]
// DSPSO - Rating=1.409,5 RD=50 ro=0,06 RI=[1309,47, 1509,47]
// RPSO - Rating=1.162,6 RD=50 ro=0,06 RI=[1062,59, 1262,59]
//
// Game results:
// mPSO [win=100, lose=24, draw=0]
// 	 Against:{mQSO=[win=20, lose=11, draw=0], DSPSO=[win=26, lose=5, draw=0], RPSO=[win=27, lose=4, draw=0], mjDE=[win=27, lose=4, draw=0]}
// 	 Problems:{MPBEval9000=[win=100, lose=24, draw=0]}
// mQSO [win=82, lose=42, draw=0]
// 	 Against:{DSPSO=[win=22, lose=9, draw=0], RPSO=[win=28, lose=3, draw=0], mjDE=[win=21, lose=10, draw=0], mPSO=[win=11, lose=20, draw=0]}
// 	 Problems:{MPBEval9000=[win=82, lose=42, draw=0]}
// mjDE [win=56, lose=68, draw=0]
// 	 Against:{mQSO=[win=10, lose=21, draw=0], DSPSO=[win=18, lose=13, draw=0], RPSO=[win=24, lose=7, draw=0], mPSO=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval9000=[win=56, lose=68, draw=0]}
// DSPSO [win=51, lose=73, draw=0]
// 	 Against:{mQSO=[win=9, lose=22, draw=0], RPSO=[win=24, lose=7, draw=0], mjDE=[win=13, lose=18, draw=0], mPSO=[win=5, lose=26, draw=0]}
// 	 Problems:{MPBEval9000=[win=51, lose=73, draw=0]}
// RPSO [win=21, lose=103, draw=0]
// 	 Against:{mQSO=[win=3, lose=28, draw=0], DSPSO=[win=7, lose=24, draw=0], mjDE=[win=7, lose=24, draw=0], mPSO=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval9000=[win=21, lose=103, draw=0]}
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=5,33, Std-Dev(sigma)=1,16 RI=[3, 7,65]
// mQSO - Mean(mu)=3,39, Std-Dev(sigma)=1,04 RI=[1,3, 5,48]
// mjDE - Mean(mu)=1,77, Std-Dev(sigma)=0,96 RI=[−0,14, 3,69]
// DSPSO - Mean(mu)=1,63, Std-Dev(sigma)=0,94 RI=[−0,25, 3,5]
// RPSO - Mean(mu)=−2,07, Std-Dev(sigma)=0,98 RI=[−4,04, −0,11]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=30,17, Std-Dev(sigma)=1,08 RI=[28,02, 32,32]
// mQSO - Mean(mu)=27,9, Std-Dev(sigma)=1,03 RI=[25,83, 29,96]
// mjDE - Mean(mu)=24,59, Std-Dev(sigma)=1,01 RI=[22,57, 26,62]
// DSPSO - Mean(mu)=24,16, Std-Dev(sigma)=1,01 RI=[22,15, 26,18]
// RPSO - Mean(mu)=19,09, Std-Dev(sigma)=1,18 RI=[16,73, 21,46]
//
// Glicko2 rating:
// mPSO - Rating=1.796,3 RD=50 ro=0,06 RI=[1696,26, 1896,26]
// mQSO - Rating=1.664,6 RD=50 ro=0,06 RI=[1564,59, 1764,59]
// mjDE - Rating=1.475,3 RD=50 ro=0,06 RI=[1375,31, 1575,31]
// DSPSO - Rating=1.417,7 RD=50 ro=0,06 RI=[1317,7, 1517,7]
// RPSO - Rating=1.146,1 RD=50 ro=0,06 RI=[1046,13, 1246,13]
//
// Game results:
// mPSO [win=98, lose=26, draw=0]
// 	 Against:{mQSO=[win=19, lose=12, draw=0], DSPSO=[win=25, lose=6, draw=0], RPSO=[win=28, lose=3, draw=0], mjDE=[win=26, lose=5, draw=0]}
// 	 Problems:{MPBEval10000=[win=98, lose=26, draw=0]}
// mQSO [win=82, lose=42, draw=0]
// 	 Against:{DSPSO=[win=22, lose=9, draw=0], RPSO=[win=28, lose=3, draw=0], mjDE=[win=20, lose=11, draw=0], mPSO=[win=12, lose=19, draw=0]}
// 	 Problems:{MPBEval10000=[win=82, lose=42, draw=0]}
// mjDE [win=59, lose=65, draw=0]
// 	 Against:{mQSO=[win=11, lose=20, draw=0], DSPSO=[win=19, lose=12, draw=0], RPSO=[win=24, lose=7, draw=0], mPSO=[win=5, lose=26, draw=0]}
// 	 Problems:{MPBEval10000=[win=59, lose=65, draw=0]}
// DSPSO [win=52, lose=72, draw=0]
// 	 Against:{mQSO=[win=9, lose=22, draw=0], RPSO=[win=25, lose=6, draw=0], mjDE=[win=12, lose=19, draw=0], mPSO=[win=6, lose=25, draw=0]}
// 	 Problems:{MPBEval10000=[win=52, lose=72, draw=0]}
// RPSO [win=19, lose=105, draw=0]
// 	 Against:{mQSO=[win=3, lose=28, draw=0], DSPSO=[win=6, lose=25, draw=0], mjDE=[win=7, lose=24, draw=0], mPSO=[win=3, lose=28, draw=0]}
// 	 Problems:{MPBEval10000=[win=19, lose=105, draw=0]}
// TrueSkill One-On-One rating:
// mjDE - Mean(mu)=9,32, Std-Dev(sigma)=1,32 RI=[6,68, 11,96]
// mPSO - Mean(mu)=7,62, Std-Dev(sigma)=1,14 RI=[5,33, 9,9]
// mQSO - Mean(mu)=5,3, Std-Dev(sigma)=1,01 RI=[3,28, 7,31]
// DSPSO - Mean(mu)=4,71, Std-Dev(sigma)=0,99 RI=[2,73, 6,69]
// RPSO - Mean(mu)=0,36, Std-Dev(sigma)=1,02 RI=[−1,68, 2,4]
//
// TrueSkill Free-For-All rating:
// mjDE - Mean(mu)=31,89, Std-Dev(sigma)=1,13 RI=[29,62, 34,15]
// mPSO - Mean(mu)=29,17, Std-Dev(sigma)=1,09 RI=[26,98, 31,35]
// mQSO - Mean(mu)=25,44, Std-Dev(sigma)=1,07 RI=[23,3, 27,57]
// DSPSO - Mean(mu)=23,1, Std-Dev(sigma)=1,1 RI=[20,89, 25,31]
// RPSO - Mean(mu)=15,03, Std-Dev(sigma)=1,36 RI=[12,3, 17,76]
//
// Glicko2 rating:
// mjDE - Rating=1.837,4 RD=50 ro=0,06 RI=[1737,41, 1937,41]
// mPSO - Rating=1.730,4 RD=50 ro=0,06 RI=[1630,43, 1830,43]
// mQSO - Rating=1.516,5 RD=50 ro=0,06 RI=[1416,46, 1616,46]
// DSPSO - Rating=1.351,9 RD=50 ro=0,06 RI=[1251,87, 1451,87]
// RPSO - Rating=1.063,8 RD=50 ro=0,06 RI=[963,83, 1163,83]
//
// Game results:
// mjDE [win=103, lose=21, draw=0]
// 	 Against:{mQSO=[win=23, lose=8, draw=0], DSPSO=[win=28, lose=3, draw=0], RPSO=[win=31, lose=0, draw=0], mPSO=[win=21, lose=10, draw=0]}
// 	 Problems:{MPBEval10001=[win=103, lose=21, draw=0]}
// mPSO [win=90, lose=34, draw=0]
// 	 Against:{mQSO=[win=22, lose=9, draw=0], DSPSO=[win=27, lose=4, draw=0], RPSO=[win=31, lose=0, draw=0], mjDE=[win=10, lose=21, draw=0]}
// 	 Problems:{MPBEval10001=[win=90, lose=34, draw=0]}
// mQSO [win=64, lose=60, draw=0]
// 	 Against:{DSPSO=[win=19, lose=12, draw=0], RPSO=[win=28, lose=3, draw=0], mPSO=[win=9, lose=22, draw=0], mjDE=[win=8, lose=23, draw=0]}
// 	 Problems:{MPBEval10001=[win=64, lose=60, draw=0]}
// DSPSO [win=44, lose=80, draw=0]
// 	 Against:{mQSO=[win=12, lose=19, draw=0], RPSO=[win=25, lose=6, draw=0], mPSO=[win=4, lose=27, draw=0], mjDE=[win=3, lose=28, draw=0]}
// 	 Problems:{MPBEval10001=[win=44, lose=80, draw=0]}
// RPSO [win=9, lose=115, draw=0]
// 	 Against:{mQSO=[win=3, lose=28, draw=0], DSPSO=[win=6, lose=25, draw=0], mPSO=[win=0, lose=31, draw=0], mjDE=[win=0, lose=31, draw=0]}
// 	 Problems:{MPBEval10001=[win=9, lose=115, draw=0]}
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=5,06, Std-Dev(sigma)=1,14 RI=[2,79, 7,33]
// mQSO - Mean(mu)=3,85, Std-Dev(sigma)=1,01 RI=[1,84, 5,87]
// mjDE - Mean(mu)=1,39, Std-Dev(sigma)=0,92 RI=[−0,45, 3,22]
// DSPSO - Mean(mu)=0,87, Std-Dev(sigma)=0,93 RI=[−0,99, 2,73]
// RPSO - Mean(mu)=−1,11, Std-Dev(sigma)=0,95 RI=[−3,01, 0,79]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=29,94, Std-Dev(sigma)=1,08 RI=[27,79, 32,09]
// mQSO - Mean(mu)=27,64, Std-Dev(sigma)=1,02 RI=[25,61, 29,67]
// mjDE - Mean(mu)=23,87, Std-Dev(sigma)=0,99 RI=[21,9, 25,84]
// DSPSO - Mean(mu)=23,65, Std-Dev(sigma)=1 RI=[21,66, 25,64]
// RPSO - Mean(mu)=20,62, Std-Dev(sigma)=1,09 RI=[18,45, 22,8]
//
// Glicko2 rating:
// mPSO - Rating=1.788 RD=50 ro=0,06 RI=[1688,03, 1888,03]
// mQSO - Rating=1.656,4 RD=50 ro=0,06 RI=[1556,36, 1756,36]
// mjDE - Rating=1.434,2 RD=50 ro=0,06 RI=[1334,16, 1534,16]
// DSPSO - Rating=1.409,5 RD=50 ro=0,06 RI=[1309,47, 1509,47]
// RPSO - Rating=1.212 RD=50 ro=0,06 RI=[1111,97, 1311,97]
//
// Game results:
// mPSO [win=97, lose=27, draw=0]
// 	 Against:{mQSO=[win=19, lose=12, draw=0], DSPSO=[win=25, lose=6, draw=0], RPSO=[win=27, lose=4, draw=0], mjDE=[win=26, lose=5, draw=0]}
// 	 Problems:{MPBEval11000=[win=97, lose=27, draw=0]}
// mQSO [win=81, lose=43, draw=0]
// 	 Against:{DSPSO=[win=21, lose=10, draw=0], RPSO=[win=27, lose=4, draw=0], mjDE=[win=21, lose=10, draw=0], mPSO=[win=12, lose=19, draw=0]}
// 	 Problems:{MPBEval11000=[win=81, lose=43, draw=0]}
// mjDE [win=54, lose=70, draw=0]
// 	 Against:{mQSO=[win=10, lose=21, draw=0], DSPSO=[win=18, lose=13, draw=0], RPSO=[win=21, lose=10, draw=0], mPSO=[win=5, lose=26, draw=0]}
// 	 Problems:{MPBEval11000=[win=54, lose=70, draw=0]}
// DSPSO [win=51, lose=73, draw=0]
// 	 Against:{mQSO=[win=10, lose=21, draw=0], RPSO=[win=22, lose=9, draw=0], mjDE=[win=13, lose=18, draw=0], mPSO=[win=6, lose=25, draw=0]}
// 	 Problems:{MPBEval11000=[win=51, lose=73, draw=0]}
// RPSO [win=27, lose=97, draw=0]
// 	 Against:{mQSO=[win=4, lose=27, draw=0], DSPSO=[win=9, lose=22, draw=0], mjDE=[win=10, lose=21, draw=0], mPSO=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval11000=[win=27, lose=97, draw=0]}
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=5,83, Std-Dev(sigma)=1,17 RI=[3,48, 8,17]
// mQSO - Mean(mu)=4,28, Std-Dev(sigma)=1,03 RI=[2,22, 6,34]
// mjDE - Mean(mu)=1,65, Std-Dev(sigma)=0,93 RI=[−0,21, 3,51]
// DSPSO - Mean(mu)=1,35, Std-Dev(sigma)=0,95 RI=[−0,54, 3,25]
// RPSO - Mean(mu)=−1,11, Std-Dev(sigma)=0,96 RI=[−3,03, 0,82]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=30,48, Std-Dev(sigma)=1,09 RI=[28,29, 32,66]
// mQSO - Mean(mu)=27,88, Std-Dev(sigma)=1,03 RI=[25,82, 29,94]
// DSPSO - Mean(mu)=23,89, Std-Dev(sigma)=1 RI=[21,88, 25,9]
// mjDE - Mean(mu)=23,56, Std-Dev(sigma)=1 RI=[21,55, 25,56]
// RPSO - Mean(mu)=19,87, Std-Dev(sigma)=1,12 RI=[17,64, 22,11]
//
// Glicko2 rating:
// mPSO - Rating=1.804,5 RD=50 ro=0,06 RI=[1704,49, 1904,49]
// mQSO - Rating=1.681,1 RD=50 ro=0,06 RI=[1581,05, 1781,05]
// DSPSO - Rating=1.417,7 RD=50 ro=0,06 RI=[1317,7, 1517,7]
// mjDE - Rating=1.417,7 RD=50 ro=0,06 RI=[1317,7, 1517,7]
// RPSO - Rating=1.179 RD=50 ro=0,06 RI=[1079,05, 1279,05]
//
// Game results:
// mPSO [win=99, lose=25, draw=0]
// 	 Against:{mQSO=[win=19, lose=12, draw=0], DSPSO=[win=25, lose=6, draw=0], RPSO=[win=27, lose=4, draw=0], mjDE=[win=28, lose=3, draw=0]}
// 	 Problems:{MPBEval12000=[win=99, lose=25, draw=0]}
// mQSO [win=84, lose=40, draw=0]
// 	 Against:{DSPSO=[win=21, lose=10, draw=0], RPSO=[win=29, lose=2, draw=0], mjDE=[win=22, lose=9, draw=0], mPSO=[win=12, lose=19, draw=0]}
// 	 Problems:{MPBEval12000=[win=84, lose=40, draw=0]}
// DSPSO [win=52, lose=72, draw=0]
// 	 Against:{mQSO=[win=10, lose=21, draw=0], RPSO=[win=23, lose=8, draw=0], mjDE=[win=13, lose=18, draw=0], mPSO=[win=6, lose=25, draw=0]}
// 	 Problems:{MPBEval12000=[win=52, lose=72, draw=0]}
// mjDE [win=52, lose=72, draw=0]
// 	 Against:{mQSO=[win=9, lose=22, draw=0], DSPSO=[win=18, lose=13, draw=0], RPSO=[win=22, lose=9, draw=0], mPSO=[win=3, lose=28, draw=0]}
// 	 Problems:{MPBEval12000=[win=52, lose=72, draw=0]}
// RPSO [win=23, lose=101, draw=0]
// 	 Against:{mQSO=[win=2, lose=29, draw=0], DSPSO=[win=8, lose=23, draw=0], mjDE=[win=9, lose=22, draw=0], mPSO=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval12000=[win=23, lose=101, draw=0]}
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=5,57, Std-Dev(sigma)=1,18 RI=[3,21, 7,92]
// mQSO - Mean(mu)=3,75, Std-Dev(sigma)=1,04 RI=[1,68, 5,82]
// mjDE - Mean(mu)=1,14, Std-Dev(sigma)=0,93 RI=[−0,72, 3]
// DSPSO - Mean(mu)=1,03, Std-Dev(sigma)=0,94 RI=[−0,85, 2,91]
// RPSO - Mean(mu)=−1,82, Std-Dev(sigma)=0,96 RI=[−3,75, 0,11]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=30,73, Std-Dev(sigma)=1,09 RI=[28,55, 32,9]
// mQSO - Mean(mu)=28,09, Std-Dev(sigma)=1,03 RI=[26,04, 30,14]
// DSPSO - Mean(mu)=24,15, Std-Dev(sigma)=1 RI=[22,16, 26,15]
// mjDE - Mean(mu)=23,63, Std-Dev(sigma)=1 RI=[21,63, 25,64]
// RPSO - Mean(mu)=19,57, Std-Dev(sigma)=1,13 RI=[17,31, 21,84]
//
// Glicko2 rating:
// mPSO - Rating=1.804,5 RD=50 ro=0,06 RI=[1704,49, 1904,49]
// mQSO - Rating=1.681,1 RD=50 ro=0,06 RI=[1581,05, 1781,05]
// DSPSO - Rating=1.434,2 RD=50 ro=0,06 RI=[1334,16, 1534,16]
// mjDE - Rating=1.417,7 RD=50 ro=0,06 RI=[1317,7, 1517,7]
// RPSO - Rating=1.162,6 RD=50 ro=0,06 RI=[1062,59, 1262,59]
//
// Game results:
// mPSO [win=99, lose=25, draw=0]
// 	 Against:{mQSO=[win=19, lose=12, draw=0], DSPSO=[win=25, lose=6, draw=0], RPSO=[win=27, lose=4, draw=0], mjDE=[win=28, lose=3, draw=0]}
// 	 Problems:{MPBEval13000=[win=99, lose=25, draw=0]}
// mQSO [win=84, lose=40, draw=0]
// 	 Against:{DSPSO=[win=20, lose=11, draw=0], RPSO=[win=29, lose=2, draw=0], mjDE=[win=23, lose=8, draw=0], mPSO=[win=12, lose=19, draw=0]}
// 	 Problems:{MPBEval13000=[win=84, lose=40, draw=0]}
// DSPSO [win=54, lose=70, draw=0]
// 	 Against:{mQSO=[win=11, lose=20, draw=0], RPSO=[win=24, lose=7, draw=0], mjDE=[win=13, lose=18, draw=0], mPSO=[win=6, lose=25, draw=0]}
// 	 Problems:{MPBEval13000=[win=54, lose=70, draw=0]}
// mjDE [win=52, lose=72, draw=0]
// 	 Against:{mQSO=[win=8, lose=23, draw=0], DSPSO=[win=18, lose=13, draw=0], RPSO=[win=23, lose=8, draw=0], mPSO=[win=3, lose=28, draw=0]}
// 	 Problems:{MPBEval13000=[win=52, lose=72, draw=0]}
// RPSO [win=21, lose=103, draw=0]
// 	 Against:{mQSO=[win=2, lose=29, draw=0], DSPSO=[win=7, lose=24, draw=0], mjDE=[win=8, lose=23, draw=0], mPSO=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval13000=[win=21, lose=103, draw=0]}
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=5,46, Std-Dev(sigma)=1,18 RI=[3,11, 7,82]
// mQSO - Mean(mu)=3,48, Std-Dev(sigma)=1,02 RI=[1,43, 5,52]
// mjDE - Mean(mu)=1,34, Std-Dev(sigma)=0,94 RI=[−0,53, 3,22]
// DSPSO - Mean(mu)=0,94, Std-Dev(sigma)=0,94 RI=[−0,94, 2,81]
// RPSO - Mean(mu)=−1,83, Std-Dev(sigma)=0,96 RI=[−3,75, 0,1]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=30,59, Std-Dev(sigma)=1,08 RI=[28,44, 32,75]
// mQSO - Mean(mu)=27,79, Std-Dev(sigma)=1,03 RI=[25,74, 29,84]
// mjDE - Mean(mu)=24,2, Std-Dev(sigma)=0,99 RI=[22,21, 26,19]
// DSPSO - Mean(mu)=23,98, Std-Dev(sigma)=1 RI=[21,98, 25,99]
// RPSO - Mean(mu)=19,62, Std-Dev(sigma)=1,13 RI=[17,36, 21,89]
//
// Glicko2 rating:
// mPSO - Rating=1.804,5 RD=50 ro=0,06 RI=[1704,49, 1904,49]
// mQSO - Rating=1.664,6 RD=50 ro=0,06 RI=[1564,59, 1764,59]
// mjDE - Rating=1.442,4 RD=50 ro=0,06 RI=[1342,39, 1542,39]
// DSPSO - Rating=1.425,9 RD=50 ro=0,06 RI=[1325,93, 1525,93]
// RPSO - Rating=1.162,6 RD=50 ro=0,06 RI=[1062,59, 1262,59]
//
// Game results:
// mPSO [win=99, lose=25, draw=0]
// 	 Against:{mQSO=[win=19, lose=12, draw=0], DSPSO=[win=25, lose=6, draw=0], RPSO=[win=27, lose=4, draw=0], mjDE=[win=28, lose=3, draw=0]}
// 	 Problems:{MPBEval14000=[win=99, lose=25, draw=0]}
// mQSO [win=82, lose=42, draw=0]
// 	 Against:{DSPSO=[win=20, lose=11, draw=0], RPSO=[win=29, lose=2, draw=0], mjDE=[win=21, lose=10, draw=0], mPSO=[win=12, lose=19, draw=0]}
// 	 Problems:{MPBEval14000=[win=82, lose=42, draw=0]}
// mjDE [win=55, lose=69, draw=0]
// 	 Against:{mQSO=[win=10, lose=21, draw=0], DSPSO=[win=19, lose=12, draw=0], RPSO=[win=23, lose=8, draw=0], mPSO=[win=3, lose=28, draw=0]}
// 	 Problems:{MPBEval14000=[win=55, lose=69, draw=0]}
// DSPSO [win=53, lose=71, draw=0]
// 	 Against:{mQSO=[win=11, lose=20, draw=0], RPSO=[win=24, lose=7, draw=0], mjDE=[win=12, lose=19, draw=0], mPSO=[win=6, lose=25, draw=0]}
// 	 Problems:{MPBEval14000=[win=53, lose=71, draw=0]}
// RPSO [win=21, lose=103, draw=0]
// 	 Against:{mQSO=[win=2, lose=29, draw=0], DSPSO=[win=7, lose=24, draw=0], mjDE=[win=8, lose=23, draw=0], mPSO=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval14000=[win=21, lose=103, draw=0]}
// TrueSkill One-On-One rating:
// mPSO - Mean(mu)=5,66, Std-Dev(sigma)=1,17 RI=[3,32, 8]
// mQSO - Mean(mu)=3,43, Std-Dev(sigma)=1,03 RI=[1,37, 5,49]
// DSPSO - Mean(mu)=0,92, Std-Dev(sigma)=0,95 RI=[−0,97, 2,81]
// mjDE - Mean(mu)=0,82, Std-Dev(sigma)=0,93 RI=[−1,05, 2,69]
// RPSO - Mean(mu)=−2,01, Std-Dev(sigma)=0,96 RI=[−3,94, −0,08]
//
// TrueSkill Free-For-All rating:
// mPSO - Mean(mu)=30,63, Std-Dev(sigma)=1,07 RI=[28,49, 32,78]
// mQSO - Mean(mu)=27,95, Std-Dev(sigma)=1,02 RI=[25,9, 30]
// DSPSO - Mean(mu)=24,35, Std-Dev(sigma)=1 RI=[22,35, 26,35]
// mjDE - Mean(mu)=23,63, Std-Dev(sigma)=1 RI=[21,62, 25,63]
// RPSO - Mean(mu)=19,63, Std-Dev(sigma)=1,13 RI=[17,37, 21,89]
//
// Glicko2 rating:
// mPSO - Rating=1.804,5 RD=50 ro=0,06 RI=[1704,49, 1904,49]
// mQSO - Rating=1.672,8 RD=50 ro=0,06 RI=[1572,82, 1772,82]
// DSPSO - Rating=1.450,6 RD=50 ro=0,06 RI=[1350,62, 1550,62]
// mjDE - Rating=1.409,5 RD=50 ro=0,06 RI=[1309,47, 1509,47]
// RPSO - Rating=1.162,6 RD=50 ro=0,06 RI=[1062,59, 1262,59]
//
// Game results:
// mPSO [win=99, lose=25, draw=0]
// 	 Against:{mQSO=[win=19, lose=12, draw=0], DSPSO=[win=25, lose=6, draw=0], RPSO=[win=27, lose=4, draw=0], mjDE=[win=28, lose=3, draw=0]}
// 	 Problems:{MPBEval15000=[win=99, lose=25, draw=0]}
// mQSO [win=83, lose=41, draw=0]
// 	 Against:{DSPSO=[win=20, lose=11, draw=0], RPSO=[win=29, lose=2, draw=0], mjDE=[win=22, lose=9, draw=0], mPSO=[win=12, lose=19, draw=0]}
// 	 Problems:{MPBEval15000=[win=83, lose=41, draw=0]}
// DSPSO [win=56, lose=68, draw=0]
// 	 Against:{mQSO=[win=11, lose=20, draw=0], RPSO=[win=24, lose=7, draw=0], mjDE=[win=15, lose=16, draw=0], mPSO=[win=6, lose=25, draw=0]}
// 	 Problems:{MPBEval15000=[win=56, lose=68, draw=0]}
// mjDE [win=51, lose=73, draw=0]
// 	 Against:{mQSO=[win=9, lose=22, draw=0], DSPSO=[win=16, lose=15, draw=0], RPSO=[win=23, lose=8, draw=0], mPSO=[win=3, lose=28, draw=0]}
// 	 Problems:{MPBEval15000=[win=51, lose=73, draw=0]}
// RPSO [win=21, lose=103, draw=0]
// 	 Against:{mQSO=[win=2, lose=29, draw=0], DSPSO=[win=7, lose=24, draw=0], mjDE=[win=8, lose=23, draw=0], mPSO=[win=4, lose=27, draw=0]}
// 	 Problems:{MPBEval15000=[win=21, lose=103, draw=0]}

// %%
fun generateSequence(changeFrequency: Int, environmentNumber: Int, sampleInterval: Int = 1000): List<Int> {
    val result = mutableListOf<Int>()

    // Generate numbers increasing by 1000
    for (i in 1000..changeFrequency * environmentNumber step sampleInterval) {
        result.add(i)
        if (i % changeFrequency == 0 && i != changeFrequency * environmentNumber) {
            // Add the number just before the next multiple of 1000 (4999, 9999, etc.)
            result.add(i + 1)
        }
    }

    return result
}

// %%
import org.jetbrains.letsPlot.commons.values.Color

// number of algorithms in algPerf
val numAlgorithms = algPerf.size

// sample x-axis values (100 evaluations)
//val xValues = (1000..100000 step 1000).toList().subList(0, 100)
val xValues = generateSequence(changeFrequency, environmentNumber)

// find the global minimum and maximum y-values across all algorithms
//val allRatings = algPerf.flatMap { it.ratings.values.map { it.rating } }
//val minY = allRatings.minOrNull() ?: 0.0
//val maxY = allRatings.maxOrNull() ?: 1.0

// create the base plot (without any layers yet)
var plot = letsPlot(mapOf("eval" to xValues))

// loop through all algorithms in algPerf
for (i in 0 until numAlgorithms) {
    // extract the rating values for the current algorithm
    val yValues = algPerf[i].ratings.values.map { it.rating }

    // calculate the lower and upper bounds for the rating deviations
    val lowerBounds = algPerf[i].ratings.values.map { it.rating - it.ratingDeviation }
    val upperBounds = algPerf[i].ratings.values.map { it.rating + it.ratingDeviation }

    // prepare data for this algorithm
    val data = mapOf(
        "eval" to xValues,
        "rating" to yValues,
        "lowerBounds" to lowerBounds,
        "upperBounds" to upperBounds,
        "Algorithm" to List(numOfProblems) { algPerf[i].name }  // label each algorithm
    )

    // add rating line to the plot (cycling through predefined colors)
    plot += geomLine(data = data) {
        x = "eval"
        y = "rating"
        color = "Algorithm"
    }

    // add rating deviation ribbon to the plot (using the same color with transparency)
    plot += geomRibbon(data = data, alpha = 0.2) {
        x = "eval"
        ymin = "lowerBounds"
        ymax = "upperBounds"
        color = "Algorithm"
        fill = "Algorithm"
    }

    // add points at the same locations as the line
    plot += geomPoint(data = data) {
        x = "eval"
        y = "rating"
        color = "Algorithm"
    }
}

// add vertical lines at every 5000th eval point
/*val verticalLines = (changeFrequency..changeFrequency * environmentNumber step changeFrequency).toList()
verticalLines.forEach { evalPoint ->
    plot += geomVLine(xintercept = evalPoint, color = "grey", linetype = "dashed") {
        // You can customize the appearance here
    }
}*/

// set y-axis limits to min and max y-values
//
plot += scaleYContinuous(limits = 1000 to 2000)
plot += scaleXContinuous(breaks = xValues, labels = xValues.map { it.toInt().toString() })  // specify the tick marks
//plot += scaleYContinuous(limits = minY to maxY)
//plot += scaleXContinuous(limits = 1000 to 100000)

// set plot size and title
plot += ggsize(1500, 750)
plot += ggtitle("DOAs ratings during optimization")

// display the plot
plot.show()

// save the plot
ggsave(plot, "plot.svg")
// Out:
//    <div id="hW8Cm1"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"DOAs ratings during optimization"
// },
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":1500.0,
// "height":750.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"y",
// "limits":[1000.0,2000.0]
// },{
// "aesthetic":"x",
// "breaks":[1000.0,2000.0,3000.0,4000.0,5000.0,5001.0,6000.0,7000.0,8000.0,9000.0,10000.0,10001.0,11000.0,12000.0,13000.0,14000.0,15000.0],
// "labels":["1000","2000","3000","4000","5000","5001","6000","7000","8000","9000","10000","10001","11000","12000","13000","14000","15000"]
// }],
// "layers":[{
// "mapping":{
// "x":"eval",
// "y":"rating",
// "color":"Algorithm"
// },
// "stat":"identity",
// "data":{
// "eval":[1000.0,2000.0,3000.0,4000.0,5000.0,5001.0,6000.0,7000.0,8000.0,9000.0,10000.0,10001.0,11000.0,12000.0,13000.0,14000.0,15000.0],
// "rating":[1137.8997255963093,1129.670173874178,1179.047484177108,1236.6543461151186,1269.5725529029721,1360.0976214707953,1335.4089664189714,1376.5567248346354,1393.015828195677,1409.4749315542929,1417.704483232808,1351.8680697877091,1409.4749315542929,1417.704483232808,1434.163586588485,1425.9340349108563,1450.62268994267],
// "Algorithm":["DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO"]
// },
// "position":"identity",
// "geom":"line",
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"eval"
// },{
// "type":"float",
// "column":"rating"
// },{
// "type":"float",
// "column":"lowerBounds"
// },{
// "type":"float",
// "column":"upperBounds"
// },{
// "type":"str",
// "column":"Algorithm"
// }]
// }
// },{
// "mapping":{
// "x":"eval",
// "ymin":"lowerBounds",
// "ymax":"upperBounds",
// "color":"Algorithm",
// "fill":"Algorithm"
// },
// "stat":"identity",
// "data":{
// "upperBounds":[1187.8997255963093,1179.670173874178,1229.047484177108,1286.6543461151186,1319.5725529029721,1410.0976214707953,1385.4089664189714,1426.5567248346354,1443.015828195677,1459.4749315542929,1467.704483232808,1401.8680697877091,1459.4749315542929,1467.704483232808,1484.163586588485,1475.9340349108563,1500.62268994267],
// "eval":[1000.0,2000.0,3000.0,4000.0,5000.0,5001.0,6000.0,7000.0,8000.0,9000.0,10000.0,10001.0,11000.0,12000.0,13000.0,14000.0,15000.0],
// "lowerBounds":[1087.8997255963093,1079.670173874178,1129.047484177108,1186.6543461151186,1219.5725529029721,1310.0976214707953,1285.4089664189714,1326.5567248346354,1343.015828195677,1359.4749315542929,1367.704483232808,1301.8680697877091,1359.4749315542929,1367.704483232808,1384.163586588485,1375.9340349108563,1400.62268994267],
// "Algorithm":["DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO"]
// },
// "alpha":0.2,
// "position":"identity",
// "geom":"ribbon",
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"eval"
// },{
// "type":"float",
// "column":"rating"
// },{
// "type":"float",
// "column":"lowerBounds"
// },{
// "type":"float",
// "column":"upperBounds"
// },{
// "type":"str",
// "column":"Algorithm"
// }]
// }
// },{
// "mapping":{
// "x":"eval",
// "y":"rating",
// "color":"Algorithm"
// },
// "stat":"identity",
// "data":{
// "eval":[1000.0,2000.0,3000.0,4000.0,5000.0,5001.0,6000.0,7000.0,8000.0,9000.0,10000.0,10001.0,11000.0,12000.0,13000.0,14000.0,15000.0],
// "rating":[1137.8997255963093,1129.670173874178,1179.047484177108,1236.6543461151186,1269.5725529029721,1360.0976214707953,1335.4089664189714,1376.5567248346354,1393.015828195677,1409.4749315542929,1417.704483232808,1351.8680697877091,1409.4749315542929,1417.704483232808,1434.163586588485,1425.9340349108563,1450.62268994267],
// "Algorithm":["DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO","DSPSO"]
// },
// "position":"identity",
// "geom":"point",
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"eval"
// },{
// "type":"float",
// "column":"rating"
// },{
// "type":"float",
// "column":"lowerBounds"
// },{
// "type":"float",
// "column":"upperBounds"
// },{
// "type":"str",
// "column":"Algorithm"
// }]
// }
// },{
// "mapping":{
// "x":"eval",
// "y":"rating",
// "color":"Algorithm"
// },
// "stat":"identity",
// "data":{
// "eval":[1000.0,2000.0,3000.0,4000.0,5000.0,5001.0,6000.0,7000.0,8000.0,9000.0,10000.0,10001.0,11000.0,12000.0,13000.0,14000.0,15000.0],
// "rating":[1310.7203113587514,1590.5250684457071,1648.1319302122909,1639.9023785292047,1615.2137234845172,1401.2453798752647,1631.6728268469114,1615.2137234845172,1639.9023785292047,1664.5910335810286,1664.5910335810286,1516.459103351946,1656.3614818962164,1681.0501369534982,1681.0501369534982,1664.5910335810286,1672.8205852667736],
// "Algorithm":["mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO"]
// },
// "position":"identity",
// "geom":"line",
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"eval"
// },{
// "type":"float",
// "column":"rating"
// },{
// "type":"float",
// "column":"lowerBounds"
// },{
// "type":"float",
// "column":"upperBounds"
// },{
// "type":"str",
// "column":"Algorithm"
// }]
// }
// },{
// "mapping":{
// "x":"eval",
// "ymin":"lowerBounds",
// "ymax":"upperBounds",
// "color":"Algorithm",
// "fill":"Algorithm"
// },
// "stat":"identity",
// "data":{
// "upperBounds":[1360.7203113587514,1640.5250684457071,1698.1319302122909,1689.9023785292047,1665.2137234845172,1451.2453798752647,1681.6728268469114,1665.2137234845172,1689.9023785292047,1714.5910335810286,1714.5910335810286,1566.459103351946,1706.3614818962164,1731.0501369534982,1731.0501369534982,1714.5910335810286,1722.8205852667736],
// "eval":[1000.0,2000.0,3000.0,4000.0,5000.0,5001.0,6000.0,7000.0,8000.0,9000.0,10000.0,10001.0,11000.0,12000.0,13000.0,14000.0,15000.0],
// "lowerBounds":[1260.7203113587514,1540.5250684457071,1598.1319302122909,1589.9023785292047,1565.2137234845172,1351.2453798752647,1581.6728268469114,1565.2137234845172,1589.9023785292047,1614.5910335810286,1614.5910335810286,1466.459103351946,1606.3614818962164,1631.0501369534982,1631.0501369534982,1614.5910335810286,1622.8205852667736],
// "Algorithm":["mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO"]
// },
// "alpha":0.2,
// "position":"identity",
// "geom":"ribbon",
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"eval"
// },{
// "type":"float",
// "column":"rating"
// },{
// "type":"float",
// "column":"lowerBounds"
// },{
// "type":"float",
// "column":"upperBounds"
// },{
// "type":"str",
// "column":"Algorithm"
// }]
// }
// },{
// "mapping":{
// "x":"eval",
// "y":"rating",
// "color":"Algorithm"
// },
// "stat":"identity",
// "data":{
// "eval":[1000.0,2000.0,3000.0,4000.0,5000.0,5001.0,6000.0,7000.0,8000.0,9000.0,10000.0,10001.0,11000.0,12000.0,13000.0,14000.0,15000.0],
// "rating":[1310.7203113587514,1590.5250684457071,1648.1319302122909,1639.9023785292047,1615.2137234845172,1401.2453798752647,1631.6728268469114,1615.2137234845172,1639.9023785292047,1664.5910335810286,1664.5910335810286,1516.459103351946,1656.3614818962164,1681.0501369534982,1681.0501369534982,1664.5910335810286,1672.8205852667736],
// "Algorithm":["mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO","mQSO"]
// },
// "position":"identity",
// "geom":"point",
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"eval"
// },{
// "type":"float",
// "column":"rating"
// },{
// "type":"float",
// "column":"lowerBounds"
// },{
// "type":"float",
// "column":"upperBounds"
// },{
// "type":"str",
// "column":"Algorithm"
// }]
// }
// },{
// "mapping":{
// "x":"eval",
// "y":"rating",
// "color":"Algorithm"
// },
// "stat":"identity",
// "data":{
// "eval":[1000.0,2000.0,3000.0,4000.0,5000.0,5001.0,6000.0,7000.0,8000.0,9000.0,10000.0,10001.0,11000.0,12000.0,13000.0,14000.0,15000.0],
// "rating":[1648.1319302122909,1405.3601557148459,1343.6385181037836,1286.0316562888756,1265.4577770556944,1072.0633117578632,1261.3430012080846,1211.9656910087178,1179.047484177108,1162.5883807505734,1146.1292773163877,1063.8337600176299,1211.9656910087178,1179.047484177108,1162.5883807505734,1162.5883807505734,1162.5883807505734],
// "Algorithm":["RPSO","RPSO","RPSO","RPSO","RPSO","RPSO","RPSO","RPSO","RPSO","RPSO","RPSO","RPSO","RPSO","RPSO","R
// D:\EARS\src\org\um\feri\ears\examples\lets-plot-images\plot.svg

// %%
import org.jetbrains.letsPlot.letsPlot
import org.jetbrains.letsPlot.ggsize
import org.jetbrains.letsPlot.geom.geomLine
import org.jetbrains.letsPlot.geom.geomRibbon
import org.jetbrains.letsPlot.geom.geomPoint
import org.jetbrains.letsPlot.scale.scaleXContinuous
import org.jetbrains.letsPlot.scale.scaleYContinuous

// specify the eval numbers you're interested in
val xZoomed = listOf(5000, 5001)

// lists to store the combined data for all algorithms
val allEvalValues = mutableListOf<Int>()
val allRatingValues = mutableListOf<Double>()
val allLowerBounds = mutableListOf<Double>()
val allUpperBounds = mutableListOf<Double>()
val allAlgorithms = mutableListOf<String>()

// loop through all algorithms and gather the data into the combined lists
for (i in 0 until numAlgorithms) {
    // filter ratings to include only the eval numbers 5000, 5001
    val ratings = algPerf[i].ratings.values
        .filter { eval -> eval.evalNumber.substring(7, 11).toInt() in xZoomed }

    val yZoomed = ratings.map { it.rating }
    val lowerBoundsZoomed = ratings.map { it.rating - it.ratingDeviation }
    val upperBoundsZoomed = ratings.map { it.rating + it.ratingDeviation }

    // append the data to the combined lists
    allEvalValues.addAll(ratings.map { it.evalNumber.substring(7, 11).toInt() })
    allRatingValues.addAll(yZoomed)
    allLowerBounds.addAll(lowerBoundsZoomed)
    allUpperBounds.addAll(upperBoundsZoomed)
    allAlgorithms.addAll(List(yZoomed.size) { algPerf[i].name })
}

// prepare the combined data for the plot
val combinedData = mapOf(
    "eval" to allEvalValues,
    "rating" to allRatingValues,
    "lowerBounds" to allLowerBounds,
    "upperBounds" to allUpperBounds,
    "Algorithm" to allAlgorithms
)

// create a single plot with all algorithms
val combinedPlot = letsPlot(combinedData) +
        geomLine {
            x = "eval"
            y = "rating"
            color = "Algorithm"
        } +
        geomRibbon(alpha = 0.2) {
            x = "eval"
            ymin = "lowerBounds"
            ymax = "upperBounds"
            color = "Algorithm"
            fill = "Algorithm"
        } +
        geomPoint {
            x = "eval"
            y = "rating"
            color = "Algorithm"
        } +
        scaleXContinuous(breaks = listOf(5000, 5001), labels = listOf("5000", "5001")) +  // specify the tick marks, format labels as integers
        scaleYContinuous(limits = 1000 to 2000) +  // adjust y-axis limits if needed
        ggsize(1500, 750) +  // set plot size
        ggtitle("DOAs ratings just before and just after the change")

// display the combined plot
combinedPlot.show()

// save the combined plot
ggsave(combinedPlot, "plot_change.svg")
// Out:
//    <div id="0HML1y"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"DOAs ratings just before and just after the change"
// },
// "mapping":{
// },
// "data":{
// "upperBounds":[1319.5725529029721,1410.0976214707953,1665.2137234845172,1451.2453798752647,1315.4577770556944,1122.0633117578632,1582.9182067042648,1961.4775847689023,1866.83773996741,1805.1161021857956],
// "eval":[5000.0,5001.0,5000.0,5001.0,5000.0,5001.0,5000.0,5001.0,5000.0,5001.0],
// "lowerBounds":[1219.5725529029721,1310.0976214707953,1565.2137234845172,1351.2453798752647,1215.4577770556944,1022.0633117578632,1482.9182067042648,1861.4775847689023,1766.83773996741,1705.1161021857956],
// "rating":[1269.5725529029721,1360.0976214707953,1615.2137234845172,1401.2453798752647,1265.4577770556944,1072.0633117578632,1532.9182067042648,1911.4775847689023,1816.83773996741,1755.1161021857956],
// "Algorithm":["DSPSO","DSPSO","mQSO","mQSO","RPSO","RPSO","mjDE","mjDE","mPSO","mPSO"]
// },
// "ggsize":{
// "width":1500.0,
// "height":750.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "breaks":[5000.0,5001.0],
// "labels":["5000","5001"]
// },{
// "aesthetic":"y",
// "limits":[1000.0,2000.0]
// }],
// "layers":[{
// "mapping":{
// "x":"eval",
// "y":"rating",
// "color":"Algorithm"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"line",
// "data":{
// }
// },{
// "mapping":{
// "x":"eval",
// "ymin":"lowerBounds",
// "ymax":"upperBounds",
// "color":"Algorithm",
// "fill":"Algorithm"
// },
// "stat":"identity",
// "alpha":0.2,
// "position":"identity",
// "geom":"ribbon",
// "data":{
// }
// },{
// "mapping":{
// "x":"eval",
// "y":"rating",
// "color":"Algorithm"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"eval"
// },{
// "type":"float",
// "column":"rating"
// },{
// "type":"float",
// "column":"lowerBounds"
// },{
// "type":"float",
// "column":"upperBounds"
// },{
// "type":"str",
// "column":"Algorithm"
// }]
// }
// };
//            var plotContainer = document.getElementById("0HML1y");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
// D:\EARS\src\org\um\feri\ears\examples\lets-plot-images\plot_change.svg
